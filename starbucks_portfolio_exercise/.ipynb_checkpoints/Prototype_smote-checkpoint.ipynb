# %%
# load in packages
from itertools import combinations

from test_results import test_results, score
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk
import xgboost as xgb
import pickle
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# load in the data
train_data = pd.read_csv('./training.csv')
train_data.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   1        No         0   2  30.443518 -1.165083   1   1   3   2
# 1   3        No         0   3  32.159350 -0.645617   2   3   2   2
# 2   4        No         0   2  30.431659  0.133583   1   1   4   2
# 3   5        No         0   0  26.588914 -0.212728   2   1   4   2
# 4   8       Yes         0   3  28.044332 -0.385883   1   1   2   2

# %%
test_data = pd.read_csv('./Test.csv')
test_data.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   2        No         0   1  41.376390  1.172517   1   1   2   2
# 1   6       Yes         0   1  25.163598  0.653050   2   2   2   2
# 2   7       Yes         0   1  26.553778 -1.597972   2   3   4   2
# 3  10        No         0   2  28.529691 -1.078506   2   3   2   2
# 4  12        No         0   2  32.378538  0.479895   2   2   1   2

# %%
features = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7']

# %%
# split into train and valid
# create ensemble for train portion only
train, valid = sk.model_selection.train_test_split(train_data, test_size=0.2,random_state=42)
train['purchase'].value_counts()
# Out:
# 0    66795
# 1      832
# Name: purchase, dtype: int64

# %%
# Generate validation set
valid_control = valid[valid['Promotion']=='No']
Y_valid_control = valid_control['purchase']
X_valid_control = valid_control[features]

valid_exper = valid[valid['Promotion']=='Yes']
Y_valid_exper = valid_exper['purchase']
X_valid_exper = valid_exper[features]

# %%
#X_valid_control_upsamp, Y_valid_control_upsamp = sm.fit_sample(X_valid_control, Y_valid_control)
#X_valid_exper_upsamp, Y_valid_exper_upsamp = sm.fit_sample(X_valid_exper, Y_valid_exper)
#X_valid_control_upsamp = pd.DataFrame(X_valid_control_upsamp, columns=features)
#X_valid_exper_upsamp = pd.DataFrame(X_valid_exper_upsamp, columns=features)
#Y_valid_control_upsamp = pd.Series(Y_valid_control_upsamp)
#Y_valid_exper_upsamp = pd.Series(Y_valid_exper_upsamp)

# %%
#random_seeds = [1, 100, 200, 300, 400, 500, 600, 700, 800, 900]

for i in range(10): #########################################
    # Get a subsample of data with no purchases
    #random_seed = (i+1)*100 #########################################
    #train_sample = train.sample(frac=0.1, replace=True, random_state=random_seed) #########################################
    train_sample = train.sample(frac=0.1, replace=True, random_state=random_seeds[i])
    train_control = train_sample[train_sample['Promotion']=='No']
    train_exper = train_sample[train_sample['Promotion']=='Yes']
    
    Y_train_control = train_control['purchase']
    X_train_control = train_control[features]

    Y_train_exper = train_exper['purchase']
    X_train_exper = train_exper[features]
    
    # up sample with SMOTE
    sm = SMOTE(random_state=42, ratio = 1.0)
    X_train_control_upsamp, Y_train_control_upsamp = sm.fit_sample(X_train_control, Y_train_control)
    X_train_exper_upsamp, Y_train_exper_upsamp = sm.fit_sample(X_train_exper, Y_train_exper)
    
    X_train_control_upsamp = pd.DataFrame(X_train_control_upsamp, columns=features)
    X_train_exper_upsamp = pd.DataFrame(X_train_exper_upsamp, columns=features)
    
    # model for control group
    model_control_name = "model_control_" + str(i+1) +'.pickle.dat'
    
    eval_set = [(X_train_control_upsamp, Y_train_control_upsamp), (X_valid_control, Y_valid_control)]
    model_control = xgb.XGBClassifier(learning_rate = 0.1,\
                                  max_depth = 7,\
                                  min_child_weight = 3,\
                                  objective = 'binary:logistic',\
                                  seed = 42,\
                                  gamma = 1,\
                                  silent = True)
    model_control.fit(X_train_control_upsamp, Y_train_control_upsamp, eval_set=eval_set,\
                      eval_metric="auc", verbose=True, early_stopping_rounds=30)
    # save model for control group
    pickle.dump(model_control, open(model_control_name, "wb"))
    
    # for experimental group
    model_exper_name = "model_exper_" + str(i+1) +'.pickle.dat'
    eval_set = [(X_train_exper_upsamp, Y_train_exper_upsamp), (X_valid_exper, Y_valid_exper)]
    model_exper = xgb.XGBClassifier(learning_rate = 0.1,\
                                  max_depth = 7,\
                                  min_child_weight = 3,\
                                  objective = 'binary:logistic',\
                                  seed = 42,\
                                  gamma = 1,\
                                  silent = True)
    model_exper.fit(X_train_exper_upsamp, Y_train_exper_upsamp, eval_set=eval_set,\
                    eval_metric="auc", verbose=True, early_stopping_rounds=30)
    
    # save model for control group
    pickle.dump(model_exper, open(model_exper_name, "wb"))
# Out:
# [0]	validation_0-auc:0.972357	validation_1-auc:0.547679
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.972619	validation_1-auc:0.547679
# [2]	validation_0-auc:0.995437	validation_1-auc:0.518224
# [3]	validation_0-auc:0.996485	validation_1-auc:0.517224
# [4]	validation_0-auc:0.996857	validation_1-auc:0.509132
# [5]	validation_0-auc:0.996995	validation_1-auc:0.504896
# [6]	validation_0-auc:0.997289	validation_1-auc:0.500807
# [7]	validation_0-auc:0.997334	validation_1-auc:0.502922
# [8]	validation_0-auc:0.997417	validation_1-auc:0.492521
# [9]	validation_0-auc:0.997431	validation_1-auc:0.488757
# [10]	validation_0-auc:0.997638	validation_1-auc:0.485378
# [11]	validation_0-auc:0.997648	validation_1-auc:0.481709
# [12]	validation_0-auc:0.997749	validation_1-auc:0.491402
# [13]	validation_0-auc:0.997822	validation_1-auc:0.48473
# [14]	validation_0-auc:0.997853	validation_1-auc:0.481116
# [15]	validation_0-auc:0.998013	validation_1-auc:0.479699
# [16]	validation_0-auc:0.998043	validation_1-auc:0.475088
# [17]	validation_0-auc:0.99812	validation_1-auc:0.470701
# [18]	validation_0-auc:0.998211	validation_1-auc:0.467302
# [19]	validation_0-auc:0.998367	validation_1-auc:0.467654
# [20]	validation_0-auc:0.998433	validation_1-auc:0.46421
# [21]	validation_0-auc:0.998505	validation_1-auc:0.458185
# [22]	validation_0-auc:0.99852	validation_1-auc:0.457326
# [23]	validation_0-auc:0.998564	validation_1-auc:0.454451
# [24]	validation_0-auc:0.99866	validation_1-auc:0.4534
# [25]	validation_0-auc:0.998769	validation_1-auc:0.45118
# [26]	validation_0-auc:0.998793	validation_1-auc:0.448886
# [27]	validation_0-auc:0.998826	validation_1-auc:0.449026
# [28]	validation_0-auc:0.998808	validation_1-auc:0.445434
# [29]	validation_0-auc:0.99886	validation_1-auc:0.44217
# [30]	validation_0-auc:0.998859	validation_1-auc:0.444262
# Stopping. Best iteration:
# [0]	validation_0-auc:0.972357	validation_1-auc:0.547679
#
# [0]	validation_0-auc:0.954231	validation_1-auc:0.647478
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.958845	validation_1-auc:0.649017
# [2]	validation_0-auc:0.958941	validation_1-auc:0.647838
# [3]	validation_0-auc:0.961641	validation_1-auc:0.646529
# [4]	validation_0-auc:0.97204	validation_1-auc:0.652546
# [5]	validation_0-auc:0.974622	validation_1-auc:0.649351
# [6]	validation_0-auc:0.981127	validation_1-auc:0.653301
# [7]	validation_0-auc:0.984641	validation_1-auc:0.652963
# [8]	validation_0-auc:0.984823	validation_1-auc:0.652511
# [9]	validation_0-auc:0.989157	validation_1-auc:0.649964
# [10]	validation_0-auc:0.990668	validation_1-auc:0.650862
# [11]	validation_0-auc:0.991194	validation_1-auc:0.65241
# [12]	validation_0-auc:0.992174	validation_1-auc:0.65327
# [13]	validation_0-auc:0.992245	validation_1-auc:0.660139
# [14]	validation_0-auc:0.99272	validation_1-auc:0.659668
# [15]	validation_0-auc:0.99317	validation_1-auc:0.657936
# [16]	validation_0-auc:0.993914	validation_1-auc:0.653905
# [17]	validation_0-auc:0.994087	validation_1-auc:0.649701
# [18]	validation_0-auc:0.994891	validation_1-auc:0.645161
# [19]	validation_0-auc:0.995346	validation_1-auc:0.64787
# [20]	validation_0-auc:0.995559	validation_1-auc:0.64542
# [21]	validation_0-auc:0.995833	validation_1-auc:0.641446
# [22]	validation_0-auc:0.995915	validation_1-auc:0.637182
# [23]	validation_0-auc:0.995883	validation_1-auc:0.639195
# [24]	validation_0-auc:0.996228	validation_1-auc:0.63978
# [25]	validation_0-auc:0.996361	validation_1-auc:0.640786
# [26]	validation_0-auc:0.996536	validation_1-auc:0.642105
# [27]	validation_0-auc:0.996576	validation_1-auc:0.643371
# [28]	validation_0-auc:0.996631	validation_1-auc:0.641724
# [29]	validation_0-auc:0.996695	validation_1-auc:0.639311
# [30]	validation_0-auc:0.996768	validation_1-auc:0.636294
# [31]	validation_0-auc:0.996838	validation_1-auc:0.636208
# [32]	validation_0-auc:0.99694	validation_1-auc:0.635158
# [33]	validation_0-auc:0.996957	validation_1-auc:0.634158
# [34]	validation_0-auc:0.997073	validation_1-auc:0.637455
# [35]	validation_0-auc:0.997141	validation_1-auc:0.636675
# [36]	validation_0-auc:0.99717	validation_1-auc:0.636351
# [37]	validation_0-auc:0.997397	validation_1-auc:0.642663
# [38]	validation_0-auc:0.997485	validation_1-auc:0.641923
# [39]	validation_0-auc:0.997563	validation_1-auc:0.641896
# [40]	validation_0-auc:0.997607	validation_1-auc:0.641401
# [41]	validation_0-auc:0.997664	validation_1-auc:0.640244
# [42]	validation_0-auc:0.997701	validation_1-auc:0.640543
# [43]	validation_0-auc:0.997818	validation_1-auc:0.639614
# Stopping. Best iteration:
# [13]	validation_0-auc:0.992245	validation_1-auc:0.660139
#
# [0]	validation_0-auc:0.964865	validation_1-auc:0.540378
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.972393	validation_1-auc:0.540577
# [2]	validation_0-auc:0.986253	validation_1-auc:0.537733
# [3]	validation_0-auc:0.985652	validation_1-auc:0.538732
# [4]	validation_0-auc:0.990167	validation_1-auc:0.54669
# [5]	validation_0-auc:0.993563	validation_1-auc:0.547377
# [6]	validation_0-auc:0.993836	validation_1-auc:0.54843
# [7]	validation_0-auc:0.994378	validation_1-auc:0.546663
# [8]	validation_0-auc:0.994312	validation_1-auc:0.543335
# [9]	validation_0-auc:0.996462	validation_1-auc:0.530247
# [10]	validation_0-auc:0.996575	validation_1-auc:0.528281
# [11]	validation_0-auc:0.996636	validation_1-auc:0.527548
# [12]	validation_0-auc:0.997535	validation_1-auc:0.53078
# [13]	validation_0-auc:0.997636	validation_1-auc:0.526023
# [14]	validation_0-auc:0.997812	validation_1-auc:0.528873
# [15]	validation_0-auc:0.997876	validation_1-auc:0.524517
# [16]	validation_0-auc:0.997936	validation_1-auc:0.524732
# [17]	validation_0-auc:0.998026	validation_1-auc:0.528058
# [18]	validation_0-auc:0.998072	validation_1-auc:0.528875
# [19]	validation_0-auc:0.998129	validation_1-auc:0.52801
# [20]	validation_0-auc:0.998168	validation_1-auc:0.524613
# [21]	validation_0-auc:0.998346	validation_1-auc:0.522114
# [22]	validation_0-auc:0.998342	validation_1-auc:0.521299
# [23]	validation_0-auc:0.998402	validation_1-auc:0.519536
# [24]	validation_0-auc:0.99852	validation_1-auc:0.519352
# [25]	validation_0-auc:0.99857	validation_1-auc:0.518212
# [26]	validation_0-auc:0.998646	validation_1-auc:0.516023
# [27]	validation_0-auc:0.998698	validation_1-auc:0.515617
# [28]	validation_0-auc:0.998724	validation_1-auc:0.510841
# [29]	validation_0-auc:0.998773	validation_1-auc:0.506767
# [30]	validation_0-auc:0.998806	validation_1-auc:0.507618
# [31]	validation_0-auc:0.998842	validation_1-auc:0.508654
# [32]	validation_0-auc:0.998851	validation_1-auc:0.508201
# [33]	validation_0-auc:0.998904	validation_1-auc:0.508213
# [34]	validation_0-auc:0.998942	validation_1-auc:0.504946
# [35]	validation_0-auc:0.998964	validation_1-auc:0.504158
# [36]	validation_0-auc:0.999008	validation_1-auc:0.501969
# Stopping. Best iteration:
# [6]	validation_0-auc:0.993836	validation_1-auc:0.54843
#
# [0]	validation_0-auc:0.966927	validation_1-auc:0.556946
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.97654	validation_1-auc:0.582873
# [2]	validation_0-auc:0.983611	validation_1-auc:0.576011
# [3]	validation_0-auc:0.982478	validation_1-auc:0.577418
# [4]	validation_0-auc:0.988085	validation_1-auc:0.57177
# [5]	validation_0-auc:0.989961	validation_1-auc:0.571525
# [6]	validation_0-auc:0.992206	validation_1-auc:0.574972
# [7]	validation_0-auc:0.992695	validation_1-auc:0.574526
# [8]	validation_0-auc:0.993336	validation_1-auc:0.571343
# [9]	validation_0-auc:0.99333	validation_1-auc:0.579286
# [10]	validation_0-auc:0.993718	validation_1-auc:0.577924
# [11]	validation_0-auc:0.993689	validation_1-auc:0.580237
# [12]	validation_0-auc:0.994459	validation_1-auc:0.590027
# [13]	validation_0-auc:0.994742	validation_1-auc:0.597699
# [14]	validation_0-auc:0.995018	validation_1-auc:0.594236
# [15]	validation_0-auc:0.995058	validation_1-auc:0.593986
# [16]	validation_0-auc:0.994985	validation_1-auc:0.600205
# [17]	validation_0-auc:0.994977	validation_1-auc:0.60351
# [18]	validation_0-auc:0.995194	validation_1-auc:0.603901
# [19]	validation_0-auc:0.995376	validation_1-auc:0.600749
# [20]	validation_0-auc:0.995534	validation_1-auc:0.599571
# [21]	validation_0-auc:0.995861	validation_1-auc:0.601973
# [22]	validation_0-auc:0.995892	validation_1-auc:0.601985
# [23]	validation_0-auc:0.996005	validation_1-auc:0.600982
# [24]	validation_0-auc:0.995993	validation_1-auc:0.60266
# [25]	validation_0-auc:0.996089	validation_1-auc:0.602737
# [26]	validation_0-auc:0.996113	validation_1-auc:0.602236
# [27]	validation_0-auc:0.996103	validation_1-auc:0.606009
# [28]	validation_0-auc:0.996149	validation_1-auc:0.604756
# [29]	validation_0-auc:0.99626	validation_1-auc:0.603204
# [30]	validation_0-auc:0.996296	validation_1-auc:0.604104
# [31]	validation_0-auc:0.996554	validation_1-auc:0.603796
# [32]	validation_0-auc:0.996571	validation_1-auc:0.60314
# [33]	validation_0-auc:0.996792	validation_1-auc:0.603322
# [34]	validation_0-auc:0.996858	validation_1-auc:0.605964
# [35]	validation_0-auc:0.996967	validation_1-auc:0.606771
# [36]	validation_0-auc:0.997204	validation_1-auc:0.607311
# [37]	validation_0-auc:0.997363	validation_1-auc:0.605986
# [38]	validation_0-auc:0.997421	validation_1-auc:0.605269
# [39]	validation_0-auc:0.997513	validation_1-auc:0.605265
# [40]	validation_0-auc:0.997515	validation_1-auc:0.604896
# [41]	validation_0-auc:0.997576	validation_1-auc:0.605569
# [42]	validation_0-auc:0.99762	validation_1-auc:0.606545
# [43]	validation_0-auc:0.997648	validation_1-auc:0.605239
# [44]	validation_0-auc:0.997776	validation_1-auc:0.605074
# [45]	validation_0-auc:0.997804	validation_1-auc:0.604804
# [46]	validation_0-auc:0.997896	validation_1-auc:0.605447
# [47]	validation_0-auc:0.997914	validation_1-auc:0.605724
# [48]	validation_0-auc:0.997919	validation_1-auc:0.605895
# [49]	validation_0-auc:0.997997	validation_1-auc:0.606942
# [50]	validation_0-auc:0.99807	validation_1-auc:0.607235
# [51]	validation_0-auc:0.998095	validation_1-auc:0.607065
# [52]	validation_0-auc:0.998155	validation_1-auc:0.607134
# [53]	validation_0-auc:0.998227	validation_1-auc:0.606188
# [54]	validation_0-auc:0.998284	validation_1-auc:0.606895
# [55]	validation_0-auc:0.998294	validation_1-auc:0.607205
# [56]	validation_0-auc:0.998345	validation_1-auc:0.607838
# [57]	validation_0-auc:0.998371	validation_1-auc:0.607748
# [58]	validation_0-auc:0.998425	validation_1-auc:0.607192
# [59]	validation_0-auc:0.998455	validation_1-auc:0.606043
# [60]	validation_0-auc:0.998477	validation_1-auc:0.606785
# [61]	validation_0-auc:0.998524	validation_1-auc:0.60631
# [62]	validation_0-auc:0.998568	validation_1-auc:0.606659
# [63]	validation_0-auc:0.998592	validation_1-auc:0.607423
# [64]	validation_0-auc:0.998615	validation_1-auc:0.605867
# [65]	validation_0-auc:0.998624	validation_1-auc:0.605077
# [66]	validation_0-auc:0.998639	validation_1-auc:0.604917
# [67]	validation_0-auc:0.998667	validation_1-auc:0.604045
# [68]	validation_0-auc:0.998686	validation_1-auc:0.602838
# [69]	validation_0-auc:0.99869	validation_1-auc:0.602064
# [70]	validation_0-auc:0.998723	validation_1-auc:0.60156
# [71]	validation_0-auc:0.998781	validation_1-auc:0.601686
# [72]	validation_0-auc:0.998791	validation_1-auc:0.60065
# [73]	validation_0-auc:0.99881	validation_1-auc:0.599967
# [74]	validation_0-auc:0.998834	validation_1-auc:0.599885
# [75]	validation_0-auc:0.998892	validation_1-auc:0.601636
# [76]	validation_0-auc:0.998907	validation_1-auc:0.600878
# [77]	validation_0-auc:0.998937	validation_1-auc:0.600379
# [78]	validation_0-auc:0.998961	validation_1-auc:0.600736
# [79]	validation_0-auc:0.998986	validation_1-auc:0.600438
# [80]	validation_0-auc:0.998998	validation_1-auc:0.599969
# [81]	validation_0-auc:0.999026	validation_1-auc:0.59987
# [82]	validation_0-auc:0.999059	validation_1-auc:0.599155
# [83]	validation_0-auc:0.999084	validation_1-auc:0.598693
# [84]	validation_0-auc:0.999104	validation_1-auc:0.598196
# [85]	validation_0-auc:0.999115	validation_1-auc:0.598014
# [86]	validation_0-auc:0.999128	validation_1-auc:0.597774
# Stopping. Best iteration:
# [56]	validation_0-auc:0.998345	validation_1-auc:0.607838
#
# [0]	validation_0-auc:0.972073	validation_1-auc:0.566312
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.976935	validation_1-auc:0.580494
# [2]	validation_0-auc:0.978206	validation_1-auc:0.575847
# [3]	validation_0-auc:0.992352	validation_1-auc:0.57104
# [4]	validation_0-auc:0.993656	validation_1-auc:0.570725
# [5]	validation_0-auc:0.995806	validation_1-auc:0.581134
# [6]	validation_0-auc:0.996023	validation_1-auc:0.571329
# [7]	validation_0-auc:0.996193	validation_1-auc:0.566328
# [8]	validation_0-auc:0.997604	validation_1-auc:0.564903
# [9]	validation_0-auc:0.997816	validation_1-auc:0.575039
# [10]	validation_0-auc:0.998152	validation_1-auc:0.573782
# [11]	validation_0-auc:0.998275	validation_1-auc:0.57301
# [12]	validation_0-auc:0.998401	validation_1-auc:0.574819
# [13]	validation_0-auc:0.998538	validation_1-auc:0.571963
# [14]	validation_0-auc:0.998614	validation_1-auc:0.573336
# [15]	validation_0-auc:0.998709	validation_1-auc:0.576174
# [16]	validation_0-auc:0.998761	validation_1-auc:0.578404
# [17]	validation_0-auc:0.998767	validation_1-auc:0.580114
# [18]	validation_0-auc:0.998786	validation_1-auc:0.583653
# [19]	validation_0-auc:0.998861	validation_1-auc:0.58764
# [20]	validation_0-auc:0.998836	validation_1-auc:0.587211
# [21]	validation_0-auc:0.999027	validation_1-auc:0.588116
# [22]	validation_0-auc:0.999109	validation_1-auc:0.589062
# [23]	validation_0-auc:0.999187	validation_1-auc:0.589392
# [24]	validation_0-auc:0.9992	validation_1-auc:0.590048
# [25]	validation_0-auc:0.999226	validation_1-auc:0.587438
# [26]	validation_0-auc:0.999253	validation_1-auc:0.58541
# [27]	validation_0-auc:0.999319	validation_1-auc:0.585536
# [28]	validation_0-auc:0.999351	validation_1-auc:0.583877
# [29]	validation_0-auc:0.999362	validation_1-auc:0.581292
# [30]	validation_0-auc:0.999412	validation_1-auc:0.581589
# [31]	validation_0-auc:0.99943	validation_1-auc:0.576051
# [32]	validation_0-auc:0.999438	validation_1-auc:0.575165
# [33]	validation_0-auc:0.99949	validation_1-auc:0.575106
# [34]	validation_0-auc:0.999497	validation_1-auc:0.572472
# [35]	validation_0-auc:0.999535	validation_1-auc:0.573492
# [36]	validation_0-auc:0.999544	validation_1-auc:0.571696
# [37]	validation_0-auc:0.999543	validation_1-auc:0.572138
# [38]	validation_0-auc:0.999549	validation_1-auc:0.567702
# [39]	validation_0-auc:0.999552	validation_1-auc:0.566817
# [40]	validation_0-auc:0.999574	validation_1-auc:0.567035
# [41]	validation_0-auc:0.999596	validation_1-auc:0.566379
# [42]	validation_0-auc:0.999607	validation_1-auc:0.561778
# [43]	validation_0-auc:0.999625	validation_1-auc:0.560544
# [44]	validation_0-auc:0.999645	validation_1-auc:0.561284
# [45]	validation_0-auc:0.999648	validation_1-auc:0.558176
# [46]	validation_0-auc:0.999691	validation_1-auc:0.558133
# [47]	validation_0-auc:0.999718	validation_1-auc:0.555635
# [48]	validation_0-auc:0.999722	validation_1-auc:0.556219
# [49]	validation_0-auc:0.999755	validation_1-auc:0.555426
# [50]	validation_0-auc:0.999776	validation_1-auc:0.554818
# [51]	validation_0-auc:0.999786	validation_1-auc:0.554659
# [52]	validation_0-auc:0.9998	validation_1-auc:0.553234
# [53]	validation_0-auc:0.999818	validation_1-auc:0.551105
# [54]	validation_0-auc:0.999817	validation_1-auc:0.550857
# Stopping. Best iteration:
# [24]	validation_0-auc:0.9992	validation_1-auc:0.590048
#
# [0]	validation_0-auc:0.949589	validation_1-auc:0.611373
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.956292	validation_1-auc:0.61739
# [2]	validation_0-auc:0.971326	validation_1-auc:0.614348
# [3]	validation_0-auc:0.971352	validation_1-auc:0.6203
# [4]	validation_0-auc:0.980866	validation_1-auc:0.613266
# [5]	validation_0-auc:0.981618	validation_1-auc:0.614775
# [6]	validation_0-auc:0.985869	validation_1-auc:0.615931
# [7]	validation_0-auc:0.987212	validation_1-auc:0.608579
# [8]	validation_0-auc:0.987651	validation_1-auc:0.608474
# [9]	validation_0-auc:0.988614	validation_1-auc:0.609195
# [10]	validation_0-auc:0.989142	validation_1-auc:0.60628
# [11]	validation_0-auc:0.989965	validation_1-auc:0.604985
# [12]	validation_0-auc:0.990597	validation_1-auc:0.601394
# [13]	validation_0-auc:0.99122	validation_1-auc:0.604876
# [14]	validation_0-auc:0.992718	validation_1-auc:0.606036
# [15]	validation_0-auc:0.994913	validation_1-auc:0.597775
# [16]	validation_0-auc:0.995838	validation_1-auc:0.593709
# [17]	validation_0-auc:0.996293	validation_1-auc:0.5963
# [18]	validation_0-auc:0.996623	validation_1-auc:0.602593
# [19]	validation_0-auc:0.997131	validation_1-auc:0.599198
# [20]	validation_0-auc:0.997233	validation_1-auc:0.599508
# [21]	validation_0-auc:0.997519	validation_1-auc:0.602081
# [22]	validation_0-auc:0.997628	validation_1-auc:0.604481
# [23]	validation_0-auc:0.997814	validation_1-auc:0.604675
# [24]	validation_0-auc:0.997912	validation_1-auc:0.601462
# [25]	validation_0-auc:0.997967	validation_1-auc:0.60343
# [26]	validation_0-auc:0.998095	validation_1-auc:0.605557
# [27]	validation_0-auc:0.998094	validation_1-auc:0.60553
# [28]	validation_0-auc:0.998155	validation_1-auc:0.603577
# [29]	validation_0-auc:0.998245	validation_1-auc:0.602415
# [30]	validation_0-auc:0.998317	validation_1-auc:0.604819
# [31]	validation_0-auc:0.998335	validation_1-auc:0.605393
# [32]	validation_0-auc:0.998386	validation_1-auc:0.606602
# [33]	validation_0-auc:0.998404	validation_1-auc:0.607721
# Stopping. Best iteration:
# [3]	validation_0-auc:0.971352	validation_1-auc:0.6203
#
# [0]	validation_0-auc:0.99633	validation_1-auc:0.461204
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.996585	validation_1-auc:0.460498
# [2]	validation_0-auc:0.997484	validation_1-auc:0.457463
# [3]	validation_0-auc:0.998088	validation_1-auc:0.44613
# [4]	validation_0-auc:0.998609	validation_1-auc:0.451212
# [5]	validation_0-auc:0.998617	validation_1-auc:0.449716
# [6]	validation_0-auc:0.998575	validation_1-auc:0.448676
# [7]	validation_0-auc:0.998772	validation_1-auc:0.45259
# [8]	validation_0-auc:0.998792	validation_1-auc:0.453212
# [9]	validation_0-auc:0.99877	validation_1-auc:0.450851
# [10]	validation_0-auc:0.998907	validation_1-auc:0.452957
# [11]	validation_0-auc:0.999297	validation_1-auc:0.478551
# [12]	validation_0-auc:0.999331	validation_1-auc:0.477089
# [13]	validation_0-auc:0.999408	validation_1-auc:0.46125
# [14]	validation_0-auc:0.999473	validation_1-auc:0.465738
# [15]	validation_0-auc:0.999485	validation_1-auc:0.465946
# [16]	validation_0-auc:0.999537	validation_1-auc:0.465305
# [17]	validation_0-auc:0.999646	validation_1-auc:0.460953
# [18]	validation_0-auc:0.999686	validation_1-auc:0.461107
# [19]	validation_0-auc:0.999698	validation_1-auc:0.462923
# [20]	validation_0-auc:0.999703	validation_1-auc:0.461627
# [21]	validation_0-auc:0.999695	validation_1-auc:0.463327
# [22]	validation_0-auc:0.999701	validation_1-auc:0.464674
# [23]	validation_0-auc:0.999699	validation_1-auc:0.461594
# [24]	validation_0-auc:0.999703	validation_1-auc:0.464157
# [25]	validation_0-auc:0.999703	validation_1-auc:0.463318
# [26]	validation_0-auc:0.999694	validation_1-auc:0.461636
# [27]	validation_0-auc:0.999699	validation_1-auc:0.458748
# [28]	validation_0-auc:0.999691	validation_1-auc:0.458757
# [29]	validation_0-auc:0.999712	validation_1-auc:0.456544
# [30]	validation_0-auc:0.99974	validation_1-auc:0.456894
# [31]	validation_0-auc:0.999724	validation_1-auc:0.456619
# [32]	validation_0-auc:0.999757	validation_1-auc:0.456022
# [33]	validation_0-auc:0.999761	validation_1-auc:0.453322
# [34]	validation_0-auc:0.99976	validation_1-auc:0.454468
# [35]	validation_0-auc:0.999754	validation_1-auc:0.461737
# [36]	validation_0-auc:0.999761	validation_1-auc:0.46264
# [37]	validation_0-auc:0.999771	validation_1-auc:0.462324
# [38]	validation_0-auc:0.999784	validation_1-auc:0.461928
# [39]	validation_0-auc:0.999789	validation_1-auc:0.462308
# [40]	validation_0-auc:0.999799	validation_1-auc:0.462239
# [41]	validation_0-auc:0.999801	validation_1-auc:0.463555
# Stopping. Best iteration:
# [11]	validation_0-auc:0.999297	validation_1-auc:0.478551
#
# [0]	validation_0-auc:0.958018	validation_1-auc:0.502695
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.960168	validation_1-auc:0.507764
# [2]	validation_0-auc:0.966602	validation_1-auc:0.530274
# [3]	validation_0-auc:0.97417	validation_1-auc:0.534361
# [4]	validation_0-auc:0.97196	validation_1-auc:0.540382
# [5]	validation_0-auc:0.972855	validation_1-auc:0.538719
# [6]	validation_0-auc:0.983012	validation_1-auc:0.581104
# [7]	validation_0-auc:0.985148	validation_1-auc:0.581023
# [8]	validation_0-auc:0.989787	validation_1-auc:0.588087
# [9]	validation_0-auc:0.990781	validation_1-auc:0.596402
# [10]	validation_0-auc:0.99338	validation_1-auc:0.593387
# [11]	validation_0-auc:0.993984	validation_1-auc:0.591153
# [12]	validation_0-auc:0.994613	validation_1-auc:0.591527
# [13]	validation_0-auc:0.994986	validation_1-auc:0.594238
# [14]	validation_0-auc:0.995503	validation_1-auc:0.597568
# [15]	validation_0-auc:0.995605	validation_1-auc:0.594109
# [16]	validation_0-auc:0.995674	validation_1-auc:0.597038
# [17]	validation_0-auc:0.995908	validation_1-auc:0.598548
# [18]	validation_0-auc:0.995923	validation_1-auc:0.599434
# [19]	validation_0-auc:0.995942	validation_1-auc:0.599702
# [20]	validation_0-auc:0.996185	validation_1-auc:0.605866
# [21]	validation_0-auc:0.996357	validation_1-auc:0.599816
# [22]	validation_0-auc:0.996444	validation_1-auc:0.601553
# [23]	validation_0-auc:0.996542	validation_1-auc:0.598421
# [24]	validation_0-auc:0.996701	validation_1-auc:0.601296
# [25]	validation_0-auc:0.996743	validation_1-auc:0.602976
# [26]	validation_0-auc:0.996826	validation_1-auc:0.601694
# [27]	validation_0-auc:0.996881	validation_1-auc:0.599137
# [28]	validation_0-auc:0.996949	validation_1-auc:0.60033
# [29]	validation_0-auc:0.997015	validation_1-auc:0.599455
# [30]	validation_0-auc:0.997102	validation_1-auc:0.598025
# [31]	validation_0-auc:0.997144	validation_1-auc:0.595711
# [32]	validation_0-auc:0.997246	validation_1-auc:0.598083
# [33]	validation_0-auc:0.997291	validation_1-auc:0.599136
# [34]	validation_0-auc:0.997315	validation_1-auc:0.600075
# [35]	validation_0-auc:0.997349	validation_1-auc:0.600619
# [36]	validation_0-auc:0.99738	validation_1-auc:0.600302
# [37]	validation_0-auc:0.99745	validation_1-auc:0.597387
# [38]	validation_0-auc:0.997463	validation_1-auc:0.596928
# [39]	validation_0-auc:0.997531	validation_1-auc:0.595562
# [40]	validation_0-auc:0.997549	validation_1-auc:0.594596
# [41]	validation_0-auc:0.997552	validation_1-auc:0.594193
# [42]	validation_0-auc:0.997576	validation_1-auc:0.593872
# [43]	validation_0-auc:0.997599	validation_1-auc:0.59313
# [44]	validation_0-auc:0.997641	validation_1-auc:0.592124
# [45]	validation_0-auc:0.99773	validation_1-auc:0.591029
# [46]	validation_0-auc:0.997752	validation_1-auc:0.59167
# [47]	validation_0-auc:0.997817	validation_1-auc:0.589306
# [48]	validation_0-auc:0.997838	validation_1-auc:0.591413
# [49]	validation_0-auc:0.997889	validation_1-auc:0.590904
# [50]	validation_0-auc:0.997897	validation_1-auc:0.590905
# Stopping. Best iteration:
# [20]	validation_0-auc:0.996185	validation_1-auc:0.605866
#
# [0]	validation_0-auc:0.966105	validation_1-auc:0.55331
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.969759	validation_1-auc:0.530715
# [2]	validation_0-auc:0.969829	validation_1-auc:0.530293
# [3]	validation_0-auc:0.970915	validation_1-auc:0.529228
# [4]	validation_0-auc:0.976654	validation_1-auc:0.523413
# [5]	validation_0-auc:0.983017	validation_1-auc:0.519414
# [6]	validation_0-auc:0.994677	validation_1-auc:0.510446
# [7]	validation_0-auc:0.99575	validation_1-auc:0.508216
# [8]	validation_0-auc:0.996171	validation_1-auc:0.506512
# [9]	validation_0-auc:0.996578	validation_1-auc:0.501891
# [10]	validation_0-auc:0.997425	validation_1-auc:0.498603
# [11]	validation_0-auc:0.997604	validation_1-auc:0.49625
# [12]	validation_0-auc:0.997908	validation_1-auc:0.489643
# [13]	validation_0-auc:0.998134	validation_1-auc:0.489012
# [14]	validation_0-auc:0.998231	validation_1-auc:0.488008
# [15]	validation_0-auc:0.998357	validation_1-auc:0.492889
# [16]	validation_0-auc:0.998513	validation_1-auc:0.489625
# [17]	validation_0-auc:0.998583	validation_1-auc:0.492863
# [18]	validation_0-auc:0.998708	validation_1-auc:0.48883
# [19]	validation_0-auc:0.998846	validation_1-auc:0.488829
# [20]	validation_0-auc:0.998898	validation_1-auc:0.487881
# [21]	validation_0-auc:0.998948	validation_1-auc:0.486596
# [22]	validation_0-auc:0.999016	validation_1-auc:0.489811
# [23]	validation_0-auc:0.999068	validation_1-auc:0.494097
# [24]	validation_0-auc:0.999073	validation_1-auc:0.495744
# [25]	validation_0-auc:0.999092	validation_1-auc:0.490381
# [26]	validation_0-auc:0.999174	validation_1-auc:0.4862
# [27]	validation_0-auc:0.99922	validation_1-auc:0.484491
# [28]	validation_0-auc:0.99924	validation_1-auc:0.480562
# [29]	validation_0-auc:0.999277	validation_1-auc:0.477211
# [30]	validation_0-auc:0.99929	validation_1-auc:0.476806
# Stopping. Best iteration:
# [0]	validation_0-auc:0.966105	validation_1-auc:0.55331
#
# [0]	validation_0-auc:0.975314	validation_1-auc:0.584579
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.979025	validation_1-auc:0.576894
# [2]	validation_0-auc:0.98631	validation_1-auc:0.583841
# [3]	validation_0-auc:0.987368	validation_1-auc:0.588128
# [4]	validation_0-auc:0.990363	validation_1-auc:0.592181
# [5]	validation_0-auc:0.992712	validation_1-auc:0.599015
# [6]	validation_0-auc:0.993415	validation_1-auc:0.603477
# [7]	validation_0-auc:0.993304	validation_1-auc:0.60282
# [8]	validation_0-auc:0.994212	validation_1-auc:0.597697
# [9]	validation_0-auc:0.994288	validation_1-auc:0.597759
# [10]	validation_0-auc:0.994353	validation_1-auc:0.599949
# [11]	validation_0-auc:0.994423	validation_1-auc:0.595222
# [12]	validation_0-auc:0.994642	validation_1-auc:0.593829
# [13]	validation_0-auc:0.994972	validation_1-auc:0.594754
# [14]	validation_0-auc:0.995281	validation_1-auc:0.59358
# [15]	validation_0-auc:0.995802	validation_1-auc:0.594063
# [16]	validation_0-auc:0.996103	validation_1-auc:0.590803
# [17]	validation_0-auc:0.996329	validation_1-auc:0.591951
# [18]	validation_0-auc:0.996574	validation_1-auc:0.593109
# [19]	validation_0-auc:0.996768	validation_1-auc:0.594781
# [20]	validation_0-auc:0.996914	validation_1-auc:0.594398
# [21]	validation_0-auc:0.997037	validation_1-auc:0.597008
# [22]	validation_0-auc:0.997142	validation_1-auc:0.597192
# [23]	validation_0-auc:0.997214	validation_1-auc:0.599094
# [24]	validation_0-auc:0.997274	validation_1-auc:0.598133
# [25]	validation_0-auc:0.997363	validation_1-auc:0.595677
# [26]	validation_0-auc:0.99744	validation_1-auc:0.601448
# [27]	validation_0-auc:0.997519	validation_1-auc:0.603951
# [28]	validation_0-auc:0.997562	validation_1-auc:0.60556
# [29]	validation_0-auc:0.997579	validation_1-auc:0.605079
# [30]	validation_0-auc:0.997641	validation_1-auc:0.605197
# [31]	validation_0-auc:0.997664	validation_1-auc:0.608603
# [32]	validation_0-auc:0.997711	validation_1-auc:0.610818
# [33]	validation_0-auc:0.997774	validation_1-auc:0.610507
# [34]	validation_0-auc:0.997833	validation_1-auc:0.610575
# [35]	validation_0-auc:0.997943	validation_1-auc:0.614041
# [36]	validation_0-auc:0.997989	validation_1-auc:0.614475
# [37]	validation_0-auc:0.998076	validation_1-auc:0.612449
# [38]	validation_0-auc:0.99813	validation_1-auc:0.612648
# [39]	validation_0-auc:0.998154	validation_1-auc:0.614112
# [40]	validation_0-auc:0.998193	validation_1-auc:0.614823
# [41]	validation_0-auc:0.998271	validation_1-auc:0.617711
# [42]	validation_0-auc:0.998309	validation_1-auc:0.616583
# [43]	validation_0-auc:0.998366	validation_1-auc:0.615005
# [44]	validation_0-auc:0.998413	validation_1-auc:0.613099
# [45]	validation_0-auc:0.998435	validation_1-auc:0.614625
# [46]	validation_0-auc:0.998486	validation_1-auc:0.611962
# [47]	validation_0-auc:0.998527	validation_1-auc:0.613107
# [48]	validation_0-auc:0.998546	validation_1-auc:0.61315
# [49]	validation_0-auc:0.998571	validation_1-auc:0.613546
# [50]	validation_0-auc:0.998603	validation_1-auc:0.614612
# [51]	validation_0-auc:0.998625	validation_1-auc:0.615195
# [52]	validation_0-auc:0.998664	validation_1-auc:0.613075
# [53]	validation_0-auc:0.998675	validation_1-auc:0.613103
# [54]	validation_0-auc:0.998704	validation_1-auc:0.613813
# [55]	validation_0-auc:0.998727	validation_1-auc:0.61434
# [56]	validation_0-auc:0.998763	validation_1-auc:0.614445
# [57]	validation_0-auc:0.998797	validation_1-auc:0.612917
# [58]	validation_0-auc:0.998836	validation_1-auc:0.612608
# [59]	validation_0-auc:0.998867	validation_1-auc:0.612059
# [60]	validation_0-auc:0.998889	validation_1-auc:0.611781
# [61]	validation_0-auc:0.998923	validation_1-auc:0.609801
# [62]	validation_0-auc:0.998977	validation_1-auc:0.608882
# [63]	validation_0-auc:0.999001	validation_1-auc:0.608272
# [64]	validation_0-auc:0.999025	validation_1-auc:0.607921
# [65]	validation_0-auc:0.999057	validation_1-auc:0.606763
# [66]	validation_0-auc:0.99909	validation_1-auc:0.60498
# [67]	validation_0-auc:0.99912	validation_1-auc:0.60564
# [68]	validation_0-auc:0.999147	validation_1-auc:0.605347
# [69]	validation_0-auc:0.999175	validation_1-auc:0.605865
# [70]	validation_0-auc:0.999203	validation_1-auc:0.604773
# [71]	validation_0-auc:0.999231	validation_1-auc:0.60488
# Stopping. Best iteration:
# [41]	validation_0-auc:0.998271	validation_1-auc:0.617711
#
# [0]	validation_0-auc:0.988599	validation_1-auc:0.484247
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.98859	validation_1-auc:0.484541
# [2]	validation_0-auc:0.99421	validation_1-auc:0.48493
# [3]	validation_0-auc:0.994986	validation_1-auc:0.487352
# [4]	validation_0-auc:0.994983	validation_1-auc:0.484676
# [5]	validation_0-auc:0.99501	validation_1-auc:0.477463
# [6]	validation_0-auc:0.995079	validation_1-auc:0.477332
# [7]	validation_0-auc:0.995044	validation_1-auc:0.499166
# [8]	validation_0-auc:0.996237	validation_1-auc:0.494129
# [9]	validation_0-auc:0.997054	validation_1-auc:0.494282
# [10]	validation_0-auc:0.997191	validation_1-auc:0.466385
# [11]	validation_0-auc:0.997809	validation_1-auc:0.46181
# [12]	validation_0-auc:0.998086	validation_1-auc:0.457752
# [13]	validation_0-auc:0.998071	validation_1-auc:0.456705
# [14]	validation_0-auc:0.998077	validation_1-auc:0.456632
# [15]	validation_0-auc:0.998097	validation_1-auc:0.456032
# [16]	validation_0-auc:0.998229	validation_1-auc:0.456918
# [17]	validation_0-auc:0.99831	validation_1-auc:0.46025
# [18]	validation_0-auc:0.998714	validation_1-auc:0.484527
# [19]	validation_0-auc:0.99871	validation_1-auc:0.489253
# [20]	validation_0-auc:0.998865	validation_1-auc:0.496693
# [21]	validation_0-auc:0.998912	validation_1-auc:0.50338
# [22]	validation_0-auc:0.999041	validation_1-auc:0.492398
# [23]	validation_0-auc:0.999017	validation_1-auc:0.489234
# [24]	validation_0-auc:0.99901	validation_1-auc:0.490355
# [25]	validation_0-auc:0.999004	validation_1-auc:0.486873
# [26]	validation_0-auc:0.999164	validation_1-auc:0.488245
# [27]	validation_0-auc:0.999318	validation_1-auc:0.487128
# [28]	validation_0-auc:0.999372	validation_1-auc:0.489013
# [29]	validation_0-auc:0.999383	validation_1-auc:0.490864
# [30]	validation_0-auc:0.999423	validation_1-auc:0.490355
# [31]	validation_0-auc:0.999478	validation_1-auc:0.488651
# [32]	validation_0-auc:0.999465	validation_1-auc:0.492653
# [33]	validation_0-auc:0.999523	validation_1-auc:0.494046
# [34]	validation_0-auc:0.999566	validation_1-auc:0.495356
# [35]	validation_0-auc:0.999573	validation_1-auc:0.495307
# [36]	validation_0-auc:0.999584	validation_1-auc:0.495658
# [37]	validation_0-auc:0.999602	validation_1-auc:0.49474
# [38]	validation_0-auc:0.999602	validation_1-auc:0.494589
# [39]	validation_0-auc:0.999621	validation_1-auc:0.493591
# [40]	validation_0-auc:0.999622	validation_1-auc:0.494296
# [41]	validation_0-auc:0.999649	validation_1-auc:0.492611
# [42]	validation_0-auc:0.999673	validation_1-auc:0.490795
# [43]	validation_0-auc:0.999684	validation_1-auc:0.489931
# [44]	validation_0-auc:0.999685	validation_1-auc:0.487876
# [45]	validation_0-auc:0.999691	validation_1-auc:0.485433
# [46]	validation_0-auc:0.999726	validation_1-auc:0.486221
# [47]	validation_0-auc:0.99974	validation_1-auc:0.485123
# [48]	validation_0-auc:0.999751	validation_1-auc:0.483564
# [49]	validation_0-auc:0.999765	validation_1-auc:0.487541
# [50]	validation_0-auc:0.999785	validation_1-auc:0.487898
# [51]	validation_0-auc:0.999794	validation_1-auc:0.487921
# Stopping. Best iteration:
# [21]	validation_0-auc:0.998912	validation_1-auc:0.50338
# [0]	validation_0-auc:0.972531	validation_1-auc:0.620558
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.982786	validation_1-auc:0.621378
# [2]	validation_0-auc:0.986875	validation_1-auc:0.625773
# [3]	validation_0-auc:0.990654	validation_1-auc:0.62461
# [4]	validation_0-auc:0.991578	validation_1-auc:0.618047
# [5]	validation_0-auc:0.992767	validation_1-auc:0.62573
# [6]	validation_0-auc:0.992692	validation_1-auc:0.628204
# [7]	validation_0-auc:0.993813	validation_1-auc:0.618246
# [8]	validation_0-auc:0.993845	validation_1-auc:0.618453
# [9]	validation_0-auc:0.994119	validation_1-auc:0.620435
# [10]	validation_0-auc:0.994661	validation_1-auc:0.619146
# [11]	validation_0-auc:0.994521	validation_1-auc:0.620784
# [12]	validation_0-auc:0.994785	validation_1-auc:0.619881
# [13]	validation_0-auc:0.9949	validation_1-auc:0.615054
# [14]	validation_0-auc:0.995034	validation_1-auc:0.613092
# [15]	validation_0-auc:0.995089	validation_1-auc:0.610009
# [16]	validation_0-auc:0.995171	validation_1-auc:0.621644
# [17]	validation_0-auc:0.995174	validation_1-auc:0.618266
# [18]	validation_0-auc:0.995184	validation_1-auc:0.615554
# [19]	validation_0-auc:0.995347	validation_1-auc:0.612965
# [20]	validation_0-auc:0.995431	validation_1-auc:0.614056
# [21]	validation_0-auc:0.995528	validation_1-auc:0.615956
# [22]	validation_0-auc:0.995579	validation_1-auc:0.611768
# [23]	validation_0-auc:0.995505	validation_1-auc:0.611445
# [24]	validation_0-auc:0.995577	validation_1-auc:0.60867
# [25]	validation_0-auc:0.99575	validation_1-auc:0.612113
# [26]	validation_0-auc:0.996272	validation_1-auc:0.608665
# [27]	validation_0-auc:0.996463	validation_1-auc:0.607927
# [28]	validation_0-auc:0.996587	validation_1-auc:0.603649
# [29]	validation_0-auc:0.996704	validation_1-auc:0.604177
# [30]	validation_0-auc:0.996769	validation_1-auc:0.603595
# [31]	validation_0-auc:0.996872	validation_1-auc:0.601821
# [32]	validation_0-auc:0.996976	validation_1-auc:0.600945
# [33]	validation_0-auc:0.997056	validation_1-auc:0.600343
# [34]	validation_0-auc:0.997083	validation_1-auc:0.599318
# [35]	validation_0-auc:0.997131	validation_1-auc:0.59899
# [36]	validation_0-auc:0.997214	validation_1-auc:0.598986
# Stopping. Best iteration:
# [6]	validation_0-auc:0.992692	validation_1-auc:0.628204
#
# [0]	validation_0-auc:0.995038	validation_1-auc:0.443981
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.99638	validation_1-auc:0.451031
# [2]	validation_0-auc:0.997147	validation_1-auc:0.439434
# [3]	validation_0-auc:0.997118	validation_1-auc:0.445314
# [4]	validation_0-auc:0.997478	validation_1-auc:0.446133
# [5]	validation_0-auc:0.997635	validation_1-auc:0.461515
# [6]	validation_0-auc:0.997762	validation_1-auc:0.459372
# [7]	validation_0-auc:0.997946	validation_1-auc:0.465745
# [8]	validation_0-auc:0.998277	validation_1-auc:0.46453
# [9]	validation_0-auc:0.998582	validation_1-auc:0.457524
# [10]	validation_0-auc:0.998617	validation_1-auc:0.458659
# [11]	validation_0-auc:0.998711	validation_1-auc:0.455886
# [12]	validation_0-auc:0.998753	validation_1-auc:0.452124
# [13]	validation_0-auc:0.998787	validation_1-auc:0.448233
# [14]	validation_0-auc:0.99881	validation_1-auc:0.450245
# [15]	validation_0-auc:0.998812	validation_1-auc:0.447989
# [16]	validation_0-auc:0.998851	validation_1-auc:0.450034
# [17]	validation_0-auc:0.998885	validation_1-auc:0.447733
# [18]	validation_0-auc:0.998891	validation_1-auc:0.446146
# [19]	validation_0-auc:0.998914	validation_1-auc:0.454958
# [20]	validation_0-auc:0.998913	validation_1-auc:0.451864
# [21]	validation_0-auc:0.999146	validation_1-auc:0.481782
# [22]	validation_0-auc:0.999171	validation_1-auc:0.484953
# [23]	validation_0-auc:0.999193	validation_1-auc:0.486354
# [24]	validation_0-auc:0.999255	validation_1-auc:0.494786
# [25]	validation_0-auc:0.999347	validation_1-auc:0.498969
# [26]	validation_0-auc:0.999378	validation_1-auc:0.500215
# [27]	validation_0-auc:0.999394	validation_1-auc:0.498201
# [28]	validation_0-auc:0.999448	validation_1-auc:0.513522
# [29]	validation_0-auc:0.999471	validation_1-auc:0.49887
# [30]	validation_0-auc:0.999496	validation_1-auc:0.49853
# [31]	validation_0-auc:0.999498	validation_1-auc:0.49753
# [32]	validation_0-auc:0.999518	validation_1-auc:0.493616
# [33]	validation_0-auc:0.999542	validation_1-auc:0.498241
# [34]	validation_0-auc:0.999552	validation_1-auc:0.498296
# [35]	validation_0-auc:0.999556	validation_1-auc:0.497409
# [36]	validation_0-auc:0.999583	validation_1-auc:0.501208
# [37]	validation_0-auc:0.999598	validation_1-auc:0.497981
# [38]	validation_0-auc:0.9996	validation_1-auc:0.498077
# [39]	validation_0-auc:0.999624	validation_1-auc:0.496247
# [40]	validation_0-auc:0.999641	validation_1-auc:0.494379
# [41]	validation_0-auc:0.999657	validation_1-auc:0.499171
# [42]	validation_0-auc:0.99968	validation_1-auc:0.49487
# [43]	validation_0-auc:0.99969	validation_1-auc:0.494223
# [44]	validation_0-auc:0.999703	validation_1-auc:0.497804
# [45]	validation_0-auc:0.999716	validation_1-auc:0.496924
# [46]	validation_0-auc:0.99973	validation_1-auc:0.495797
# [47]	validation_0-auc:0.999737	validation_1-auc:0.495187
# [48]	validation_0-auc:0.999758	validation_1-auc:0.501351
# [49]	validation_0-auc:0.999768	validation_1-auc:0.498194
# [50]	validation_0-auc:0.999773	validation_1-auc:0.496571
# [51]	validation_0-auc:0.999779	validation_1-auc:0.494229
# [52]	validation_0-auc:0.999794	validation_1-auc:0.492781
# [53]	validation_0-auc:0.999802	validation_1-auc:0.492634
# [54]	validation_0-auc:0.999805	validation_1-auc:0.490154
# [55]	validation_0-auc:0.999816	validation_1-auc:0.490807
# [56]	validation_0-auc:0.999825	validation_1-auc:0.492332
# [57]	validation_0-auc:0.999833	validation_1-auc:0.491073
# [58]	validation_0-auc:0.999838	validation_1-auc:0.490449
# Stopping. Best iteration:
# [28]	validation_0-auc:0.999448	validation_1-auc:0.513522
#
# [0]	validation_0-auc:0.95793	validation_1-auc:0.63527
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.961147	validation_1-auc:0.605798
# [2]	validation_0-auc:0.96221	validation_1-auc:0.603617
# [3]	validation_0-auc:0.973719	validation_1-auc:0.595289
# [4]	validation_0-auc:0.977067	validation_1-auc:0.588114
# [5]	validation_0-auc:0.978851	validation_1-auc:0.581692
# [6]	validation_0-auc:0.979727	validation_1-auc:0.584819
# [7]	validation_0-auc:0.98747	validation_1-auc:0.595015
# [8]	validation_0-auc:0.989277	validation_1-auc:0.579149
# [9]	validation_0-auc:0.991049	validation_1-auc:0.618846
# [10]	validation_0-auc:0.991694	validation_1-auc:0.602572
# [11]	validation_0-auc:0.992454	validation_1-auc:0.613753
# [12]	validation_0-auc:0.993198	validation_1-auc:0.615614
# [13]	validation_0-auc:0.993641	validation_1-auc:0.622278
# [14]	validation_0-auc:0.993937	validation_1-auc:0.622815
# [15]	validation_0-auc:0.994206	validation_1-auc:0.623922
# [16]	validation_0-auc:0.995046	validation_1-auc:0.624606
# [17]	validation_0-auc:0.995397	validation_1-auc:0.629811
# [18]	validation_0-auc:0.995555	validation_1-auc:0.62774
# [19]	validation_0-auc:0.995795	validation_1-auc:0.626969
# [20]	validation_0-auc:0.995912	validation_1-auc:0.623822
# [21]	validation_0-auc:0.996226	validation_1-auc:0.624113
# [22]	validation_0-auc:0.996399	validation_1-auc:0.624989
# [23]	validation_0-auc:0.996778	validation_1-auc:0.624962
# [24]	validation_0-auc:0.996841	validation_1-auc:0.626318
# [25]	validation_0-auc:0.996918	validation_1-auc:0.627533
# [26]	validation_0-auc:0.997141	validation_1-auc:0.627761
# [27]	validation_0-auc:0.997239	validation_1-auc:0.627561
# [28]	validation_0-auc:0.997315	validation_1-auc:0.626364
# [29]	validation_0-auc:0.99747	validation_1-auc:0.630491
# [30]	validation_0-auc:0.997526	validation_1-auc:0.631021
# Stopping. Best iteration:
# [0]	validation_0-auc:0.95793	validation_1-auc:0.63527
#
# [0]	validation_0-auc:0.951116	validation_1-auc:0.518299
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.965564	validation_1-auc:0.519353
# [2]	validation_0-auc:0.966867	validation_1-auc:0.529972
# [3]	validation_0-auc:0.967045	validation_1-auc:0.523562
# [4]	validation_0-auc:0.967071	validation_1-auc:0.550073
# [5]	validation_0-auc:0.990074	validation_1-auc:0.543575
# [6]	validation_0-auc:0.994043	validation_1-auc:0.537544
# [7]	validation_0-auc:0.994968	validation_1-auc:0.535717
# [8]	validation_0-auc:0.994856	validation_1-auc:0.528528
# [9]	validation_0-auc:0.996759	validation_1-auc:0.542249
# [10]	validation_0-auc:0.997877	validation_1-auc:0.55093
# [11]	validation_0-auc:0.998645	validation_1-auc:0.548495
# [12]	validation_0-auc:0.998909	validation_1-auc:0.554991
# [13]	validation_0-auc:0.999057	validation_1-auc:0.551818
# [14]	validation_0-auc:0.999089	validation_1-auc:0.546638
# [15]	validation_0-auc:0.999125	validation_1-auc:0.543762
# [16]	validation_0-auc:0.999233	validation_1-auc:0.527419
# [17]	validation_0-auc:0.999265	validation_1-auc:0.529815
# [18]	validation_0-auc:0.99927	validation_1-auc:0.527191
# [19]	validation_0-auc:0.999275	validation_1-auc:0.526271
# [20]	validation_0-auc:0.999285	validation_1-auc:0.533841
# [21]	validation_0-auc:0.999295	validation_1-auc:0.5353
# [22]	validation_0-auc:0.999321	validation_1-auc:0.537564
# [23]	validation_0-auc:0.999336	validation_1-auc:0.539904
# [24]	validation_0-auc:0.999352	validation_1-auc:0.537232
# [25]	validation_0-auc:0.999358	validation_1-auc:0.534209
# [26]	validation_0-auc:0.999362	validation_1-auc:0.529037
# [27]	validation_0-auc:0.999484	validation_1-auc:0.537846
# [28]	validation_0-auc:0.999492	validation_1-auc:0.541761
# [29]	validation_0-auc:0.999498	validation_1-auc:0.542311
# [30]	validation_0-auc:0.999492	validation_1-auc:0.539911
# [31]	validation_0-auc:0.999486	validation_1-auc:0.541166
# [32]	validation_0-auc:0.999549	validation_1-auc:0.537725
# [33]	validation_0-auc:0.999586	validation_1-auc:0.535581
# [34]	validation_0-auc:0.999623	validation_1-auc:0.535247
# [35]	validation_0-auc:0.999658	validation_1-auc:0.534549
# [36]	validation_0-auc:0.999689	validation_1-auc:0.53427
# [37]	validation_0-auc:0.999691	validation_1-auc:0.534034
# [38]	validation_0-auc:0.999714	validation_1-auc:0.539081
# [39]	validation_0-auc:0.999731	validation_1-auc:0.539555
# [40]	validation_0-auc:0.999761	validation_1-auc:0.541076
# [41]	validation_0-auc:0.99976	validation_1-auc:0.538074
# [42]	validation_0-auc:0.999779	validation_1-auc:0.536907
# Stopping. Best iteration:
# [12]	validation_0-auc:0.998909	validation_1-auc:0.554991
#
# [0]	validation_0-auc:0.974381	validation_1-auc:0.604272
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.97868	validation_1-auc:0.606917
# [2]	validation_0-auc:0.980517	validation_1-auc:0.580983
# [3]	validation_0-auc:0.982335	validation_1-auc:0.575816
# [4]	validation_0-auc:0.986617	validation_1-auc:0.605011
# [5]	validation_0-auc:0.9871	validation_1-auc:0.597708
# [6]	validation_0-auc:0.988972	validation_1-auc:0.594228
# [7]	validation_0-auc:0.988805	validation_1-auc:0.600378
# [8]	validation_0-auc:0.990668	validation_1-auc:0.599891
# [9]	validation_0-auc:0.990921	validation_1-auc:0.594445
# [10]	validation_0-auc:0.99242	validation_1-auc:0.594546
# [11]	validation_0-auc:0.993071	validation_1-auc:0.596307
# [12]	validation_0-auc:0.993919	validation_1-auc:0.597778
# [13]	validation_0-auc:0.99455	validation_1-auc:0.597658
# [14]	validation_0-auc:0.995144	validation_1-auc:0.594815
# [15]	validation_0-auc:0.995483	validation_1-auc:0.593854
# [16]	validation_0-auc:0.995666	validation_1-auc:0.59771
# [17]	validation_0-auc:0.995997	validation_1-auc:0.596604
# [18]	validation_0-auc:0.996332	validation_1-auc:0.60351
# [19]	validation_0-auc:0.996383	validation_1-auc:0.601377
# [20]	validation_0-auc:0.996432	validation_1-auc:0.599015
# [21]	validation_0-auc:0.996671	validation_1-auc:0.600177
# [22]	validation_0-auc:0.996772	validation_1-auc:0.601539
# [23]	validation_0-auc:0.99679	validation_1-auc:0.601005
# [24]	validation_0-auc:0.99684	validation_1-auc:0.600998
# [25]	validation_0-auc:0.996957	validation_1-auc:0.603183
# [26]	validation_0-auc:0.996994	validation_1-auc:0.606535
# [27]	validation_0-auc:0.997103	validation_1-auc:0.60581
# [28]	validation_0-auc:0.997139	validation_1-auc:0.605121
# [29]	validation_0-auc:0.997152	validation_1-auc:0.604455
# [30]	validation_0-auc:0.997152	validation_1-auc:0.603082
# [31]	validation_0-auc:0.997281	validation_1-auc:0.601471
# Stopping. Best iteration:
# [1]	validation_0-auc:0.97868	validation_1-auc:0.606917
#
# [0]	validation_0-auc:0.991699	validation_1-auc:0.555968
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.993807	validation_1-auc:0.541283
# [2]	validation_0-auc:0.991506	validation_1-auc:0.528023
# [3]	validation_0-auc:0.994973	validation_1-auc:0.539603
# [4]	validation_0-auc:0.996712	validation_1-auc:0.546227
# [5]	validation_0-auc:0.996485	validation_1-auc:0.543282
# [6]	validation_0-auc:0.996738	validation_1-auc:0.546361
# [7]	validation_0-auc:0.997299	validation_1-auc:0.541153
# [8]	validation_0-auc:0.997523	validation_1-auc:0.540411
# [9]	validation_0-auc:0.997816	validation_1-auc:0.530546
# [10]	validation_0-auc:0.998438	validation_1-auc:0.533065
# [11]	validation_0-auc:0.998527	validation_1-auc:0.521063
# [12]	validation_0-auc:0.998598	validation_1-auc:0.508608
# [13]	validation_0-auc:0.998625	validation_1-auc:0.506784
# [14]	validation_0-auc:0.998611	validation_1-auc:0.509846
# [15]	validation_0-auc:0.998537	validation_1-auc:0.496201
# [16]	validation_0-auc:0.998553	validation_1-auc:0.494363
# [17]	validation_0-auc:0.998817	validation_1-auc:0.493946
# [18]	validation_0-auc:0.998886	validation_1-auc:0.490678
# [19]	validation_0-auc:0.998924	validation_1-auc:0.491981
# [20]	validation_0-auc:0.998978	validation_1-auc:0.488755
# [21]	validation_0-auc:0.999003	validation_1-auc:0.487709
# [22]	validation_0-auc:0.999026	validation_1-auc:0.488643
# [23]	validation_0-auc:0.999064	validation_1-auc:0.485932
# [24]	validation_0-auc:0.999115	validation_1-auc:0.484856
# [25]	validation_0-auc:0.999115	validation_1-auc:0.488796
# [26]	validation_0-auc:0.999238	validation_1-auc:0.485797
# [27]	validation_0-auc:0.99924	validation_1-auc:0.484798
# [28]	validation_0-auc:0.999313	validation_1-auc:0.486266
# [29]	validation_0-auc:0.999354	validation_1-auc:0.487098
# [30]	validation_0-auc:0.999373	validation_1-auc:0.482959
# Stopping. Best iteration:
# [0]	validation_0-auc:0.991699	validation_1-auc:0.555968
#
# [0]	validation_0-auc:0.970426	validation_1-auc:0.628811
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.979294	validation_1-auc:0.626224
# [2]	validation_0-auc:0.978942	validation_1-auc:0.625052
# [3]	validation_0-auc:0.979958	validation_1-auc:0.625319
# [4]	validation_0-auc:0.981975	validation_1-auc:0.626335
# [5]	validation_0-auc:0.981424	validation_1-auc:0.627054
# [6]	validation_0-auc:0.982091	validation_1-auc:0.627958
# [7]	validation_0-auc:0.981763	validation_1-auc:0.633943
# [8]	validation_0-auc:0.981466	validation_1-auc:0.620773
# [9]	validation_0-auc:0.986615	validation_1-auc:0.621832
# [10]	validation_0-auc:0.9891	validation_1-auc:0.619894
# [11]	validation_0-auc:0.98994	validation_1-auc:0.620696
# [12]	validation_0-auc:0.990251	validation_1-auc:0.620094
# [13]	validation_0-auc:0.990733	validation_1-auc:0.620511
# [14]	validation_0-auc:0.992704	validation_1-auc:0.618463
# [15]	validation_0-auc:0.994354	validation_1-auc:0.620527
# [16]	validation_0-auc:0.994539	validation_1-auc:0.620179
# [17]	validation_0-auc:0.995282	validation_1-auc:0.62037
# [18]	validation_0-auc:0.995512	validation_1-auc:0.621209
# [19]	validation_0-auc:0.996053	validation_1-auc:0.616028
# [20]	validation_0-auc:0.996812	validation_1-auc:0.621771
# [21]	validation_0-auc:0.997027	validation_1-auc:0.618653
# [22]	validation_0-auc:0.997098	validation_1-auc:0.61796
# [23]	validation_0-auc:0.997199	validation_1-auc:0.623525
# [24]	validation_0-auc:0.99737	validation_1-auc:0.623066
# [25]	validation_0-auc:0.997522	validation_1-auc:0.623685
# [26]	validation_0-auc:0.997587	validation_1-auc:0.624635
# [27]	validation_0-auc:0.997585	validation_1-auc:0.624245
# [28]	validation_0-auc:0.997665	validation_1-auc:0.625388
# [29]	validation_0-auc:0.997709	validation_1-auc:0.623851
# [30]	validation_0-auc:0.997735	validation_1-auc:0.627307
# [31]	validation_0-auc:0.997759	validation_1-auc:0.628551
# [32]	validation_0-auc:0.997781	validation_1-auc:0.626348
# [33]	validation_0-auc:0.997869	validation_1-auc:0.626535
# [34]	validation_0-auc:0.997908	validation_1-auc:0.624459
# [35]	validation_0-auc:0.997947	validation_1-auc:0.626358
# [36]	validation_0-auc:0.998008	validation_1-auc:0.626047
# [37]	validation_0-auc:0.998094	validation_1-auc:0.625792
# Stopping. Best iteration:
# [7]	validation_0-auc:0.981763	validation_1-auc:0.633943
#
# [0]	validation_0-auc:0.997069	validation_1-auc:0.519082
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.997348	validation_1-auc:0.519907
# [2]	validation_0-auc:0.998219	validation_1-auc:0.495169
# [3]	validation_0-auc:0.998379	validation_1-auc:0.520637
# [4]	validation_0-auc:0.998669	validation_1-auc:0.522577
# [5]	validation_0-auc:0.998979	validation_1-auc:0.512809
# [6]	validation_0-auc:0.999046	validation_1-auc:0.513597
# [7]	validation_0-auc:0.99907	validation_1-auc:0.513732
# [8]	validation_0-auc:0.999092	validation_1-auc:0.511713
# [9]	validation_0-auc:0.999128	validation_1-auc:0.498224
# [10]	validation_0-auc:0.999123	validation_1-auc:0.498667
# [11]	validation_0-auc:0.999118	validation_1-auc:0.495824
# [12]	validation_0-auc:0.99912	validation_1-auc:0.492854
# [13]	validation_0-auc:0.999168	validation_1-auc:0.49258
# [14]	validation_0-auc:0.999162	validation_1-auc:0.492915
# [15]	validation_0-auc:0.99917	validation_1-auc:0.496766
# [16]	validation_0-auc:0.999166	validation_1-auc:0.496439
# [17]	validation_0-auc:0.999205	validation_1-auc:0.494846
# [18]	validation_0-auc:0.99935	validation_1-auc:0.498359
# [19]	validation_0-auc:0.999364	validation_1-auc:0.494646
# [20]	validation_0-auc:0.999392	validation_1-auc:0.501228
# [21]	validation_0-auc:0.999411	validation_1-auc:0.49877
# [22]	validation_0-auc:0.99943	validation_1-auc:0.497529
# [23]	validation_0-auc:0.999425	validation_1-auc:0.497877
# [24]	validation_0-auc:0.999445	validation_1-auc:0.498589
# [25]	validation_0-auc:0.999451	validation_1-auc:0.500134
# [26]	validation_0-auc:0.999533	validation_1-auc:0.500034
# [27]	validation_0-auc:0.999566	validation_1-auc:0.503041
# [28]	validation_0-auc:0.999613	validation_1-auc:0.500439
# [29]	validation_0-auc:0.999617	validation_1-auc:0.49868
# [30]	validation_0-auc:0.999647	validation_1-auc:0.503415
# [31]	validation_0-auc:0.999682	validation_1-auc:0.505583
# [32]	validation_0-auc:0.999711	validation_1-auc:0.502877
# [33]	validation_0-auc:0.999737	validation_1-auc:0.503641
# [34]	validation_0-auc:0.999726	validation_1-auc:0.504522
# Stopping. Best iteration:
# [4]	validation_0-auc:0.998669	validation_1-auc:0.522577
#
# [0]	validation_0-auc:0.967612	validation_1-auc:0.623117
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.969454	validation_1-auc:0.640523
# [2]	validation_0-auc:0.981519	validation_1-auc:0.624077
# [3]	validation_0-auc:0.980139	validation_1-auc:0.630571
# [4]	validation_0-auc:0.984375	validation_1-auc:0.628016
# [5]	validation_0-auc:0.988818	validation_1-auc:0.625551
# [6]	validation_0-auc:0.989641	validation_1-auc:0.624007
# [7]	validation_0-auc:0.99097	validation_1-auc:0.619383
# [8]	validation_0-auc:0.991188	validation_1-auc:0.611583
# [9]	validation_0-auc:0.992322	validation_1-auc:0.609396
# [10]	validation_0-auc:0.992041	validation_1-auc:0.602325
# [11]	validation_0-auc:0.992704	validation_1-auc:0.599287
# [12]	validation_0-auc:0.993265	validation_1-auc:0.606177
# [13]	validation_0-auc:0.993383	validation_1-auc:0.607619
# [14]	validation_0-auc:0.993974	validation_1-auc:0.604972
# [15]	validation_0-auc:0.994411	validation_1-auc:0.60193
# [16]	validation_0-auc:0.994582	validation_1-auc:0.60156
# [17]	validation_0-auc:0.994874	validation_1-auc:0.603791
# [18]	validation_0-auc:0.995156	validation_1-auc:0.602275
# [19]	validation_0-auc:0.995272	validation_1-auc:0.607075
# [20]	validation_0-auc:0.995387	validation_1-auc:0.607305
# [21]	validation_0-auc:0.995578	validation_1-auc:0.607899
# [22]	validation_0-auc:0.995789	validation_1-auc:0.605326
# [23]	validation_0-auc:0.995937	validation_1-auc:0.608102
# [24]	validation_0-auc:0.996347	validation_1-auc:0.607985
# [25]	validation_0-auc:0.996569	validation_1-auc:0.606554
# [26]	validation_0-auc:0.996721	validation_1-auc:0.609209
# [27]	validation_0-auc:0.996768	validation_1-auc:0.609974
# [28]	validation_0-auc:0.997024	validation_1-auc:0.608805
# [29]	validation_0-auc:0.997128	validation_1-auc:0.608526
# [30]	validation_0-auc:0.997201	validation_1-auc:0.608681
# [31]	validation_0-auc:0.997246	validation_1-auc:0.609146
# Stopping. Best iteration:
# [1]	validation_0-auc:0.969454	validation_1-auc:0.640523

# %%
# confusion matrix for validation set
avg_pred_probs_contol = np.zeros(shape=(X_valid_control.shape[0],2))
#avg_pred_probs_contol = np.zeros(shape=(X_valid_control_upsamp.shape[0],2))
avg_pred_probs_exper = np.zeros(shape=(X_valid_exper.shape[0],2))
#avg_pred_probs_exper = np.zeros(shape=(X_valid_exper_upsamp.shape[0],2))
for i in range(10): #########################################
    model_control_name = "model_control_" + str(i+1) +'.pickle.dat'
    model_control = pickle.load(open(model_control_name, "rb"))
    pred_probs_contol = model_control.predict_proba(X_valid_control, ntree_limit=model_control.best_ntree_limit)
    avg_pred_probs_contol += pred_probs_contol

    model_exper_name = "model_exper_" + str(i+1) +'.pickle.dat'
    model_exper = pickle.load(open(model_exper_name, "rb"))
    pred_probs_exper = model_exper.predict_proba(X_valid_exper, ntree_limit=model_exper.best_ntree_limit)
    avg_pred_probs_exper += pred_probs_exper

# get average soft predictions for both control and experimental model
avg_pred_probs_contol /= 10.0 #########################################
avg_pred_probs_exper /= 10.0 #########################################

control_valid_pred = []
for pred in avg_pred_probs_contol:
    if pred[1] > pred[0]:
        control_valid_pred.append(1.0)
    else:
        control_valid_pred.append(0.0)
        
exper_valid_pred = []
for pred in avg_pred_probs_exper:
    if pred[1] > pred[0]:
        exper_valid_pred.append(1.0)
    else:
        exper_valid_pred.append(0.0)
        
control_valid_pred = np.array(control_valid_pred)
exper_valid_pred = np.array(exper_valid_pred)

# %%
# true negatives, false positives
# false negatives, true positives
cm = sk.metrics.confusion_matrix
cm(Y_valid_control, control_valid_pred)
# Out:
# array([[8407,    0],
#        [  67,    0]], dtype=int64)

# %%
# true negatives, false positives
# false negatives, true positives
cm = sk.metrics.confusion_matrix
cm(Y_valid_exper, exper_valid_pred)
# Out:
# array([[8292,    0],
#        [ 141,    0]], dtype=int64)

# %%
def promotion_strategy(df):
    '''
    INPUT 
    df - a dataframe with *only* the columns V1 - V7 (same as train_data)

    OUTPUT
    promotion_df - np.array with the values
                   'Yes' or 'No' related to whether or not an 
                   individual should recieve a promotion 
                   should be the length of df.shape[0]            
    Ex:
    INPUT: df
    
    V1	V2	  V3	V4	V5	V6	V7
    2	30	-1.1	1	1	3	2
    3	32	-0.6	2	3	2	2
    2	30	0.13	1	1	4	2
    
    OUTPUT: promotion
    
    array(['Yes', 'Yes', 'No'])
    indicating the first two users would recieve the promotion and 
    the last should not.
    '''

    test = df
    
    avg_pred_probs_contol = np.zeros(shape=(test.shape[0],2))
    avg_pred_probs_exper = np.zeros(shape=(test.shape[0],2))
    for i in range(10): #########################################
        model_control_name = "model_control_" + str(i+1) +'.pickle.dat'
        model_control = pickle.load(open(model_control_name, "rb"))
        pred_probs_contol = model_control.predict_proba(test, ntree_limit=model_control.best_ntree_limit)
        avg_pred_probs_contol += pred_probs_contol

        model_exper_name = "model_exper_" + str(i+1) +'.pickle.dat'
        model_exper = pickle.load(open(model_exper_name, "rb"))
        pred_probs_exper = model_exper.predict_proba(test, ntree_limit=model_exper.best_ntree_limit)
        avg_pred_probs_exper += pred_probs_exper

    # get average soft predictions for both control and experimental model
    avg_pred_probs_contol /= 10.0 #########################################
    avg_pred_probs_exper /= 10.0 #########################################

    # get difference in probabilities between experimental and cpntrol model for purchase = 1 label
    diff_avg_pred_probs = avg_pred_probs_exper[:,1] - avg_pred_probs_contol[:,1]
    
    promotion = []
    
    # Only send promotions to top 1 percentile of probabilities
    cutoff_percentile = np.percentile(diff_avg_pred_probs, 90)
    
    for prob in diff_avg_pred_probs:
        if prob > 0:
            if prob > cutoff_percentile:
                promotion.append('Yes')
        else:
            promotion.append('No')

    promotion = np.array(promotion)
    
    return promotion

# %%
# This will test your results, and provide you back some information 
# on how well your promotion_strategy will work in practice

test_results(promotion_strategy)
# Out:
# Nice job!  See how well your strategy worked on our test data below!
#
# Your irr with this strategy is 0.0092.
#
# Your nir with this strategy is -121.70.
# We came up with a model with an irr of 0.0188 and an nir of 189.45 on the test set.
#
#  How did you do?
# (0.009170385626590753, -121.69999999999999)

# %%
#learning_rate = 0.1, max_depth = 7, min_child_weight = 3, objective = 'binary:logistic', seed = 42, gamma = 1, silent = True
#95%, irr=0.0188, nlr: 31.94
