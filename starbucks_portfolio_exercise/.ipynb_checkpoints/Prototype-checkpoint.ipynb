# %%
# load in packages
from itertools import combinations

from test_results import test_results, score
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk
import xgboost as xgb
import pickle
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# load in the data
train_data = pd.read_csv('./training.csv')
train_data.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   1        No         0   2  30.443518 -1.165083   1   1   3   2
# 1   3        No         0   3  32.159350 -0.645617   2   3   2   2
# 2   4        No         0   2  30.431659  0.133583   1   1   4   2
# 3   5        No         0   0  26.588914 -0.212728   2   1   4   2
# 4   8       Yes         0   3  28.044332 -0.385883   1   1   2   2

# %%
test_data = pd.read_csv('./Test.csv')
test_data.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   2        No         0   1  41.376390  1.172517   1   1   2   2
# 1   6       Yes         0   1  25.163598  0.653050   2   2   2   2
# 2   7       Yes         0   1  26.553778 -1.597972   2   3   4   2
# 3  10        No         0   2  28.529691 -1.078506   2   3   2   2
# 4  12        No         0   2  32.378538  0.479895   2   2   1   2

# %%
features = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7']

# %%
# up sample purhcase '1' to 8,000 examples

train_data_pur = train_data[train_data['purchase'] == 1]

train_data_pur_new = sk.utils.resample(train_data_pur, replace=True, n_samples=7000)
train_data_pur_new = pd.DataFrame(train_data_pur_new)
train_data_pur_new.head()
# Out:
#            ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 26865   39918       Yes         1   1  24.545281  1.518828   2   1   1   2
# 35024   52104       Yes         1   2  25.391155  1.605406   2   1   2   1
# 62785   93541       Yes         1   1  28.092568  0.393317   2   3   1   2
# 79383  118479       Yes         1   1  32.758640 -1.684550   2   3   1   2
# 20953   31167       Yes         1   2  30.818383  0.133583   2   1   2   1

# %%
train_data_upsam = pd.concat([train_data, train_data_pur_new], ignore_index=True)
train_data_upsam.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   1        No         0   2  30.443518 -1.165083   1   1   3   2
# 1   3        No         0   3  32.159350 -0.645617   2   3   2   2
# 2   4        No         0   2  30.431659  0.133583   1   1   4   2
# 3   5        No         0   0  26.588914 -0.212728   2   1   4   2
# 4   8       Yes         0   3  28.044332 -0.385883   1   1   2   2

# %%
# split into train and valid
# create ensemble for train portion only
train, valid = sk.model_selection.train_test_split(train_data_upsam, test_size=0.2,random_state=42)
train_no_pur = train[train['purchase']==0]
train_pur = train[train['purchase']==1]

# %%
# Generate validation set
valid_control = valid[valid['Promotion']=='No']
Y_valid_control = valid_control['purchase']
X_valid_control = valid_control[features]

valid_exper = valid[valid['Promotion']=='Yes']
Y_valid_exper = valid_exper['purchase']
X_valid_exper = valid_exper[features]

# %%
random_seeds = [1, 100, 200, 300, 400, 500, 600, 700, 800, 900]

for i in range(10):
    # Get a subsample of data with no purchases
    train_no_pur_sample = train_no_pur.sample(frac=0.1, replace=True, random_state=random_seeds[i])
    # Join subsample of customers with no purchases with full data for customers with purchases
    train = pd.concat([train_no_pur_sample, train_pur], ignore_index=True)
    train= sk.utils.shuffle(train)
    train_control = train[train['Promotion']=='No']
    train_exper = train[train['Promotion']=='Yes']
    
    Y_train_control = train_control['purchase']
    X_train_control = train_control[features]

    Y_train_exper = train_exper['purchase']
    X_train_exper = train_exper[features]
    
    # model for control group
    model_control_name = "model_control_" + str(i+1) +'.pickle.dat'
    
    eval_set = [(X_train_control, Y_train_control), (X_valid_control, Y_valid_control)]
    model_control = xgb.XGBClassifier(learning_rate = 0.1,\
                                  max_depth = 7,\
                                  min_child_weight = 5,\
                                  objective = 'binary:logistic',\
                                  seed = 42,\
                                  gamma = 1,\
                                  silent = True)
    model_control.fit(X_train_control, Y_train_control, eval_set=eval_set,\
                      eval_metric="auc", verbose=True, early_stopping_rounds=30)
    # save model for control group
    pickle.dump(model_control, open(model_control_name, "wb"))
    
    # for experimental group
    model_exper_name = "model_exper_" + str(i+1) +'.pickle.dat'
    eval_set = [(X_train_exper, Y_train_exper), (X_valid_exper, Y_valid_exper)]
    model_exper = xgb.XGBClassifier(learning_rate = 0.1,\
                                  max_depth = 7,\
                                  min_child_weight = 5,\
                                  objective = 'binary:logistic',\
                                  seed = 42,\
                                  gamma = 1,\
                                  silent = True)
    model_exper.fit(X_train_exper, Y_train_exper, eval_set=eval_set,\
                    eval_metric="auc", verbose=True, early_stopping_rounds=30)
    
    # save model for control group
    pickle.dump(model_exper, open(model_exper_name, "wb"))
# Out:
# [0]	validation_0-auc:0.644776	validation_1-auc:0.627161
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.672676	validation_1-auc:0.645559
# [2]	validation_0-auc:0.683759	validation_1-auc:0.652584
# [3]	validation_0-auc:0.704999	validation_1-auc:0.663601
# [4]	validation_0-auc:0.728263	validation_1-auc:0.683148
# [5]	validation_0-auc:0.74944	validation_1-auc:0.703511
# [6]	validation_0-auc:0.765438	validation_1-auc:0.719348
# [7]	validation_0-auc:0.779421	validation_1-auc:0.734062
# [8]	validation_0-auc:0.820614	validation_1-auc:0.772948
# [9]	validation_0-auc:0.824164	validation_1-auc:0.77668
# [10]	validation_0-auc:0.860689	validation_1-auc:0.808497
# [11]	validation_0-auc:0.865342	validation_1-auc:0.811509
# [12]	validation_0-auc:0.869514	validation_1-auc:0.814713
# [13]	validation_0-auc:0.86987	validation_1-auc:0.8151
# [14]	validation_0-auc:0.876216	validation_1-auc:0.821155
# [15]	validation_0-auc:0.891747	validation_1-auc:0.835303
# [16]	validation_0-auc:0.893443	validation_1-auc:0.837131
# [17]	validation_0-auc:0.897555	validation_1-auc:0.839999
# [18]	validation_0-auc:0.904766	validation_1-auc:0.848113
# [19]	validation_0-auc:0.911291	validation_1-auc:0.853163
# [20]	validation_0-auc:0.918337	validation_1-auc:0.859514
# [21]	validation_0-auc:0.919375	validation_1-auc:0.86049
# [22]	validation_0-auc:0.920243	validation_1-auc:0.861735
# [23]	validation_0-auc:0.921679	validation_1-auc:0.863782
# [24]	validation_0-auc:0.92353	validation_1-auc:0.866051
# [25]	validation_0-auc:0.928934	validation_1-auc:0.873363
# [26]	validation_0-auc:0.930205	validation_1-auc:0.874513
# [27]	validation_0-auc:0.931911	validation_1-auc:0.87673
# [28]	validation_0-auc:0.933299	validation_1-auc:0.877364
# [29]	validation_0-auc:0.939503	validation_1-auc:0.883557
# [30]	validation_0-auc:0.941131	validation_1-auc:0.885805
# [31]	validation_0-auc:0.94137	validation_1-auc:0.886585
# [32]	validation_0-auc:0.94387	validation_1-auc:0.890046
# [33]	validation_0-auc:0.946844	validation_1-auc:0.895703
# [34]	validation_0-auc:0.947583	validation_1-auc:0.896764
# [35]	validation_0-auc:0.949219	validation_1-auc:0.899039
# [36]	validation_0-auc:0.952198	validation_1-auc:0.902139
# [37]	validation_0-auc:0.953268	validation_1-auc:0.903789
# [38]	validation_0-auc:0.954108	validation_1-auc:0.905496
# [39]	validation_0-auc:0.954966	validation_1-auc:0.906608
# [40]	validation_0-auc:0.955776	validation_1-auc:0.907273
# [41]	validation_0-auc:0.957638	validation_1-auc:0.909118
# [42]	validation_0-auc:0.958001	validation_1-auc:0.910036
# [43]	validation_0-auc:0.958429	validation_1-auc:0.910761
# [44]	validation_0-auc:0.958565	validation_1-auc:0.911083
# [45]	validation_0-auc:0.959157	validation_1-auc:0.912059
# [46]	validation_0-auc:0.960704	validation_1-auc:0.913864
# [47]	validation_0-auc:0.961953	validation_1-auc:0.914983
# [48]	validation_0-auc:0.962103	validation_1-auc:0.915412
# [49]	validation_0-auc:0.962541	validation_1-auc:0.915922
# [50]	validation_0-auc:0.962739	validation_1-auc:0.916069
# [51]	validation_0-auc:0.96273	validation_1-auc:0.916195
# [52]	validation_0-auc:0.964074	validation_1-auc:0.917895
# [53]	validation_0-auc:0.964503	validation_1-auc:0.91888
# [54]	validation_0-auc:0.964935	validation_1-auc:0.919599
# [55]	validation_0-auc:0.965093	validation_1-auc:0.920045
# [56]	validation_0-auc:0.965719	validation_1-auc:0.920668
# [57]	validation_0-auc:0.966061	validation_1-auc:0.921152
# [58]	validation_0-auc:0.966109	validation_1-auc:0.921464
# [59]	validation_0-auc:0.966702	validation_1-auc:0.922438
# [60]	validation_0-auc:0.969607	validation_1-auc:0.927702
# [61]	validation_0-auc:0.97004	validation_1-auc:0.92906
# [62]	validation_0-auc:0.971497	validation_1-auc:0.9314
# [63]	validation_0-auc:0.971963	validation_1-auc:0.931634
# [64]	validation_0-auc:0.972177	validation_1-auc:0.932013
# [65]	validation_0-auc:0.972608	validation_1-auc:0.932979
# [66]	validation_0-auc:0.972938	validation_1-auc:0.933717
# [67]	validation_0-auc:0.973105	validation_1-auc:0.933482
# [68]	validation_0-auc:0.973226	validation_1-auc:0.933791
# [69]	validation_0-auc:0.975317	validation_1-auc:0.937001
# [70]	validation_0-auc:0.976012	validation_1-auc:0.937724
# [71]	validation_0-auc:0.97613	validation_1-auc:0.937924
# [72]	validation_0-auc:0.976158	validation_1-auc:0.938018
# [73]	validation_0-auc:0.9768	validation_1-auc:0.938892
# [74]	validation_0-auc:0.97681	validation_1-auc:0.938927
# [75]	validation_0-auc:0.97708	validation_1-auc:0.939401
# [76]	validation_0-auc:0.978671	validation_1-auc:0.94232
# [77]	validation_0-auc:0.978814	validation_1-auc:0.942416
# [78]	validation_0-auc:0.97947	validation_1-auc:0.943182
# [79]	validation_0-auc:0.980799	validation_1-auc:0.945884
# [80]	validation_0-auc:0.980718	validation_1-auc:0.945707
# [81]	validation_0-auc:0.981219	validation_1-auc:0.945753
# [82]	validation_0-auc:0.981545	validation_1-auc:0.946353
# [83]	validation_0-auc:0.98147	validation_1-auc:0.946183
# [84]	validation_0-auc:0.982306	validation_1-auc:0.946798
# [85]	validation_0-auc:0.983015	validation_1-auc:0.947506
# [86]	validation_0-auc:0.983051	validation_1-auc:0.947535
# [87]	validation_0-auc:0.983074	validation_1-auc:0.947557
# [88]	validation_0-auc:0.983512	validation_1-auc:0.948188
# [89]	validation_0-auc:0.983447	validation_1-auc:0.948019
# [90]	validation_0-auc:0.983453	validation_1-auc:0.947988
# [91]	validation_0-auc:0.983613	validation_1-auc:0.948293
# [92]	validation_0-auc:0.983855	validation_1-auc:0.948051
# [93]	validation_0-auc:0.983852	validation_1-auc:0.948006
# [94]	validation_0-auc:0.98437	validation_1-auc:0.949063
# [95]	validation_0-auc:0.984494	validation_1-auc:0.949155
# [96]	validation_0-auc:0.984455	validation_1-auc:0.949076
# [97]	validation_0-auc:0.9845	validation_1-auc:0.949184
# [98]	validation_0-auc:0.984559	validation_1-auc:0.949217
# [99]	validation_0-auc:0.984936	validation_1-auc:0.950089
# [0]	validation_0-auc:0.749153	validation_1-auc:0.721368
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.757789	validation_1-auc:0.72688
# [2]	validation_0-auc:0.759721	validation_1-auc:0.722211
# [3]	validation_0-auc:0.765809	validation_1-auc:0.728905
# [4]	validation_0-auc:0.777056	validation_1-auc:0.742387
# [5]	validation_0-auc:0.783266	validation_1-auc:0.745054
# [6]	validation_0-auc:0.793257	validation_1-auc:0.751786
# [7]	validation_0-auc:0.79981	validation_1-auc:0.756126
# [8]	validation_0-auc:0.802125	validation_1-auc:0.756913
# [9]	validation_0-auc:0.805855	validation_1-auc:0.761537
# [10]	validation_0-auc:0.811349	validation_1-auc:0.765807
# [11]	validation_0-auc:0.813684	validation_1-auc:0.766896
# [12]	validation_0-auc:0.818845	validation_1-auc:0.770309
# [13]	validation_0-auc:0.823406	validation_1-auc:0.773896
# [14]	validation_0-auc:0.825815	validation_1-auc:0.775411
# [15]	validation_0-auc:0.830647	validation_1-auc:0.779808
# [16]	validation_0-auc:0.837315	validation_1-auc:0.78492
# [17]	validation_0-auc:0.840449	validation_1-auc:0.78732
# [18]	validation_0-auc:0.843359	validation_1-auc:0.789057
# [19]	validation_0-auc:0.84565	validation_1-auc:0.790958
# [20]	validation_0-auc:0.848275	validation_1-auc:0.79398
# [21]	validation_0-auc:0.850761	validation_1-auc:0.796713
# [22]	validation_0-auc:0.85357	validation_1-auc:0.798967
# [23]	validation_0-auc:0.855684	validation_1-auc:0.801164
# [24]	validation_0-auc:0.856666	validation_1-auc:0.802224
# [25]	validation_0-auc:0.858562	validation_1-auc:0.803124
# [26]	validation_0-auc:0.863355	validation_1-auc:0.807227
# [27]	validation_0-auc:0.864997	validation_1-auc:0.809083
# [28]	validation_0-auc:0.872831	validation_1-auc:0.81591
# [29]	validation_0-auc:0.875354	validation_1-auc:0.817392
# [30]	validation_0-auc:0.876974	validation_1-auc:0.818448
# [31]	validation_0-auc:0.879769	validation_1-auc:0.82055
# [32]	validation_0-auc:0.880744	validation_1-auc:0.821901
# [33]	validation_0-auc:0.88202	validation_1-auc:0.823267
# [34]	validation_0-auc:0.88322	validation_1-auc:0.824356
# [35]	validation_0-auc:0.885781	validation_1-auc:0.827009
# [36]	validation_0-auc:0.889949	validation_1-auc:0.830976
# [37]	validation_0-auc:0.892099	validation_1-auc:0.834022
# [38]	validation_0-auc:0.893202	validation_1-auc:0.835368
# [39]	validation_0-auc:0.895305	validation_1-auc:0.837526
# [40]	validation_0-auc:0.897431	validation_1-auc:0.8392
# [41]	validation_0-auc:0.897787	validation_1-auc:0.83923
# [42]	validation_0-auc:0.900127	validation_1-auc:0.841726
# [43]	validation_0-auc:0.901081	validation_1-auc:0.842154
# [44]	validation_0-auc:0.902558	validation_1-auc:0.843954
# [45]	validation_0-auc:0.907719	validation_1-auc:0.847924
# [46]	validation_0-auc:0.908398	validation_1-auc:0.848351
# [47]	validation_0-auc:0.909207	validation_1-auc:0.848937
# [48]	validation_0-auc:0.910815	validation_1-auc:0.849736
# [49]	validation_0-auc:0.911993	validation_1-auc:0.851082
# [50]	validation_0-auc:0.912577	validation_1-auc:0.851461
# [51]	validation_0-auc:0.913513	validation_1-auc:0.852318
# [52]	validation_0-auc:0.915196	validation_1-auc:0.854118
# [53]	validation_0-auc:0.916764	validation_1-auc:0.855776
# [54]	validation_0-auc:0.918847	validation_1-auc:0.858136
# [55]	validation_0-auc:0.920733	validation_1-auc:0.860069
# [56]	validation_0-auc:0.921655	validation_1-auc:0.860864
# [57]	validation_0-auc:0.922991	validation_1-auc:0.862562
# [58]	validation_0-auc:0.923266	validation_1-auc:0.862803
# [59]	validation_0-auc:0.924854	validation_1-auc:0.864523
# [60]	validation_0-auc:0.926297	validation_1-auc:0.865699
# [61]	validation_0-auc:0.926904	validation_1-auc:0.866246
# [62]	validation_0-auc:0.927254	validation_1-auc:0.866564
# [63]	validation_0-auc:0.92763	validation_1-auc:0.867288
# [64]	validation_0-auc:0.929994	validation_1-auc:0.869213
# [65]	validation_0-auc:0.931773	validation_1-auc:0.870596
# [66]	validation_0-auc:0.932416	validation_1-auc:0.871655
# [67]	validation_0-auc:0.933601	validation_1-auc:0.872755
# [68]	validation_0-auc:0.934986	validation_1-auc:0.874591
# [69]	validation_0-auc:0.935315	validation_1-auc:0.875173
# [70]	validation_0-auc:0.9355	validation_1-auc:0.875436
# [71]	validation_0-auc:0.936155	validation_1-auc:0.87614
# [72]	validation_0-auc:0.936204	validation_1-auc:0.876279
# [73]	validation_0-auc:0.936761	validation_1-auc:0.876827
# [74]	validation_0-auc:0.937899	validation_1-auc:0.877718
# [75]	validation_0-auc:0.937985	validation_1-auc:0.877777
# [76]	validation_0-auc:0.9403	validation_1-auc:0.879564
# [77]	validation_0-auc:0.940738	validation_1-auc:0.880264
# [78]	validation_0-auc:0.940828	validation_1-auc:0.880336
# [79]	validation_0-auc:0.941659	validation_1-auc:0.881244
# [80]	validation_0-auc:0.942239	validation_1-auc:0.881742
# [81]	validation_0-auc:0.942641	validation_1-auc:0.882499
# [82]	validation_0-auc:0.943106	validation_1-auc:0.88287
# [83]	validation_0-auc:0.943177	validation_1-auc:0.882856
# [84]	validation_0-auc:0.943492	validation_1-auc:0.882908
# [85]	validation_0-auc:0.94385	validation_1-auc:0.883248
# [86]	validation_0-auc:0.944377	validation_1-auc:0.884096
# [87]	validation_0-auc:0.945811	validation_1-auc:0.885531
# [88]	validation_0-auc:0.945858	validation_1-auc:0.885621
# [89]	validation_0-auc:0.946119	validation_1-auc:0.885798
# [90]	validation_0-auc:0.946875	validation_1-auc:0.886226
# [91]	validation_0-auc:0.946948	validation_1-auc:0.886354
# [92]	validation_0-auc:0.947278	validation_1-auc:0.886375
# [93]	validation_0-auc:0.947326	validation_1-auc:0.88663
# [94]	validation_0-auc:0.948081	validation_1-auc:0.887413
# [95]	validation_0-auc:0.948185	validation_1-auc:0.887621
# [96]	validation_0-auc:0.948788	validation_1-auc:0.888816
# [97]	validation_0-auc:0.948934	validation_1-auc:0.889251
# [98]	validation_0-auc:0.949307	validation_1-auc:0.889738
# [99]	validation_0-auc:0.950092	validation_1-auc:0.89056
# [0]	validation_0-auc:0.708089	validation_1-auc:0.668336
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.748028	validation_1-auc:0.708257
# [2]	validation_0-auc:0.765286	validation_1-auc:0.724931
# [3]	validation_0-auc:0.79216	validation_1-auc:0.747844
# [4]	validation_0-auc:0.793377	validation_1-auc:0.749814
# [5]	validation_0-auc:0.825367	validation_1-auc:0.781113
# [6]	validation_0-auc:0.825019	validation_1-auc:0.784296
# [7]	validation_0-auc:0.827789	validation_1-auc:0.788398
# [8]	validation_0-auc:0.835218	validation_1-auc:0.793305
# [9]	validation_0-auc:0.85071	validation_1-auc:0.809283
# [10]	validation_0-auc:0.854448	validation_1-auc:0.811831
# [11]	validation_0-auc:0.856682	validation_1-auc:0.814
# [12]	validation_0-auc:0.856861	validation_1-auc:0.812189
# [13]	validation_0-auc:0.858233	validation_1-auc:0.814579
# [14]	validation_0-auc:0.861801	validation_1-auc:0.819092
# [15]	validation_0-auc:0.876991	validation_1-auc:0.835071
# [16]	validation_0-auc:0.893878	validation_1-auc:0.852836
# [17]	validation_0-auc:0.901298	validation_1-auc:0.863312
# [18]	validation_0-auc:0.903571	validation_1-auc:0.864907
# [19]	validation_0-auc:0.905506	validation_1-auc:0.867508
# [20]	validation_0-auc:0.913773	validation_1-auc:0.871265
# [21]	validation_0-auc:0.914417	validation_1-auc:0.872353
# [22]	validation_0-auc:0.91482	validation_1-auc:0.872931
# [23]	validation_0-auc:0.918775	validation_1-auc:0.876437
# [24]	validation_0-auc:0.92062	validation_1-auc:0.877995
# [25]	validation_0-auc:0.923291	validation_1-auc:0.881858
# [26]	validation_0-auc:0.930013	validation_1-auc:0.888643
# [27]	validation_0-auc:0.930406	validation_1-auc:0.888842
# [28]	validation_0-auc:0.935477	validation_1-auc:0.894297
# [29]	validation_0-auc:0.93754	validation_1-auc:0.896003
# [30]	validation_0-auc:0.939426	validation_1-auc:0.898398
# [31]	validation_0-auc:0.939663	validation_1-auc:0.898907
# [32]	validation_0-auc:0.940479	validation_1-auc:0.899744
# [33]	validation_0-auc:0.944276	validation_1-auc:0.904749
# [34]	validation_0-auc:0.944604	validation_1-auc:0.904571
# [35]	validation_0-auc:0.944941	validation_1-auc:0.904785
# [36]	validation_0-auc:0.945188	validation_1-auc:0.904713
# [37]	validation_0-auc:0.947217	validation_1-auc:0.906374
# [38]	validation_0-auc:0.947144	validation_1-auc:0.905961
# [39]	validation_0-auc:0.95127	validation_1-auc:0.910326
# [40]	validation_0-auc:0.952527	validation_1-auc:0.912136
# [41]	validation_0-auc:0.952733	validation_1-auc:0.912409
# [42]	validation_0-auc:0.953588	validation_1-auc:0.913274
# [43]	validation_0-auc:0.954609	validation_1-auc:0.913636
# [44]	validation_0-auc:0.956442	validation_1-auc:0.915723
# [45]	validation_0-auc:0.957744	validation_1-auc:0.916642
# [46]	validation_0-auc:0.958372	validation_1-auc:0.917365
# [47]	validation_0-auc:0.958258	validation_1-auc:0.917031
# [48]	validation_0-auc:0.958209	validation_1-auc:0.917113
# [49]	validation_0-auc:0.960345	validation_1-auc:0.919963
# [50]	validation_0-auc:0.960682	validation_1-auc:0.920213
# [51]	validation_0-auc:0.960709	validation_1-auc:0.920336
# [52]	validation_0-auc:0.960665	validation_1-auc:0.920151
# [53]	validation_0-auc:0.960727	validation_1-auc:0.920313
# [54]	validation_0-auc:0.962167	validation_1-auc:0.921785
# [55]	validation_0-auc:0.963475	validation_1-auc:0.922482
# [56]	validation_0-auc:0.963477	validation_1-auc:0.922267
# [57]	validation_0-auc:0.963624	validation_1-auc:0.922593
# [58]	validation_0-auc:0.964684	validation_1-auc:0.923886
# [59]	validation_0-auc:0.964895	validation_1-auc:0.924332
# [60]	validation_0-auc:0.964947	validation_1-auc:0.924426
# [61]	validation_0-auc:0.965414	validation_1-auc:0.925421
# [62]	validation_0-auc:0.966617	validation_1-auc:0.927003
# [63]	validation_0-auc:0.967947	validation_1-auc:0.928687
# [64]	validation_0-auc:0.968602	validation_1-auc:0.929553
# [65]	validation_0-auc:0.970256	validation_1-auc:0.9302
# [66]	validation_0-auc:0.970403	validation_1-auc:0.930546
# [67]	validation_0-auc:0.971068	validation_1-auc:0.931438
# [68]	validation_0-auc:0.971075	validation_1-auc:0.9314
# [69]	validation_0-auc:0.97199	validation_1-auc:0.932712
# [70]	validation_0-auc:0.972344	validation_1-auc:0.933424
# [71]	validation_0-auc:0.973191	validation_1-auc:0.934416
# [72]	validation_0-auc:0.973157	validation_1-auc:0.934768
# [73]	validation_0-auc:0.973293	validation_1-auc:0.934843
# [74]	validation_0-auc:0.973378	validation_1-auc:0.934813
# [75]	validation_0-auc:0.973478	validation_1-auc:0.934948
# [76]	validation_0-auc:0.973485	validation_1-auc:0.935033
# [77]	validation_0-auc:0.974186	validation_1-auc:0.93632
# [78]	validation_0-auc:0.974272	validation_1-auc:0.936506
# [79]	validation_0-auc:0.974764	validation_1-auc:0.937571
# [80]	validation_0-auc:0.975313	validation_1-auc:0.938516
# [81]	validation_0-auc:0.976276	validation_1-auc:0.938845
# [82]	validation_0-auc:0.976958	validation_1-auc:0.939754
# [83]	validation_0-auc:0.976946	validation_1-auc:0.939693
# [84]	validation_0-auc:0.976946	validation_1-auc:0.939682
# [85]	validation_0-auc:0.977299	validation_1-auc:0.939904
# [86]	validation_0-auc:0.97735	validation_1-auc:0.939998
# [87]	validation_0-auc:0.977363	validation_1-auc:0.940169
# [88]	validation_0-auc:0.977593	validation_1-auc:0.940455
# [89]	validation_0-auc:0.977593	validation_1-auc:0.940281
# [90]	validation_0-auc:0.978063	validation_1-auc:0.940322
# [91]	validation_0-auc:0.978518	validation_1-auc:0.940599
# [92]	validation_0-auc:0.978408	validation_1-auc:0.940422
# [93]	validation_0-auc:0.978858	validation_1-auc:0.941132
# [94]	validation_0-auc:0.979016	validation_1-auc:0.941307
# [95]	validation_0-auc:0.979996	validation_1-auc:0.94222
# [96]	validation_0-auc:0.98024	validation_1-auc:0.942643
# [97]	validation_0-auc:0.980262	validation_1-auc:0.942688
# [98]	validation_0-auc:0.980456	validation_1-auc:0.94301
# [99]	validation_0-auc:0.980584	validation_1-auc:0.943221
# [0]	validation_0-auc:0.759607	validation_1-auc:0.712289
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.776041	validation_1-auc:0.72898
# [2]	validation_0-auc:0.783004	validation_1-auc:0.7317
# [3]	validation_0-auc:0.789162	validation_1-auc:0.737705
# [4]	validation_0-auc:0.795652	validation_1-auc:0.745636
# [5]	validation_0-auc:0.800556	validation_1-auc:0.751351
# [6]	validation_0-auc:0.801871	validation_1-auc:0.751405
# [7]	validation_0-auc:0.805333	validation_1-auc:0.756357
# [8]	validation_0-auc:0.810444	validation_1-auc:0.760396
# [9]	validation_0-auc:0.813327	validation_1-auc:0.763128
# [10]	validation_0-auc:0.821275	validation_1-auc:0.769953
# [11]	validation_0-auc:0.82498	validation_1-auc:0.772932
# [12]	validation_0-auc:0.826511	validation_1-auc:0.773605
# [13]	validation_0-auc:0.827289	validation_1-auc:0.773162
# [14]	validation_0-auc:0.828357	validation_1-auc:0.774046
# [15]	validation_0-auc:0.831422	validation_1-auc:0.77581
# [16]	validation_0-auc:0.832421	validation_1-auc:0.77681
# [17]	validation_0-auc:0.833677	validation_1-auc:0.778076
# [18]	validation_0-auc:0.835693	validation_1-auc:0.780153
# [19]	validation_0-auc:0.840771	validation_1-auc:0.783852
# [20]	validation_0-auc:0.842956	validation_1-auc:0.785058
# [21]	validation_0-auc:0.84498	validation_1-auc:0.78711
# [22]	validation_0-auc:0.847622	validation_1-auc:0.789038
# [23]	validation_0-auc:0.847201	validation_1-auc:0.788979
# [24]	validation_0-auc:0.848686	validation_1-auc:0.791288
# [25]	validation_0-auc:0.850412	validation_1-auc:0.793101
# [26]	validation_0-auc:0.851994	validation_1-auc:0.794192
# [27]	validation_0-auc:0.855242	validation_1-auc:0.797413
# [28]	validation_0-auc:0.856899	validation_1-auc:0.799245
# [29]	validation_0-auc:0.86296	validation_1-auc:0.803809
# [30]	validation_0-auc:0.865762	validation_1-auc:0.805705
# [31]	validation_0-auc:0.867875	validation_1-auc:0.807619
# [32]	validation_0-auc:0.869062	validation_1-auc:0.808418
# [33]	validation_0-auc:0.871043	validation_1-auc:0.810334
# [34]	validation_0-auc:0.874324	validation_1-auc:0.813722
# [35]	validation_0-auc:0.875069	validation_1-auc:0.814415
# [36]	validation_0-auc:0.879242	validation_1-auc:0.81799
# [37]	validation_0-auc:0.881721	validation_1-auc:0.820386
# [38]	validation_0-auc:0.883196	validation_1-auc:0.821772
# [39]	validation_0-auc:0.886274	validation_1-auc:0.824589
# [40]	validation_0-auc:0.887199	validation_1-auc:0.825432
# [41]	validation_0-auc:0.89022	validation_1-auc:0.827617
# [42]	validation_0-auc:0.893079	validation_1-auc:0.830209
# [43]	validation_0-auc:0.895175	validation_1-auc:0.832032
# [44]	validation_0-auc:0.897674	validation_1-auc:0.834066
# [45]	validation_0-auc:0.898719	validation_1-auc:0.835182
# [46]	validation_0-auc:0.900874	validation_1-auc:0.837831
# [47]	validation_0-auc:0.901486	validation_1-auc:0.838423
# [48]	validation_0-auc:0.902588	validation_1-auc:0.839714
# [49]	validation_0-auc:0.903871	validation_1-auc:0.840533
# [50]	validation_0-auc:0.907249	validation_1-auc:0.842902
# [51]	validation_0-auc:0.90828	validation_1-auc:0.844035
# [52]	validation_0-auc:0.908713	validation_1-auc:0.844587
# [53]	validation_0-auc:0.90952	validation_1-auc:0.845481
# [54]	validation_0-auc:0.909782	validation_1-auc:0.845744
# [55]	validation_0-auc:0.911771	validation_1-auc:0.847057
# [56]	validation_0-auc:0.913883	validation_1-auc:0.848667
# [57]	validation_0-auc:0.914209	validation_1-auc:0.849149
# [58]	validation_0-auc:0.914387	validation_1-auc:0.849032
# [59]	validation_0-auc:0.916758	validation_1-auc:0.851564
# [60]	validation_0-auc:0.91707	validation_1-auc:0.852077
# [61]	validation_0-auc:0.916949	validation_1-auc:0.852103
# [62]	validation_0-auc:0.91919	validation_1-auc:0.854003
# [63]	validation_0-auc:0.919488	validation_1-auc:0.854542
# [64]	validation_0-auc:0.920078	validation_1-auc:0.855057
# [65]	validation_0-auc:0.920215	validation_1-auc:0.85543
# [66]	validation_0-auc:0.921977	validation_1-auc:0.856622
# [67]	validation_0-auc:0.922209	validation_1-auc:0.856734
# [68]	validation_0-auc:0.924625	validation_1-auc:0.858886
# [69]	validation_0-auc:0.92622	validation_1-auc:0.860298
# [70]	validation_0-auc:0.927732	validation_1-auc:0.86158
# [71]	validation_0-auc:0.929358	validation_1-auc:0.863102
# [72]	validation_0-auc:0.930926	validation_1-auc:0.865032
# [73]	validation_0-auc:0.932495	validation_1-auc:0.866366
# [74]	validation_0-auc:0.934479	validation_1-auc:0.868676
# [75]	validation_0-auc:0.935461	validation_1-auc:0.869734
# [76]	validation_0-auc:0.937046	validation_1-auc:0.871541
# [77]	validation_0-auc:0.937175	validation_1-auc:0.871678
# [78]	validation_0-auc:0.938928	validation_1-auc:0.873554
# [79]	validation_0-auc:0.939917	validation_1-auc:0.874465
# [80]	validation_0-auc:0.940426	validation_1-auc:0.875076
# [81]	validation_0-auc:0.941639	validation_1-auc:0.87672
# [82]	validation_0-auc:0.942638	validation_1-auc:0.877863
# [83]	validation_0-auc:0.942778	validation_1-auc:0.877957
# [84]	validation_0-auc:0.943372	validation_1-auc:0.878431
# [85]	validation_0-auc:0.944172	validation_1-auc:0.879068
# [86]	validation_0-auc:0.944743	validation_1-auc:0.879966
# [87]	validation_0-auc:0.94591	validation_1-auc:0.881416
# [88]	validation_0-auc:0.946015	validation_1-auc:0.881397
# [89]	validation_0-auc:0.946709	validation_1-auc:0.882059
# [90]	validation_0-auc:0.947105	validation_1-auc:0.882631
# [91]	validation_0-auc:0.947933	validation_1-auc:0.88367
# [92]	validation_0-auc:0.948159	validation_1-auc:0.88366
# [93]	validation_0-auc:0.94895	validation_1-auc:0.884722
# [94]	validation_0-auc:0.949812	validation_1-auc:0.885962
# [95]	validation_0-auc:0.949882	validation_1-auc:0.885965
# [96]	validation_0-auc:0.950792	validation_1-auc:0.886911
# [97]	validation_0-auc:0.951534	validation_1-auc:0.887625
# [98]	validation_0-auc:0.952014	validation_1-auc:0.888433
# [99]	validation_0-auc:0.952204	validation_1-auc:0.888684
# [0]	validation_0-auc:0.666324	validation_1-auc:0.63868
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.690161	validation_1-auc:0.670628
# [2]	validation_0-auc:0.722562	validation_1-auc:0.696171
# [3]	validation_0-auc:0.778423	validation_1-auc:0.738868
# [4]	validation_0-auc:0.778945	validation_1-auc:0.73868
# [5]	validation_0-auc:0.78641	validation_1-auc:0.742741
# [6]	validation_0-auc:0.800338	validation_1-auc:0.752777
# [7]	validation_0-auc:0.811669	validation_1-auc:0.764145
# [8]	validation_0-auc:0.829103	validation_1-auc:0.777408
# [9]	validation_0-auc:0.8371	validation_1-auc:0.78675
# [10]	validation_0-auc:0.841997	validation_1-auc:0.791888
# [11]	validation_0-auc:0.853718	validation_1-auc:0.800025
# [12]	validation_0-auc:0.858423	validation_1-auc:0.805915
# [13]	validation_0-auc:0.857391	validation_1-auc:0.804292
# [14]	validation_0-auc:0.862424	validation_1-auc:0.809055
# [15]	validation_0-auc:0.865888	validation_1-auc:0.813305
# [16]	validation_0-auc:0.866913	validation_1-auc:0.814448
# [17]	validation_0-auc:0.868665	validation_1-auc:0.81485
# [18]	validation_0-auc:0.877701	validation_1-auc:0.824804
# [19]	validation_0-auc:0.886195	validation_1-auc:0.832631
# [20]	validation_0-auc:0.886811	validation_1-auc:0.832346
# [21]	validation_0-auc:0.899887	validation_1-auc:0.845375
# [22]	validation_0-auc:0.900395	validation_1-auc:0.846429
# [23]	validation_0-auc:0.900514	validation_1-auc:0.846323
# [24]	validation_0-auc:0.903613	validation_1-auc:0.848613
# [25]	validation_0-auc:0.903807	validation_1-auc:0.848494
# [26]	validation_0-auc:0.907935	validation_1-auc:0.853151
# [27]	validation_0-auc:0.914526	validation_1-auc:0.859843
# [28]	validation_0-auc:0.918015	validation_1-auc:0.863206
# [29]	validation_0-auc:0.918535	validation_1-auc:0.863809
# [30]	validation_0-auc:0.924335	validation_1-auc:0.869839
# [31]	validation_0-auc:0.924636	validation_1-auc:0.870342
# [32]	validation_0-auc:0.925023	validation_1-auc:0.870406
# [33]	validation_0-auc:0.926248	validation_1-auc:0.872664
# [34]	validation_0-auc:0.931148	validation_1-auc:0.878265
# [35]	validation_0-auc:0.933928	validation_1-auc:0.881166
# [36]	validation_0-auc:0.934829	validation_1-auc:0.882325
# [37]	validation_0-auc:0.940533	validation_1-auc:0.888024
# [38]	validation_0-auc:0.944147	validation_1-auc:0.891875
# [39]	validation_0-auc:0.944426	validation_1-auc:0.892355
# [40]	validation_0-auc:0.946306	validation_1-auc:0.893217
# [41]	validation_0-auc:0.946301	validation_1-auc:0.892876
# [42]	validation_0-auc:0.948955	validation_1-auc:0.8957
# [43]	validation_0-auc:0.949065	validation_1-auc:0.895763
# [44]	validation_0-auc:0.952254	validation_1-auc:0.899982
# [45]	validation_0-auc:0.955019	validation_1-auc:0.903425
# [46]	validation_0-auc:0.956152	validation_1-auc:0.905912
# [47]	validation_0-auc:0.95632	validation_1-auc:0.906303
# [48]	validation_0-auc:0.958273	validation_1-auc:0.909548
# [49]	validation_0-auc:0.958968	validation_1-auc:0.910746
# [50]	validation_0-auc:0.960601	validation_1-auc:0.911753
# [51]	validation_0-auc:0.961712	validation_1-auc:0.913565
# [52]	validation_0-auc:0.962031	validation_1-auc:0.913891
# [53]	validation_0-auc:0.962097	validation_1-auc:0.913907
# [54]	validation_0-auc:0.96228	validation_1-auc:0.914363
# [55]	validation_0-auc:0.962922	validation_1-auc:0.915853
# [56]	validation_0-auc:0.963182	validation_1-auc:0.916639
# [57]	validation_0-auc:0.963347	validation_1-auc:0.916794
# [58]	validation_0-auc:0.963948	validation_1-auc:0.917121
# [59]	validation_0-auc:0.966015	validation_1-auc:0.919278
# [60]	validation_0-auc:0.96777	validation_1-auc:0.922005
# [61]	validation_0-auc:0.968414	validation_1-auc:0.923685
# [62]	validation_0-auc:0.969827	validation_1-auc:0.926013
# [63]	validation_0-auc:0.969883	validation_1-auc:0.925786
# [64]	validation_0-auc:0.970678	validation_1-auc:0.92672
# [65]	validation_0-auc:0.970725	validation_1-auc:0.926689
# [66]	validation_0-auc:0.972273	validation_1-auc:0.929481
# [67]	validation_0-auc:0.973133	validation_1-auc:0.930869
# [68]	validation_0-auc:0.974035	validation_1-auc:0.932041
# [69]	validation_0-auc:0.974084	validation_1-auc:0.932052
# [70]	validation_0-auc:0.974115	validation_1-auc:0.932162
# [71]	validation_0-auc:0.974437	validation_1-auc:0.932874
# [72]	validation_0-auc:0.975508	validation_1-auc:0.934358
# [73]	validation_0-auc:0.976162	validation_1-auc:0.935257
# [74]	validation_0-auc:0.976154	validation_1-auc:0.935224
# [75]	validation_0-auc:0.976866	validation_1-auc:0.93526
# [76]	validation_0-auc:0.977074	validation_1-auc:0.935541
# [77]	validation_0-auc:0.977847	validation_1-auc:0.93687
# [78]	validation_0-auc:0.977873	validation_1-auc:0.936869
# [79]	validation_0-auc:0.977988	validation_1-auc:0.936913
# [80]	validation_0-auc:0.979786	validation_1-auc:0.939752
# [81]	validation_0-auc:0.980082	validation_1-auc:0.940215
# [82]	validation_0-auc:0.980077	validation_1-auc:0.940229
# [83]	validation_0-auc:0.980769	validation_1-auc:0.941545
# [84]	validation_0-auc:0.98079	validation_1-auc:0.941472
# [85]	validation_0-auc:0.980892	validation_1-auc:0.941469
# [86]	validation_0-auc:0.980879	validation_1-auc:0.941506
# [87]	validation_0-auc:0.980964	validation_1-auc:0.941637
# [88]	validation_0-auc:0.981385	validation_1-auc:0.942541
# [89]	validation_0-auc:0.981984	validation_1-auc:0.943155
# [90]	validation_0-auc:0.982352	validation_1-auc:0.944218
# [91]	validation_0-auc:0.98282	validation_1-auc:0.944865
# [92]	validation_0-auc:0.983011	validation_1-auc:0.945194
# [93]	validation_0-auc:0.983003	validation_1-auc:0.945087
# [94]	validation_0-auc:0.983488	validation_1-auc:0.945698
# [95]	validation_0-auc:0.983478	validation_1-auc:0.945588
# [96]	validation_0-auc:0.983675	validation_1-auc:0.946019
# [97]	validation_0-auc:0.983802	validation_1-auc:0.945837
# [98]	validation_0-auc:0.984164	validation_1-auc:0.946743
# [99]	validation_0-auc:0.98457	validation_1-auc:0.947414
# [0]	validation_0-auc:0.762494	validation_1-auc:0.731804
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.783035	validation_1-auc:0.74769
# [2]	validation_0-auc:0.78548	validation_1-auc:0.747862
# [3]	validation_0-auc:0.792586	validation_1-auc:0.754178
# [4]	validation_0-auc:0.796003	validation_1-auc:0.757338
# [5]	validation_0-auc:0.804437	validation_1-auc:0.764352
# [6]	validation_0-auc:0.807057	validation_1-auc:0.764631
# [7]	validation_0-auc:0.816424	validation_1-auc:0.77312
# [8]	validation_0-auc:0.818367	validation_1-auc:0.774089
# [9]	validation_0-auc:0.823329	validation_1-auc:0.778496
# [10]	validation_0-auc:0.828074	validation_1-auc:0.78136
# [11]	validation_0-auc:0.833063	validation_1-auc:0.786213
# [12]	validation_0-auc:0.84003	validation_1-auc:0.792076
# [13]	validation_0-auc:0.841769	validation_1-auc:0.793401
# [14]	validation_0-auc:0.84703	validation_1-auc:0.798583
# [15]	validation_0-auc:0.849923	validation_1-auc:0.801109
# [16]	validation_0-auc:0.851742	validation_1-auc:0.8024
# [17]	validation_0-auc:0.855575	validation_1-auc:0.805244
# [18]	validation_0-auc:0.857354	validation_1-auc:0.807095
# [19]	validation_0-auc:0.85897	validation_1-auc:0.808611
# [20]	validation_0-auc:0.86063	validation_1-auc:0.810213
# [21]	validation_0-auc:0.863486	validation_1-auc:0.812762
# [22]	validation_0-auc:0.865246	validation_1-auc:0.814732
# [23]	validation_0-auc:0.866848	validation_1-auc:0.815761
# [24]	validation_0-auc:0.869654	validation_1-auc:0.817133
# [25]	validation_0-auc:0.871741	validation_1-auc:0.819078
# [26]	validation_0-auc:0.876453	validation_1-auc:0.823433
# [27]	validation_0-auc:0.878996	validation_1-auc:0.825438
# [28]	validation_0-auc:0.879488	validation_1-auc:0.8256
# [29]	validation_0-auc:0.883634	validation_1-auc:0.829936
# [30]	validation_0-auc:0.885129	validation_1-auc:0.831049
# [31]	validation_0-auc:0.886331	validation_1-auc:0.831995
# [32]	validation_0-auc:0.889936	validation_1-auc:0.835943
# [33]	validation_0-auc:0.891003	validation_1-auc:0.837002
# [34]	validation_0-auc:0.892208	validation_1-auc:0.838449
# [35]	validation_0-auc:0.892767	validation_1-auc:0.839213
# [36]	validation_0-auc:0.894619	validation_1-auc:0.840385
# [37]	validation_0-auc:0.895924	validation_1-auc:0.841545
# [38]	validation_0-auc:0.897501	validation_1-auc:0.843199
# [39]	validation_0-auc:0.899094	validation_1-auc:0.844381
# [40]	validation_0-auc:0.900093	validation_1-auc:0.845077
# [41]	validation_0-auc:0.900464	validation_1-auc:0.845632
# [42]	validation_0-auc:0.90434	validation_1-auc:0.849217
# [43]	validation_0-auc:0.907556	validation_1-auc:0.852717
# [44]	validation_0-auc:0.908242	validation_1-auc:0.853274
# [45]	validation_0-auc:0.909985	validation_1-auc:0.854918
# [46]	validation_0-auc:0.911692	validation_1-auc:0.856197
# [47]	validation_0-auc:0.911889	validation_1-auc:0.856326
# [48]	validation_0-auc:0.914199	validation_1-auc:0.858674
# [49]	validation_0-auc:0.914658	validation_1-auc:0.859193
# [50]	validation_0-auc:0.917499	validation_1-auc:0.861526
# [51]	validation_0-auc:0.918549	validation_1-auc:0.862275
# [52]	validation_0-auc:0.922137	validation_1-auc:0.865013
# [53]	validation_0-auc:0.923104	validation_1-auc:0.865792
# [54]	validation_0-auc:0.925956	validation_1-auc:0.867811
# [55]	validation_0-auc:0.927531	validation_1-auc:0.869667
# [56]	validation_0-auc:0.927751	validation_1-auc:0.869945
# [57]	validation_0-auc:0.928325	validation_1-auc:0.870574
# [58]	validation_0-auc:0.930035	validation_1-auc:0.871961
# [59]	validation_0-auc:0.930295	validation_1-auc:0.872276
# [60]	validation_0-auc:0.932571	validation_1-auc:0.875173
# [61]	validation_0-auc:0.933646	validation_1-auc:0.876392
# [62]	validation_0-auc:0.934787	validation_1-auc:0.877859
# [63]	validation_0-auc:0.935591	validation_1-auc:0.878818
# [64]	validation_0-auc:0.937136	validation_1-auc:0.880493
# [65]	validation_0-auc:0.937972	validation_1-auc:0.881271
# [66]	validation_0-auc:0.940166	validation_1-auc:0.883555
# [67]	validation_0-auc:0.94094	validation_1-auc:0.883857
# [68]	validation_0-auc:0.941653	validation_1-auc:0.884908
# [69]	validation_0-auc:0.941826	validation_1-auc:0.885165
# [70]	validation_0-auc:0.943099	validation_1-auc:0.88607
# [71]	validation_0-auc:0.94361	validation_1-auc:0.8867
# [72]	validation_0-auc:0.944593	validation_1-auc:0.888031
# [73]	validation_0-auc:0.946586	validation_1-auc:0.889944
# [74]	validation_0-auc:0.947157	validation_1-auc:0.890446
# [75]	validation_0-auc:0.947815	validation_1-auc:0.890893
# [76]	validation_0-auc:0.948847	validation_1-auc:0.892303
# [77]	validation_0-auc:0.949096	validation_1-auc:0.892644
# [78]	validation_0-auc:0.949539	validation_1-auc:0.893247
# [79]	validation_0-auc:0.949616	validation_1-auc:0.893361
# [80]	validation_0-auc:0.950072	validation_1-auc:0.893751
# [81]	validation_0-auc:0.950098	validation_1-auc:0.893826
# [82]	validation_0-auc:0.95093	validation_1-auc:0.894951
# [83]	validation_0-auc:0.951772	validation_1-auc:0.895887
# [84]	validation_0-auc:0.952446	validation_1-auc:0.896812
# [85]	validation_0-auc:0.95273	validation_1-auc:0.897154
# [86]	validation_0-auc:0.953175	validation_1-auc:0.897536
# [87]	validation_0-auc:0.954003	validation_1-auc:0.898285
# [88]	validation_0-auc:0.954031	validation_1-auc:0.898277
# [89]	validation_0-auc:0.954487	validation_1-auc:0.898943
# [90]	validation_0-auc:0.955253	validation_1-auc:0.900053
# [91]	validation_0-auc:0.955845	validation_1-auc:0.900321
# [92]	validation_0-auc:0.956123	validation_1-auc:0.900444
# [93]	validation_0-auc:0.956385	validation_1-auc:0.900639
# [94]	validation_0-auc:0.956881	validation_1-auc:0.901328
# [95]	validation_0-auc:0.958142	validation_1-auc:0.902887
# [96]	validation_0-auc:0.958166	validation_1-auc:0.902958
# [97]	validation_0-auc:0.958934	validation_1-auc:0.904239
# [98]	validation_0-auc:0.959623	validation_1-auc:0.904897
# [99]	validation_0-auc:0.959647	validation_1-auc:0.904877
# [0]	validation_0-auc:0.677512	validation_1-auc:0.644537
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.700164	validation_1-auc:0.661501
# [2]	validation_0-auc:0.737838	validation_1-auc:0.688573
# [3]	validation_0-auc:0.768688	validation_1-auc:0.718569
# [4]	validation_0-auc:0.797317	validation_1-auc:0.743714
# [5]	validation_0-auc:0.807756	validation_1-auc:0.755105
# [6]	validation_0-auc:0.807186	validation_1-auc:0.754854
# [7]	validation_0-auc:0.820215	validation_1-auc:0.770613
# [8]	validation_0-auc:0.829699	validation_1-auc:0.779184
# [9]	validation_0-auc:0.84604	validation_1-auc:0.792909
# [10]	validation_0-auc:0.850206	validation_1-auc:0.797339
# [11]	validation_0-auc:0.850623	validation_1-auc:0.79696
# [12]	validation_0-auc:0.849859	validation_1-auc:0.797771
# [13]	validation_0-auc:0.861079	validation_1-auc:0.807495
# [14]	validation_0-auc:0.873033	validation_1-auc:0.819087
# [15]	validation_0-auc:0.88784	validation_1-auc:0.836466
# [16]	validation_0-auc:0.892365	validation_1-auc:0.840413
# [17]	validation_0-auc:0.893769	validation_1-auc:0.842587
# [18]	validation_0-auc:0.902687	validation_1-auc:0.850651
# [19]	validation_0-auc:0.90525	validation_1-auc:0.854253
# [20]	validation_0-auc:0.908821	validation_1-auc:0.858758
# [21]	validation_0-auc:0.914488	validation_1-auc:0.865426
# [22]	validation_0-auc:0.915457	validation_1-auc:0.865082
# [23]	validation_0-auc:0.916167	validation_1-auc:0.866569
# [24]	validation_0-auc:0.923452	validation_1-auc:0.873553
# [25]	validation_0-auc:0.924696	validation_1-auc:0.876244
# [26]	validation_0-auc:0.931163	validation_1-auc:0.880428
# [27]	validation_0-auc:0.933323	validation_1-auc:0.882663
# [28]	validation_0-auc:0.935952	validation_1-auc:0.88476
# [29]	validation_0-auc:0.9371	validation_1-auc:0.886301
# [30]	validation_0-auc:0.939446	validation_1-auc:0.889836
# [31]	validation_0-auc:0.940821	validation_1-auc:0.891923
# [32]	validation_0-auc:0.942499	validation_1-auc:0.892853
# [33]	validation_0-auc:0.944447	validation_1-auc:0.894806
# [34]	validation_0-auc:0.945593	validation_1-auc:0.895491
# [35]	validation_0-auc:0.945845	validation_1-auc:0.895675
# [36]	validation_0-auc:0.946557	validation_1-auc:0.896221
# [37]	validation_0-auc:0.947419	validation_1-auc:0.898077
# [38]	validation_0-auc:0.950482	validation_1-auc:0.902257
# [39]	validation_0-auc:0.952345	validation_1-auc:0.904752
# [40]	validation_0-auc:0.954778	validation_1-auc:0.908505
# [41]	validation_0-auc:0.955913	validation_1-auc:0.909025
# [42]	validation_0-auc:0.956371	validation_1-auc:0.909504
# [43]	validation_0-auc:0.956596	validation_1-auc:0.910136
# [44]	validation_0-auc:0.958013	validation_1-auc:0.912829
# [45]	validation_0-auc:0.95837	validation_1-auc:0.913331
# [46]	validation_0-auc:0.962104	validation_1-auc:0.916659
# [47]	validation_0-auc:0.963114	validation_1-auc:0.917273
# [48]	validation_0-auc:0.963957	validation_1-auc:0.91876
# [49]	validation_0-auc:0.967013	validation_1-auc:0.922368
# [50]	validation_0-auc:0.967798	validation_1-auc:0.92283
# [51]	validation_0-auc:0.96824	validation_1-auc:0.923827
# [52]	validation_0-auc:0.968486	validation_1-auc:0.924375
# [53]	validation_0-auc:0.968605	validation_1-auc:0.924745
# [54]	validation_0-auc:0.968931	validation_1-auc:0.925958
# [55]	validation_0-auc:0.969011	validation_1-auc:0.925947
# [56]	validation_0-auc:0.969255	validation_1-auc:0.92684
# [57]	validation_0-auc:0.969319	validation_1-auc:0.926881
# [58]	validation_0-auc:0.969837	validation_1-auc:0.928016
# [59]	validation_0-auc:0.969888	validation_1-auc:0.927903
# [60]	validation_0-auc:0.971644	validation_1-auc:0.928694
# [61]	validation_0-auc:0.971995	validation_1-auc:0.929386
# [62]	validation_0-auc:0.972737	validation_1-auc:0.930297
# [63]	validation_0-auc:0.972843	validation_1-auc:0.930295
# [64]	validation_0-auc:0.973374	validation_1-auc:0.930925
# [65]	validation_0-auc:0.973766	validation_1-auc:0.93131
# [66]	validation_0-auc:0.973839	validation_1-auc:0.931482
# [67]	validation_0-auc:0.973943	validation_1-auc:0.931773
# [68]	validation_0-auc:0.974599	validation_1-auc:0.933091
# [69]	validation_0-auc:0.975175	validation_1-auc:0.933816
# [70]	validation_0-auc:0.975797	validation_1-auc:0.934568
# [71]	validation_0-auc:0.975979	validation_1-auc:0.934545
# [72]	validation_0-auc:0.975935	validation_1-auc:0.934542
# [73]	validation_0-auc:0.975908	validation_1-auc:0.93451
# [74]	validation_0-auc:0.975927	validation_1-auc:0.934583
# [75]	validation_0-auc:0.976291	validation_1-auc:0.93503
# [76]	validation_0-auc:0.976414	validation_1-auc:0.935306
# [77]	validation_0-auc:0.976327	validation_1-auc:0.935168
# [78]	validation_0-auc:0.976517	validation_1-auc:0.93553
# [79]	validation_0-auc:0.976462	validation_1-auc:0.935486
# [80]	validation_0-auc:0.976981	validation_1-auc:0.935902
# [81]	validation_0-auc:0.977427	validation_1-auc:0.936427
# [82]	validation_0-auc:0.977341	validation_1-auc:0.936257
# [83]	validation_0-auc:0.978314	validation_1-auc:0.937359
# [84]	validation_0-auc:0.978555	validation_1-auc:0.937867
# [85]	validation_0-auc:0.978532	validation_1-auc:0.93779
# [86]	validation_0-auc:0.978545	validation_1-auc:0.937807
# [87]	validation_0-auc:0.979733	validation_1-auc:0.940441
# [88]	validation_0-auc:0.980235	validation_1-auc:0.940598
# [89]	validation_0-auc:0.980378	validation_1-auc:0.9407
# [90]	validation_0-auc:0.980351	validation_1-auc:0.940438
# [91]	validation_0-auc:0.980356	validation_1-auc:0.940486
# [92]	validation_0-auc:0.980418	validation_1-auc:0.940599
# [93]	validation_0-auc:0.981296	validation_1-auc:0.942738
# [94]	validation_0-auc:0.98161	validation_1-auc:0.943299
# [95]	validation_0-auc:0.981538	validation_1-auc:0.943071
# [96]	validation_0-auc:0.982031	validation_1-auc:0.943965
# [97]	validation_0-auc:0.982052	validation_1-auc:0.943931
# [98]	validation_0-auc:0.98209	validation_1-auc:0.944072
# [99]	validation_0-auc:0.982066	validation_1-auc:0.944078
# [0]	validation_0-auc:0.759584	validation_1-auc:0.720982
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.772088	validation_1-auc:0.733341
# [2]	validation_0-auc:0.780515	validation_1-auc:0.742375
# [3]	validation_0-auc:0.783581	validation_1-auc:0.743927
# [4]	validation_0-auc:0.792965	validation_1-auc:0.752348
# [5]	validation_0-auc:0.797054	validation_1-auc:0.756617
# [6]	validation_0-auc:0.805574	validation_1-auc:0.762927
# [7]	validation_0-auc:0.810182	validation_1-auc:0.766616
# [8]	validation_0-auc:0.813705	validation_1-auc:0.770047
# [9]	validation_0-auc:0.82122	validation_1-auc:0.77641
# [10]	validation_0-auc:0.821947	validation_1-auc:0.77656
# [11]	validation_0-auc:0.827	validation_1-auc:0.77981
# [12]	validation_0-auc:0.82942	validation_1-auc:0.781176
# [13]	validation_0-auc:0.830998	validation_1-auc:0.781794
# [14]	validation_0-auc:0.832253	validation_1-auc:0.783063
# [15]	validation_0-auc:0.833821	validation_1-auc:0.784637
# [16]	validation_0-auc:0.833899	validation_1-auc:0.784381
# [17]	validation_0-auc:0.834723	validation_1-auc:0.784757
# [18]	validation_0-auc:0.837406	validation_1-auc:0.78616
# [19]	validation_0-auc:0.83843	validation_1-auc:0.786374
# [20]	validation_0-auc:0.840425	validation_1-auc:0.788114
# [21]	validation_0-auc:0.845208	validation_1-auc:0.792456
# [22]	validation_0-auc:0.847763	validation_1-auc:0.793121
# [23]	validation_0-auc:0.850503	validation_1-auc:0.794876
# [24]	validation_0-auc:0.85259	validation_1-auc:0.797369
# [25]	validation_0-auc:0.853512	validation_1-auc:0.798263
# [26]	validation_0-auc:0.855046	validation_1-auc:0.799388
# [27]	validation_0-auc:0.855335	validation_1-auc:0.799671
# [28]	validation_0-auc:0.855775	validation_1-auc:0.80041
# [29]	validation_0-auc:0.858028	validation_1-auc:0.801983
# [30]	validation_0-auc:0.858577	validation_1-auc:0.80272
# [31]	validation_0-auc:0.860762	validation_1-auc:0.805538
# [32]	validation_0-auc:0.861308	validation_1-auc:0.805908
# [33]	validation_0-auc:0.862728	validation_1-auc:0.806994
# [34]	validation_0-auc:0.869821	validation_1-auc:0.81308
# [35]	validation_0-auc:0.871099	validation_1-auc:0.813585
# [36]	validation_0-auc:0.873149	validation_1-auc:0.814577
# [37]	validation_0-auc:0.873904	validation_1-auc:0.814995
# [38]	validation_0-auc:0.876585	validation_1-auc:0.817247
# [39]	validation_0-auc:0.878577	validation_1-auc:0.81939
# [40]	validation_0-auc:0.882212	validation_1-auc:0.822366
# [41]	validation_0-auc:0.888651	validation_1-auc:0.828033
# [42]	validation_0-auc:0.891717	validation_1-auc:0.830751
# [43]	validation_0-auc:0.892644	validation_1-auc:0.832146
# [44]	validation_0-auc:0.894399	validation_1-auc:0.833347
# [45]	validation_0-auc:0.896359	validation_1-auc:0.834961
# [46]	validation_0-auc:0.896687	validation_1-auc:0.83522
# [47]	validation_0-auc:0.900065	validation_1-auc:0.839131
# [48]	validation_0-auc:0.901583	validation_1-auc:0.840517
# [49]	validation_0-auc:0.905247	validation_1-auc:0.843916
# [50]	validation_0-auc:0.905234	validation_1-auc:0.843992
# [51]	validation_0-auc:0.911432	validation_1-auc:0.850606
# [52]	validation_0-auc:0.912268	validation_1-auc:0.851314
# [53]	validation_0-auc:0.91288	validation_1-auc:0.852301
# [54]	validation_0-auc:0.913918	validation_1-auc:0.853404
# [55]	validation_0-auc:0.917331	validation_1-auc:0.857436
# [56]	validation_0-auc:0.920034	validation_1-auc:0.859854
# [57]	validation_0-auc:0.923007	validation_1-auc:0.862328
# [58]	validation_0-auc:0.925043	validation_1-auc:0.864122
# [59]	validation_0-auc:0.925616	validation_1-auc:0.864553
# [60]	validation_0-auc:0.926829	validation_1-auc:0.865282
# [61]	validation_0-auc:0.927145	validation_1-auc:0.865759
# [62]	validation_0-auc:0.929047	validation_1-auc:0.868326
# [63]	validation_0-auc:0.929434	validation_1-auc:0.86854
# [64]	validation_0-auc:0.931345	validation_1-auc:0.870794
# [65]	validation_0-auc:0.931594	validation_1-auc:0.870919
# [66]	validation_0-auc:0.931673	validation_1-auc:0.870986
# [67]	validation_0-auc:0.932287	validation_1-auc:0.871832
# [68]	validation_0-auc:0.933646	validation_1-auc:0.87294
# [69]	validation_0-auc:0.9363	validation_1-auc:0.875377
# [70]	validation_0-auc:0.937738	validation_1-auc:0.876906
# [71]	validation_0-auc:0.937767	validation_1-auc:0.876909
# [72]	validation_0-auc:0.937988	validation_1-auc:0.87727
# [73]	validation_0-auc:0.939133	validation_1-auc:0.878409
# [74]	validation_0-auc:0.940251	validation_1-auc:0.87947
# [75]	validation_0-auc:0.940958	validation_1-auc:0.880557
# [76]	validation_0-auc:0.942673	validation_1-auc:0.882159
# [77]	validation_0-auc:0.942765	validation_1-auc:0.882247
# [78]	validation_0-auc:0.943419	validation_1-auc:0.883024
# [79]	validation_0-auc:0.945032	validation_1-auc:0.885001
# [80]	validation_0-auc:0.945182	validation_1-auc:0.885378
# [81]	validation_0-auc:0.945669	validation_1-auc:0.885536
# [82]	validation_0-auc:0.946588	validation_1-auc:0.886415
# [83]	validation_0-auc:0.947502	validation_1-auc:0.887151
# [84]	validation_0-auc:0.94869	validation_1-auc:0.888793
# [85]	validation_0-auc:0.950146	validation_1-auc:0.89036
# [86]	validation_0-auc:0.951035	validation_1-auc:0.89136
# [87]	validation_0-auc:0.952943	validation_1-auc:0.893592
# [88]	validation_0-auc:0.953219	validation_1-auc:0.894339
# [89]	validation_0-auc:0.953261	validation_1-auc:0.89442
# [90]	validation_0-auc:0.953447	validation_1-auc:0.894513
# [91]	validation_0-auc:0.954518	validation_1-auc:0.895549
# [92]	validation_0-auc:0.955852	validation_1-auc:0.897137
# [93]	validation_0-auc:0.956191	validation_1-auc:0.897468
# [94]	validation_0-auc:0.957112	validation_1-auc:0.898472
# [95]	validation_0-auc:0.957091	validation_1-auc:0.898454
# [96]	validation_0-auc:0.958297	validation_1-auc:0.900141
# [97]	validation_0-auc:0.959355	validation_1-auc:0.901338
# [98]	validation_0-auc:0.960483	validation_1-auc:0.902846
# [99]	validation_0-auc:0.960797	validation_1-auc:0.903448
# [0]	validation_0-auc:0.716877	validation_1-auc:0.686928
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.742391	validation_1-auc:0.710555
# [2]	validation_0-auc:0.800407	validation_1-auc:0.759976
# [3]	validation_0-auc:0.814729	validation_1-auc:0.763494
# [4]	validation_0-auc:0.814982	validation_1-auc:0.761936
# [5]	validation_0-auc:0.835815	validation_1-auc:0.773923
# [6]	validation_0-auc:0.849306	validation_1-auc:0.791501
# [7]	validation_0-auc:0.85454	validation_1-auc:0.795907
# [8]	validation_0-auc:0.868899	validation_1-auc:0.807282
# [9]	validation_0-auc:0.87704	validation_1-auc:0.812978
# [10]	validation_0-auc:0.88591	validation_1-auc:0.81955
# [11]	validation_0-auc:0.906903	validation_1-auc:0.845658
# [12]	validation_0-auc:0.910429	validation_1-auc:0.849717
# [13]	validation_0-auc:0.914534	validation_1-auc:0.855457
# [14]	validation_0-auc:0.919942	validation_1-auc:0.862953
# [15]	validation_0-auc:0.922234	validation_1-auc:0.865463
# [16]	validation_0-auc:0.925959	validation_1-auc:0.868325
# [17]	validation_0-auc:0.929044	validation_1-auc:0.873531
# [18]	validation_0-auc:0.931007	validation_1-auc:0.875007
# [19]	validation_0-auc:0.932867	validation_1-auc:0.878046
# [20]	validation_0-auc:0.933981	validation_1-auc:0.879687
# [21]	validation_0-auc:0.94046	validation_1-auc:0.88717
# ...
# [24]	validation_0-auc:0.859968	validation_1-auc:0.805403
# [25]	validation_0-auc:0.860719	validation_1-auc:0.806042
# [26]	validation_0-auc:0.862545	validation_1-auc:0.807855
# [27]	validation_0-auc:0.868967	validation_1-auc:0.813112
# [28]	validation_0-auc:0.86958	validation_1-auc:0.813872
# [29]	validation_0-auc:0.873513	validation_1-auc:0.81734
# [30]	validation_0-auc:0.874869	validation_1-auc:0.818799
# [31]	validation_0-auc:0.87871	validation_1-auc:0.821403
# [32]	validation_0-auc:0.87952	validation_1-auc:0.822386
# [33]	validation_0-auc:0.884212	validation_1-auc:0.826349
# [34]	validation_0-auc:0.885042	validation_1-auc:0.827156
# [35]	validation_0-auc:0.886871	validation_1-auc:0.828391
# [36]	validation_0-auc:0.891032	validation_1-auc:0.831646
# [37]	validation_0-auc:0.893467	validation_1-auc:0.834071
# [38]	validation_0-auc:0.894012	validation_1-auc:0.834539
# [39]	validation_0-auc:0.894558	validation_1-auc:0.834929
# [40]	validation_0-auc:0.896533	validation_1-auc:0.836421
# [41]	validation_0-auc:0.897087	validation_1-auc:0.837004
# [42]	validation_0-auc:0.899957	validation_1-auc:0.839921
# [43]	validation_0-auc:0.900862	validation_1-auc:0.84048
# [44]	validation_0-auc:0.903622	validation_1-auc:0.842916
# [45]	validation_0-auc:0.903706	validation_1-auc:0.843023
# [46]	validation_0-auc:0.9051	validation_1-auc:0.844387
# [47]	validation_0-auc:0.908719	validation_1-auc:0.846794
# [48]	validation_0-auc:0.910715	validation_1-auc:0.848676
# [49]	validation_0-auc:0.911514	validation_1-auc:0.849663
# [50]	validation_0-auc:0.912919	validation_1-auc:0.850325
# [51]	validation_0-auc:0.914402	validation_1-auc:0.851561
# [52]	validation_0-auc:0.916248	validation_1-auc:0.85309
# [53]	validation_0-auc:0.918682	validation_1-auc:0.855005
# [54]	validation_0-auc:0.919205	validation_1-auc:0.855579
# [55]	validation_0-auc:0.921049	validation_1-auc:0.857709
# [56]	validation_0-auc:0.922933	validation_1-auc:0.859312
# [57]	validation_0-auc:0.927245	validation_1-auc:0.8627
# [58]	validation_0-auc:0.928777	validation_1-auc:0.864101
# [59]	validation_0-auc:0.932522	validation_1-auc:0.867977
# [60]	validation_0-auc:0.933686	validation_1-auc:0.869097
# [61]	validation_0-auc:0.935096	validation_1-auc:0.870325
# [62]	validation_0-auc:0.935236	validation_1-auc:0.870551
# [63]	validation_0-auc:0.936226	validation_1-auc:0.871231
# [64]	validation_0-auc:0.937543	validation_1-auc:0.872328
# [65]	validation_0-auc:0.938691	validation_1-auc:0.873462
# [66]	validation_0-auc:0.939155	validation_1-auc:0.873702
# [67]	validation_0-auc:0.940341	validation_1-auc:0.875247
# [68]	validation_0-auc:0.941193	validation_1-auc:0.876407
# [69]	validation_0-auc:0.941383	validation_1-auc:0.876445
# [70]	validation_0-auc:0.942313	validation_1-auc:0.877282
# [71]	validation_0-auc:0.942898	validation_1-auc:0.877807
# [72]	validation_0-auc:0.942992	validation_1-auc:0.877898
# [73]	validation_0-auc:0.943498	validation_1-auc:0.878304
# [74]	validation_0-auc:0.944484	validation_1-auc:0.87911
# [75]	validation_0-auc:0.946381	validation_1-auc:0.881338
# [76]	validation_0-auc:0.946966	validation_1-auc:0.882389
# [77]	validation_0-auc:0.948792	validation_1-auc:0.88452
# [78]	validation_0-auc:0.949195	validation_1-auc:0.885106
# [79]	validation_0-auc:0.949264	validation_1-auc:0.885139
# [80]	validation_0-auc:0.949366	validation_1-auc:0.885335
# [81]	validation_0-auc:0.951227	validation_1-auc:0.887207
# [82]	validation_0-auc:0.951824	validation_1-auc:0.887946
# [83]	validation_0-auc:0.952659	validation_1-auc:0.889331
# [84]	validation_0-auc:0.953438	validation_1-auc:0.89018
# [85]	validation_0-auc:0.953577	validation_1-auc:0.890339
# [86]	validation_0-auc:0.954374	validation_1-auc:0.891244
# [87]	validation_0-auc:0.955062	validation_1-auc:0.892013
# [88]	validation_0-auc:0.955439	validation_1-auc:0.892353
# [89]	validation_0-auc:0.955469	validation_1-auc:0.892386
# [90]	validation_0-auc:0.956025	validation_1-auc:0.893308
# [91]	validation_0-auc:0.956734	validation_1-auc:0.893865
# [92]	validation_0-auc:0.95735	validation_1-auc:0.894717
# [93]	validation_0-auc:0.957855	validation_1-auc:0.895435
# [94]	validation_0-auc:0.957991	validation_1-auc:0.895588
# [95]	validation_0-auc:0.958579	validation_1-auc:0.896801
# [96]	validation_0-auc:0.958726	validation_1-auc:0.897029
# [97]	validation_0-auc:0.958767	validation_1-auc:0.896964
# [98]	validation_0-auc:0.959065	validation_1-auc:0.897408
# [99]	validation_0-auc:0.959369	validation_1-auc:0.897727
# [0]	validation_0-auc:0.707137	validation_1-auc:0.669052
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.725023	validation_1-auc:0.685855
# [2]	validation_0-auc:0.745444	validation_1-auc:0.69237
# [3]	validation_0-auc:0.744272	validation_1-auc:0.700831
# [4]	validation_0-auc:0.784957	validation_1-auc:0.741351
# [5]	validation_0-auc:0.794703	validation_1-auc:0.751912
# [6]	validation_0-auc:0.813457	validation_1-auc:0.769273
# [7]	validation_0-auc:0.839841	validation_1-auc:0.794775
# [8]	validation_0-auc:0.847143	validation_1-auc:0.802632
# [9]	validation_0-auc:0.856192	validation_1-auc:0.810629
# [10]	validation_0-auc:0.860276	validation_1-auc:0.8153
# [11]	validation_0-auc:0.864912	validation_1-auc:0.816373
# [12]	validation_0-auc:0.880525	validation_1-auc:0.833113
# [13]	validation_0-auc:0.882666	validation_1-auc:0.836569
# [14]	validation_0-auc:0.882819	validation_1-auc:0.835318
# [15]	validation_0-auc:0.886717	validation_1-auc:0.839846
# [16]	validation_0-auc:0.893088	validation_1-auc:0.847117
# [17]	validation_0-auc:0.900636	validation_1-auc:0.854595
# [18]	validation_0-auc:0.901981	validation_1-auc:0.854893
# [19]	validation_0-auc:0.905245	validation_1-auc:0.858129
# [20]	validation_0-auc:0.910041	validation_1-auc:0.864965
# [21]	validation_0-auc:0.910815	validation_1-auc:0.865697
# [22]	validation_0-auc:0.912119	validation_1-auc:0.867044
# [23]	validation_0-auc:0.915942	validation_1-auc:0.870002
# [24]	validation_0-auc:0.918249	validation_1-auc:0.874758
# [25]	validation_0-auc:0.920926	validation_1-auc:0.877072
# [26]	validation_0-auc:0.927184	validation_1-auc:0.882827
# [27]	validation_0-auc:0.928795	validation_1-auc:0.884508
# [28]	validation_0-auc:0.931811	validation_1-auc:0.886266
# [29]	validation_0-auc:0.932204	validation_1-auc:0.886679
# [30]	validation_0-auc:0.933616	validation_1-auc:0.888171
# [31]	validation_0-auc:0.933989	validation_1-auc:0.888738
# [32]	validation_0-auc:0.933947	validation_1-auc:0.888783
# [33]	validation_0-auc:0.938397	validation_1-auc:0.89303
# [34]	validation_0-auc:0.938158	validation_1-auc:0.892885
# [35]	validation_0-auc:0.941049	validation_1-auc:0.896457
# [36]	validation_0-auc:0.944389	validation_1-auc:0.900362
# [37]	validation_0-auc:0.947453	validation_1-auc:0.90423
# [38]	validation_0-auc:0.947781	validation_1-auc:0.904753
# [39]	validation_0-auc:0.947809	validation_1-auc:0.904713
# [40]	validation_0-auc:0.953248	validation_1-auc:0.910402
# [41]	validation_0-auc:0.954637	validation_1-auc:0.911877
# [42]	validation_0-auc:0.955414	validation_1-auc:0.913012
# [43]	validation_0-auc:0.958044	validation_1-auc:0.916009
# [44]	validation_0-auc:0.960125	validation_1-auc:0.918005
# [45]	validation_0-auc:0.961854	validation_1-auc:0.920054
# [46]	validation_0-auc:0.961985	validation_1-auc:0.920485
# [47]	validation_0-auc:0.961904	validation_1-auc:0.920459
# [48]	validation_0-auc:0.962562	validation_1-auc:0.921173
# [49]	validation_0-auc:0.964507	validation_1-auc:0.923457
# [50]	validation_0-auc:0.964466	validation_1-auc:0.923218
# [51]	validation_0-auc:0.964478	validation_1-auc:0.923408
# [52]	validation_0-auc:0.965297	validation_1-auc:0.924887
# [53]	validation_0-auc:0.967143	validation_1-auc:0.927351
# [54]	validation_0-auc:0.967108	validation_1-auc:0.927244
# [55]	validation_0-auc:0.96923	validation_1-auc:0.929844
# [56]	validation_0-auc:0.969384	validation_1-auc:0.929818
# [57]	validation_0-auc:0.969794	validation_1-auc:0.929672
# [58]	validation_0-auc:0.969994	validation_1-auc:0.92982
# [59]	validation_0-auc:0.97117	validation_1-auc:0.929279
# [60]	validation_0-auc:0.971723	validation_1-auc:0.930246
# [61]	validation_0-auc:0.97184	validation_1-auc:0.930724
# [62]	validation_0-auc:0.971982	validation_1-auc:0.931091
# [63]	validation_0-auc:0.971967	validation_1-auc:0.93097
# [64]	validation_0-auc:0.972833	validation_1-auc:0.932633
# [65]	validation_0-auc:0.972996	validation_1-auc:0.932625
# [66]	validation_0-auc:0.973507	validation_1-auc:0.933285
# [67]	validation_0-auc:0.973492	validation_1-auc:0.933378
# [68]	validation_0-auc:0.974884	validation_1-auc:0.935803
# [69]	validation_0-auc:0.975443	validation_1-auc:0.936235
# [70]	validation_0-auc:0.976568	validation_1-auc:0.937023
# [71]	validation_0-auc:0.976531	validation_1-auc:0.936905
# [72]	validation_0-auc:0.977012	validation_1-auc:0.937593
# [73]	validation_0-auc:0.976979	validation_1-auc:0.937463
# [74]	validation_0-auc:0.976906	validation_1-auc:0.937326
# [75]	validation_0-auc:0.976961	validation_1-auc:0.937567
# [76]	validation_0-auc:0.976977	validation_1-auc:0.93775
# [77]	validation_0-auc:0.977106	validation_1-auc:0.937987
# [78]	validation_0-auc:0.977699	validation_1-auc:0.938623
# [79]	validation_0-auc:0.977759	validation_1-auc:0.938672
# [80]	validation_0-auc:0.978552	validation_1-auc:0.940225
# [81]	validation_0-auc:0.978955	validation_1-auc:0.940728
# [82]	validation_0-auc:0.979241	validation_1-auc:0.940895
# [83]	validation_0-auc:0.979226	validation_1-auc:0.940935
# [84]	validation_0-auc:0.979984	validation_1-auc:0.942265
# [85]	validation_0-auc:0.980604	validation_1-auc:0.943416
# [86]	validation_0-auc:0.980558	validation_1-auc:0.94349
# [87]	validation_0-auc:0.980589	validation_1-auc:0.94349
# [88]	validation_0-auc:0.981504	validation_1-auc:0.945102
# [89]	validation_0-auc:0.98195	validation_1-auc:0.945394
# [90]	validation_0-auc:0.982587	validation_1-auc:0.945748
# [91]	validation_0-auc:0.982574	validation_1-auc:0.945735
# [92]	validation_0-auc:0.982901	validation_1-auc:0.946324
# [93]	validation_0-auc:0.982875	validation_1-auc:0.946294
# [94]	validation_0-auc:0.983574	validation_1-auc:0.947637
# [95]	validation_0-auc:0.984374	validation_1-auc:0.947946
# [96]	validation_0-auc:0.984683	validation_1-auc:0.948356
# [97]	validation_0-auc:0.984688	validation_1-auc:0.948411
# [98]	validation_0-auc:0.985182	validation_1-auc:0.948776
# [99]	validation_0-auc:0.985829	validation_1-auc:0.949425
# [0]	validation_0-auc:0.754598	validation_1-auc:0.702799
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.77665	validation_1-auc:0.731496
# [2]	validation_0-auc:0.783481	validation_1-auc:0.738461
# [3]	validation_0-auc:0.787943	validation_1-auc:0.743087
# [4]	validation_0-auc:0.789756	validation_1-auc:0.745696
# [5]	validation_0-auc:0.792427	validation_1-auc:0.748664
# [6]	validation_0-auc:0.79575	validation_1-auc:0.752001
# [7]	validation_0-auc:0.797942	validation_1-auc:0.754366
# [8]	validation_0-auc:0.802747	validation_1-auc:0.760031
# [9]	validation_0-auc:0.80937	validation_1-auc:0.765129
# [10]	validation_0-auc:0.812768	validation_1-auc:0.768307
# [11]	validation_0-auc:0.817172	validation_1-auc:0.771579
# [12]	validation_0-auc:0.821805	validation_1-auc:0.774811
# [13]	validation_0-auc:0.823601	validation_1-auc:0.77634
# [14]	validation_0-auc:0.828671	validation_1-auc:0.781749
# [15]	validation_0-auc:0.830694	validation_1-auc:0.782161
# [16]	validation_0-auc:0.835341	validation_1-auc:0.786094
# [17]	validation_0-auc:0.840936	validation_1-auc:0.789996
# [18]	validation_0-auc:0.842903	validation_1-auc:0.791281
# [19]	validation_0-auc:0.845597	validation_1-auc:0.793817
# [20]	validation_0-auc:0.850707	validation_1-auc:0.79821
# [21]	validation_0-auc:0.851738	validation_1-auc:0.799156
# [22]	validation_0-auc:0.851926	validation_1-auc:0.79925
# [23]	validation_0-auc:0.852282	validation_1-auc:0.799679
# [24]	validation_0-auc:0.857082	validation_1-auc:0.804257
# [25]	validation_0-auc:0.858616	validation_1-auc:0.805123
# [26]	validation_0-auc:0.86196	validation_1-auc:0.809048
# [27]	validation_0-auc:0.865436	validation_1-auc:0.811979
# [28]	validation_0-auc:0.869613	validation_1-auc:0.814231
# [29]	validation_0-auc:0.870562	validation_1-auc:0.814982
# [30]	validation_0-auc:0.87482	validation_1-auc:0.819003
# [31]	validation_0-auc:0.876999	validation_1-auc:0.821122
# [32]	validation_0-auc:0.879006	validation_1-auc:0.823668
# [33]	validation_0-auc:0.881529	validation_1-auc:0.825523
# [34]	validation_0-auc:0.882301	validation_1-auc:0.826251
# [35]	validation_0-auc:0.884426	validation_1-auc:0.827665
# [36]	validation_0-auc:0.886392	validation_1-auc:0.82964
# [37]	validation_0-auc:0.887608	validation_1-auc:0.830551
# [38]	validation_0-auc:0.892423	validation_1-auc:0.834912
# [39]	validation_0-auc:0.894493	validation_1-auc:0.836851
# [40]	validation_0-auc:0.894985	validation_1-auc:0.837506
# [41]	validation_0-auc:0.896452	validation_1-auc:0.839077
# [42]	validation_0-auc:0.897295	validation_1-auc:0.839567
# [43]	validation_0-auc:0.899886	validation_1-auc:0.842084
# [44]	validation_0-auc:0.902794	validation_1-auc:0.845138
# [45]	validation_0-auc:0.906409	validation_1-auc:0.848115
# [46]	validation_0-auc:0.90703	validation_1-auc:0.848862
# [47]	validation_0-auc:0.909064	validation_1-auc:0.850964
# [48]	validation_0-auc:0.910082	validation_1-auc:0.851575
# [49]	validation_0-auc:0.913096	validation_1-auc:0.854607
# [50]	validation_0-auc:0.913322	validation_1-auc:0.85493
# [51]	validation_0-auc:0.914676	validation_1-auc:0.85614
# [52]	validation_0-auc:0.916283	validation_1-auc:0.857796
# [53]	validation_0-auc:0.916602	validation_1-auc:0.858086
# [54]	validation_0-auc:0.91876	validation_1-auc:0.860432
# [55]	validation_0-auc:0.918801	validation_1-auc:0.860546
# [56]	validation_0-auc:0.923294	validation_1-auc:0.864437
# [57]	validation_0-auc:0.924177	validation_1-auc:0.865095
# [58]	validation_0-auc:0.926391	validation_1-auc:0.86734
# [59]	validation_0-auc:0.927631	validation_1-auc:0.868265
# [60]	validation_0-auc:0.927766	validation_1-auc:0.868432
# [61]	validation_0-auc:0.928089	validation_1-auc:0.86882
# [62]	validation_0-auc:0.928756	validation_1-auc:0.86961
# [63]	validation_0-auc:0.930354	validation_1-auc:0.870963
# [64]	validation_0-auc:0.932669	validation_1-auc:0.872716
# [65]	validation_0-auc:0.932681	validation_1-auc:0.872795
# [66]	validation_0-auc:0.933897	validation_1-auc:0.874172
# [67]	validation_0-auc:0.936765	validation_1-auc:0.87689
# [68]	validation_0-auc:0.938728	validation_1-auc:0.87906
# [69]	validation_0-auc:0.939058	validation_1-auc:0.879381
# [70]	validation_0-auc:0.939068	validation_1-auc:0.87946
# [71]	validation_0-auc:0.939495	validation_1-auc:0.880191
# [72]	validation_0-auc:0.939765	validation_1-auc:0.880586
# [73]	validation_0-auc:0.940173	validation_1-auc:0.880928
# [74]	validation_0-auc:0.941683	validation_1-auc:0.882889
# [75]	validation_0-auc:0.943056	validation_1-auc:0.883765
# [76]	validation_0-auc:0.944128	validation_1-auc:0.884747
# [77]	validation_0-auc:0.944578	validation_1-auc:0.885222
# [78]	validation_0-auc:0.944795	validation_1-auc:0.88543
# [79]	validation_0-auc:0.94552	validation_1-auc:0.885958
# [80]	validation_0-auc:0.945712	validation_1-auc:0.88609
# [81]	validation_0-auc:0.947173	validation_1-auc:0.887208
# [82]	validation_0-auc:0.94826	validation_1-auc:0.888509
# [83]	validation_0-auc:0.948345	validation_1-auc:0.888595
# [84]	validation_0-auc:0.94858	validation_1-auc:0.88895
# [85]	validation_0-auc:0.94912	validation_1-auc:0.889744
# [86]	validation_0-auc:0.949103	validation_1-auc:0.889571
# [87]	validation_0-auc:0.949666	validation_1-auc:0.89023
# [88]	validation_0-auc:0.95115	validation_1-auc:0.891227
# [89]	validation_0-auc:0.951727	validation_1-auc:0.891522
# [90]	validation_0-auc:0.951851	validation_1-auc:0.891697
# [91]	validation_0-auc:0.95201	validation_1-auc:0.891778
# [92]	validation_0-auc:0.952194	validation_1-auc:0.891971
# [93]	validation_0-auc:0.953373	validation_1-auc:0.893451
# [94]	validation_0-auc:0.953986	validation_1-auc:0.894288
# [95]	validation_0-auc:0.95402	validation_1-auc:0.894242
# [96]	validation_0-auc:0.954566	validation_1-auc:0.894881
# [97]	validation_0-auc:0.955583	validation_1-auc:0.895564
# [98]	validation_0-auc:0.955679	validation_1-auc:0.895661
# [99]	validation_0-auc:0.955691	validation_1-auc:0.895654

# %%
def promotion_strategy(df):
    '''
    INPUT 
    df - a dataframe with *only* the columns V1 - V7 (same as train_data)

    OUTPUT
    promotion_df - np.array with the values
                   'Yes' or 'No' related to whether or not an 
                   individual should recieve a promotion 
                   should be the length of df.shape[0]            
    Ex:
    INPUT: df
    
    V1	V2	  V3	V4	V5	V6	V7
    2	30	-1.1	1	1	3	2
    3	32	-0.6	2	3	2	2
    2	30	0.13	1	1	4	2
    
    OUTPUT: promotion
    
    array(['Yes', 'Yes', 'No'])
    indicating the first two users would recieve the promotion and 
    the last should not.
    '''

    test = df
    avg_pred_probs_contol = np.zeros(shape=(test.shape[0],2))
    avg_pred_probs_exper = np.zeros(shape=(test.shape[0],2))
    for i in range(10):
        model_control_name = "model_control_" + str(i+1) +'.pickle.dat'
        model_control = pickle.load(open(model_control_name, "rb"))
        pred_probs_contol = model_control.predict_proba(test, ntree_limit=model_control.best_ntree_limit)
        avg_pred_probs_contol += pred_probs_contol

        model_exper_name = "model_exper_" + str(i+1) +'.pickle.dat'
        model_exper = pickle.load(open(model_exper_name, "rb"))
        pred_probs_exper = model_exper.predict_proba(test, ntree_limit=model_control.best_ntree_limit)
        avg_pred_probs_exper += pred_probs_exper

    # get average soft predictions for both control and experimental model
    avg_pred_probs_contol /= 10.0
    avg_pred_probs_exper /= 10.0

    # get difference in probabilities between experimental and cpntrol model for purchase = 1 label
    diff_avg_pred_probs = avg_pred_probs_exper[:,1] - avg_pred_probs_contol[:,1]
    
    promotion = []
    
    # Only send promotions to top 0.1 percentile of probabilities
    cutoff_percentile = np.percentile(diff_avg_pred_probs, 99.9)
    
    for prob in diff_avg_pred_probs:
        if prob > 0:
            if prob > cutoff_percentile:
                promotion.append('Yes')
        else:
            promotion.append('No')

    promotion = np.array(promotion)
    
    return promotion

# %%
# This will test your results, and provide you back some information 
# on how well your promotion_strategy will work in practice

test_results(promotion_strategy)
# Out:
# Nice job!  See how well your strategy worked on our test data below!
#
# Your irr with this strategy is 0.0476.
#
# Your nir with this strategy is 6.85.
# We came up with a model with an irr of 0.0188 and an nir of 189.45 on the test set.
#
#  How did you do?
# (0.047619047619047616, 6.85)
