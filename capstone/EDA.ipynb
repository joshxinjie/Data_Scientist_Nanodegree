# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from model_helper import generate_offer_monthly_data
# %matplotlib inline

# %% [markdown]
# ## Plot Offer Completion/Tried/Failed Rate

# %%
all_data = pd.read_csv("all_data.csv")

# %%
offer_0_total = all_data['offer_0_n_offers'].sum()
offer_0_succ = all_data['offer_0_n_succ_offers'].sum()
offer_0_tried = all_data['offer_0_n_tried_offers'].sum()
offer_0_succ_tried = offer_0_succ + offer_0_tried
offer_0_failed = offer_0_total - offer_0_succ_tried

offer_1_total = all_data['offer_1_n_offers'].sum()
offer_1_succ = all_data['offer_1_n_succ_offers'].sum()
offer_1_tried = all_data['offer_1_n_tried_offers'].sum()
offer_1_succ_tried = offer_1_succ + offer_1_tried
offer_1_failed = offer_1_total - offer_1_succ_tried

offer_2_total = all_data['offer_2_n_offers'].sum()
offer_2_succ = all_data['offer_2_n_succ_offers'].sum()
offer_2_tried = all_data['offer_2_n_tried_offers'].sum()
offer_2_succ_tried = offer_2_succ + offer_2_tried
offer_2_failed = offer_2_total - offer_2_succ_tried

offer_3_total = all_data['offer_3_n_offers'].sum()
offer_3_succ = all_data['offer_3_n_succ_offers'].sum()
offer_3_tried = all_data['offer_3_n_tried_offers'].sum()
offer_3_succ_tried = offer_3_succ + offer_3_tried
offer_3_failed = offer_3_total - offer_3_succ_tried

offer_4_total = all_data['offer_4_n_offers'].sum()
offer_4_succ = all_data['offer_4_n_succ_offers'].sum()
offer_4_tried = all_data['offer_4_n_tried_offers'].sum()
offer_4_succ_tried = offer_4_succ + offer_4_tried
offer_4_failed = offer_4_total - offer_4_succ_tried

offer_5_total = all_data['offer_5_n_offers'].sum()
offer_5_succ = all_data['offer_5_n_succ_offers'].sum()
offer_5_tried = all_data['offer_5_n_tried_offers'].sum()
offer_5_succ_tried = offer_5_succ + offer_5_tried
offer_5_failed = offer_5_total - offer_5_succ_tried

offer_6_total = all_data['offer_6_n_offers'].sum()
offer_6_succ = all_data['offer_6_n_succ_offers'].sum()
offer_6_tried = all_data['offer_6_n_tried_offers'].sum()
offer_6_succ_tried = offer_6_succ + offer_6_tried
offer_6_failed = offer_6_total - offer_6_succ_tried

offer_7_total = all_data['offer_7_n_offers'].sum()
offer_7_succ = all_data['offer_7_n_succ_offers'].sum()
offer_7_tried = all_data['offer_7_n_tried_offers'].sum()
offer_7_succ_tried = offer_7_succ + offer_7_tried
offer_7_failed = offer_7_total - offer_7_succ_tried

offer_8_total = all_data['offer_8_n_offers'].sum()
offer_8_succ = all_data['offer_8_n_succ_offers'].sum()
offer_8_tried = all_data['offer_8_n_tried_offers'].sum()
offer_8_succ_tried = offer_8_succ + offer_8_tried
offer_8_failed = offer_8_total - offer_8_succ_tried

offer_9_total = all_data['offer_9_n_offers'].sum()
offer_9_succ = all_data['offer_9_n_succ_offers'].sum()
offer_9_tried = all_data['offer_9_n_tried_offers'].sum()
offer_9_succ_tried = offer_9_succ + offer_9_tried
offer_9_failed = offer_9_total - offer_9_succ_tried

succ_list = [offer_0_succ, offer_1_succ, offer_2_succ, offer_3_succ,\
             offer_4_succ, offer_5_succ, offer_6_succ, offer_7_succ,\
             offer_8_succ, offer_9_succ
            ]

tried_list = [offer_0_tried, offer_1_tried, offer_2_tried, offer_3_tried,\
              offer_4_tried, offer_5_tried, offer_6_tried, offer_7_tried,\
              offer_8_tried, offer_9_tried
             ]

failed_list = [offer_0_failed, offer_1_failed, offer_2_failed, offer_3_failed,\
               offer_4_failed, offer_5_failed, offer_6_failed, offer_7_failed,\
               offer_8_failed, offer_9_failed
              ]

# %%
df = pd.DataFrame({'Num Succ Offers' : succ_list,'Num Tried Offers' : tried_list,\
                   'Num Failed Offers' : failed_list}
                 )

fig, ax = plt.subplots();
fig.set_size_inches(14,10);

# https://stackoverflow.com/questions/44338623/horizontal-stacked-bar-chart-in-python-giving-multiple-charts-in-jupyter-noteboo
# https://stackoverflow.com/questions/49601890/display-label-stacked-barh-with-values-from-dataframe
df.plot.barh(stacked=True, colormap='Reds', edgecolor='red', ax=ax);

ind = np.arange(9)

ax.set_title("Summary of Offers' Success/Try/Fail Rates", fontsize=22);
ax.set_yticklabels(['Discount 10/20/5', 'Discount 7/7/3', 'Discount 7/10/2', 'Info 4/0/0',\
                 'BOGO 5/10/10', 'Info 3/0/0', 'BOGO 7/5/5', 'BOGO 7/10/10',\
                 'BOGO 5/5/5', 'Discount 10/10/2'], fontsize=16
                  )
ax.set_ylabel("Offer family_type/validity/difficulty/reward", fontsize=16)
ax.set_xlabel("Number of offers", fontsize=16)
ax.legend(loc='center right', bbox_to_anchor=(1.2, 0.5), fontsize=14);

# %% [markdown]
# ## Plot Number of Offers Received By Each Individual

# %%
fig, ax = plt.subplots(figsize=(8,8));
all_data.total_n_offers.value_counts().sort_index().plot(kind='bar', ax=ax);
ax.set_title("Number of Offers Received by Each Individual", fontsize=18);
ax.set_xlabel("Number of Offers Received", fontsize=16);
ax.set_ylabel("Number of Individuals", fontsize=16);

# %%
fig, ax = plt.subplots(figsize=(8,8));
all_data.total_n_succ_offers.value_counts().sort_index().plot(kind='bar', ax=ax);
ax.set_title("Number of Offers Successfully Completed by Each Individual", fontsize=18);
ax.set_xlabel("Number of Offers Successfully Completed", fontsize=16);
ax.set_ylabel("Number of Individuals", fontsize=16);

# %%
fig, ax = plt.subplots(figsize=(8,8));
all_data.total_n_tried_offers.value_counts().sort_index().plot(kind='bar', ax=ax);
ax.set_title("Number of Offers Tried by Each Individual", fontsize=18);
ax.set_xlabel("Number of Offers Tried", fontsize=16);
ax.set_ylabel("Number of Individuals", fontsize=16);

# %%
all_data.total_n_succ_offers.value_counts()
# Out:
# 0.0    15596
# 1.0     1303
# 2.0       96
# 3.0        4
# 4.0        1
# Name: total_n_succ_offers, dtype: int64

# %%
all_data.total_n_tried_offers.value_counts()
# Out:
# 0.0    15502
# 1.0     1361
# 2.0      129
# 3.0        8
# Name: total_n_tried_offers, dtype: int64

# %% [markdown]
# ## Plot Monthly Profit Trend

# %%
monthly_data =pd.read_csv("monthly_data_rolling.csv")

# %%
monthly_data_offer_0 = generate_offer_monthly_data('offer_id_0', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_0.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_0[monthly_data_offer_0['offer_id_0']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_0[monthly_data_offer_0['offer_id_0']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Discount 10/20/5 (Offer ID 0)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_0_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_0.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_0[monthly_data_offer_0['offer_id_0']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_0[monthly_data_offer_0['offer_id_0']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Discount 10/20/5 (Offer ID 0)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_0_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_1 = generate_offer_monthly_data('offer_id_1', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_1.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_1[monthly_data_offer_1['offer_id_1']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_1[monthly_data_offer_1['offer_id_1']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Discount 7/7/3 (Offer ID 1)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_1_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_1.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_1[monthly_data_offer_1['offer_id_1']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_1[monthly_data_offer_1['offer_id_1']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Discount 7/7/3 (Offer ID 1)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_1_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_2 = generate_offer_monthly_data('offer_id_2', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_2.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_2[monthly_data_offer_2['offer_id_2']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_2[monthly_data_offer_2['offer_id_2']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Discount 7/10/2 (Offer ID 2)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_2_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_2.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_2[monthly_data_offer_2['offer_id_2']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_2[monthly_data_offer_2['offer_id_2']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Discount 7/10/2 (Offer ID 2)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_2_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_3 = generate_offer_monthly_data('offer_id_3', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_3.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_3[monthly_data_offer_3['offer_id_3']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_3[monthly_data_offer_3['offer_id_3']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Informational 4/0/0 (Offer ID 3)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_3_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_3.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_3[monthly_data_offer_3['offer_id_3']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_3[monthly_data_offer_3['offer_id_3']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Informational 4/0/0 (Offer ID 3)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_3_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_4 = generate_offer_monthly_data('offer_id_4', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_4.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_4[monthly_data_offer_4['offer_id_4']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_4[monthly_data_offer_4['offer_id_4']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For BOGO 5/10/10 (Offer ID 4)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_4_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_4.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_4[monthly_data_offer_4['offer_id_4']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_4[monthly_data_offer_4['offer_id_4']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For BOGO 5/10/10 (Offer ID 4)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_4_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_5 = generate_offer_monthly_data('offer_id_5', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_5.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_5[monthly_data_offer_5['offer_id_5']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_5[monthly_data_offer_5['offer_id_5']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Informational 3/0/0 (Offer ID 5)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_5_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_5.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_5[monthly_data_offer_5['offer_id_5']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_5[monthly_data_offer_5['offer_id_5']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Informational 3/0/0 (Offer ID 5)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_5_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_6 = generate_offer_monthly_data('offer_id_6', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_6.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_6[monthly_data_offer_6['offer_id_6']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_6[monthly_data_offer_6['offer_id_6']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For BOGO 7/5/5 (Offer ID 6)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_6_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_6.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_6[monthly_data_offer_6['offer_id_6']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_6[monthly_data_offer_6['offer_id_6']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For BOGO 7/5/5 (Offer ID 6)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_6_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_7 = generate_offer_monthly_data('offer_id_7', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_7.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_7[monthly_data_offer_7['offer_id_7']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_7[monthly_data_offer_7['offer_id_7']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For BOGO 7/10/10 (Offer ID 7)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_7_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_7.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_7[monthly_data_offer_7['offer_id_7']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_7[monthly_data_offer_7['offer_id_7']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For BOGO 7/10/10 (Offer ID 7)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_7_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_8 = generate_offer_monthly_data('offer_id_8', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_8.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_8[monthly_data_offer_8['offer_id_8']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_8[monthly_data_offer_8['offer_id_8']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For BOGO 5/5/5 (Offer ID 8)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_8_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_8.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_8[monthly_data_offer_8['offer_id_8']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_8[monthly_data_offer_8['offer_id_8']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For BOGO 5/5/5 (Offer ID 8)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_8_sum.jpg", bbox_inches='tight')

# %%
monthly_data_offer_9 = generate_offer_monthly_data('offer_id_9', monthly_data)

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_9.groupby('month_num').agg({'per_id':'nunique'}).reset_index().plot(x='month_num', y='per_id', kind='line', label='Number of individuals receiving offer', ax=ax);
monthly_data_offer_9[monthly_data_offer_9['offer_id_9']==0].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Non-promotional profitable instances', ax=ax);
monthly_data_offer_9[monthly_data_offer_9['offer_id_9']==1].groupby('month_num').agg({'has_profit':'sum'}).reset_index().plot(x='month_num', y='has_profit', kind='line', label='Promotional profitable instances', ax=ax);
ax.set_title("Number of Profitable Monthly Instances For Discount 10/10/2 (Offer ID 9)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Counts", fontsize=16);
ax.legend(loc='center left', fontsize=14);
fig.savefig("offer_9_count.jpg", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(10,9));
monthly_data_offer_9.groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total profits from individuals receiving offer', ax=ax);
monthly_data_offer_9[monthly_data_offer_9['offer_id_9']==0].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total non-promotional profits', ax=ax);
monthly_data_offer_9[monthly_data_offer_9['offer_id_9']==1].groupby('month_num').agg({'profit':'sum'}).reset_index().plot(x='month_num', y='profit', kind='line', label='Total promotional profits', ax=ax);
ax.set_title("Monthly Profits For Discount 10/10/2 (Offer ID 9)", fontsize=16)
ax.set_xlabel("Month Number", fontsize=16);
ax.set_ylabel("Amount", fontsize=16);
ax.legend(loc='upper left', fontsize=14);
fig.savefig("offer_9_sum.jpg", bbox_inches='tight')
