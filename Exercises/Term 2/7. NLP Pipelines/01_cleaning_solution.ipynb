# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.

# %%
# import statements
import requests
from bs4 import BeautifulSoup

# %%
# fetch web page
r = requests.get("https://www.udacity.com/courses/all")

# %%
# display text from web page
print(r.text)
# Out:
# <!DOCTYPE html><html><head>
#   <meta charset="utf-8">
#   <title>Course Catalog | Udacity</title>
#   <base href="/"><link rel="preload" href="runtime.779ab63315b4a9607089.js" as="script"><link rel="preload" href="polyfills.9f2bda1e51d11e4eb315.js" as="script"><link rel="preload" href="scripts.7810e8fe1e953f6db44e.js" as="script"><link rel="preload" href="main.cf6ccd25ad509cb9cf80.js" as="script">
#
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <link rel="icon" type="image/x-icon" href="favicon.ico">
#   <script src="assets/vendor/segment.js" async="" data-analytics-bootstrap=""></script>
# <link rel="stylesheet" href="styles.7b8016be798ce78687bd.css"><style ng-transition="iridium-us">html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# span.snackbar__content[_ngcontent-sc0] {
#   margin: 0;
#   color: white; }
#
# span.snackbar__content[_ngcontent-sc0]   a[_ngcontent-sc0] {
#     margin: 0;
#     color: white;
#     text-decoration: underline; }</style><style ng-transition="iridium-us">html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 23.72881356%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }</style><style ng-transition="iridium-us">html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem);
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2], .sticky   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2], .sticky   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-riseup[_nghost-sc2], .page-riseup   [_nghost-sc2] {
#   background: #2e3d49; }</style><style ng-transition="iridium-us">html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 2.5rem 0.75rem 1.5rem;
#   color: #fff;
#   text-align: center; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }</style><style ng-transition="iridium-us">html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc4] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc4] {
#   display: none !important; }
#
# .show[_ngcontent-sc4] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc4] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc4] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc4] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc4] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc4] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc4] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc4] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc4] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc4] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc4] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc4] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc4] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc4] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc4] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc4] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc4] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc4]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc4]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc4], [_nghost-sc4] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc4]::after, [_nghost-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc4], .header--clone[_nghost-sc4] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc4]   .header__navbar[_ngcontent-sc4], .header--clone[_nghost-sc4]   .header__navbar[_ngcontent-sc4], .header.header--clone[_ngcontent-sc4]   header[_ngcontent-sc4], .header--clone[_nghost-sc4]   header[_ngcontent-sc4] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc4], .header--stick[_nghost-sc4] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc4]::after, header[_ngcontent-sc4]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 23.72881356%; }
#           .header__navbar--logo[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc4] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   nav[_ngcontent-sc4] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc4]   a[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   div[_ngcontent-sc4] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4]:hover, .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--guest[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--student[_ngcontent-sc4] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc4] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc4] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   #wordmark[_ngcontent-sc4] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc4] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   li[_ngcontent-sc4] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4]:hover, .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#             color: #01647f; }
#
# [_nghost-sc4] {
#   display: block; }
#
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# .header-icons[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem; }
#
# .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .header-icons[_ngcontent-sc4] {
#       display: none; } }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4] {
#   margin-bottom: 0; }
#
# .page-eu.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-eu.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .button--navigation[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .button--navigation[_ngcontent-sc4]:hover, .page-homepage:not(.page-us)   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .text--navigation[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .divider[_ngcontent-sc4]::before, .page-homepage:not(.page-us)   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-riseup[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-riseup[_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-riseup[_nghost-sc4]   .button--navigation[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-riseup[_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover, .page-riseup   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-riseup[_nghost-sc4]   .text--navigation[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-riseup[_nghost-sc4]   .divider[_ngcontent-sc4]::before, .page-riseup   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-business[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-business   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-business[_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-business[_nghost-sc4]   .button--navigation[_ngcontent-sc4], .page-business   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-business[_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover, .page-business   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-business[_nghost-sc4]   .text--navigation[_ngcontent-sc4], .page-business   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-business[_nghost-sc4]   .divider[_ngcontent-sc4]::before, .page-business   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
# ...
#   overflow: hidden;
#   width: 100%;
#   max-height: 20rem; }
# .card-wrapper.is-expanded[_ngcontent-sc244]   .card__inner[_ngcontent-sc244] {
#   border-bottom-left-radius: 0;
#   border-bottom-right-radius: 0; }
# .card-wrapper[_ngcontent-sc244]   hr[_ngcontent-sc244] {
#   border-top: 1px solid #dbe2e8;
#   margin: 1.5rem 4rem; }
# .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#   margin-top: 0;
#   font-weight: 600;
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   color: #7D97AD;
#   text-transform: none;
#   display: inline-block; }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# .card-heading[_ngcontent-sc244] {
#   margin-top: 0;
#   margin-bottom: 0.5rem; }
# .card-heading[_ngcontent-sc244]   a[_ngcontent-sc244] {
#     color: #2e3d49;
#     text-transform: capitalize;
#     font-weight: 600;
#     display: block;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     line-height: 1.6rem;
#     max-height: 4.8rem; }
# .card-heading[_ngcontent-sc244]   a[_ngcontent-sc244]:hover {
#       color: #02b3e4; }
# .card-content[_ngcontent-sc244] {
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 74.57627119%; }
# .card-content[_ngcontent-sc244]:last-child {
#     margin-right: 0; }
# @media (max-width: 62rem) {
#     .card-content[_ngcontent-sc244] {
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 100%; }
#       .card-content[_ngcontent-sc244]:last-child {
#         margin-right: 0; } }
# .card__expander[_ngcontent-sc244] {
#   background: linear-gradient(to top left, #F7F7F7, #EAFBFF); }
# .card__expander--summary[_ngcontent-sc244] {
#     font-size: 0.9rem;
#     padding: 1.5rem 4rem 0; }
# .card__expander--details[_ngcontent-sc244] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 100%;
#     display: flex;
#     justify-content: space-between;
#     padding: 0 4rem 1.5rem; }
# .card__expander--details[_ngcontent-sc244]:last-child {
#       margin-right: 0; }
# .card__expander--details[_ngcontent-sc244]   .btn[_ngcontent-sc244] {
#       width: 10rem;
#       height: 2.5rem;
#       line-height: 2.3rem;
#       color: #fff;
#       background-color: #02b3e4; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244] {
#   display: flex; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   h4[_ngcontent-sc244] {
#     font-size: 0.9rem;
#     text-transform: capitalize;
#     margin-top: 0; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   div[_ngcontent-sc244] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 49.15254237%; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   div[_ngcontent-sc244]:last-child {
#       margin-right: 0; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   span[_ngcontent-sc244] {
#     font-size: 0.875rem;
#     color: #2e3d49; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   span.truncate-content[_ngcontent-sc244] {
#       max-height: 3rem;
#       display: block;
#       overflow-y: hidden; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   .level[_ngcontent-sc244]   span[_ngcontent-sc244]:after {
#     content: '' !important; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   .skills[_ngcontent-sc244]    ~ .level[_ngcontent-sc244] {
#     margin-top: 1.4rem; }
# .card[_ngcontent-sc244]   h4[_ngcontent-sc244] {
#   margin-bottom: 0; }
# @media (max-width: 48rem) {
#   .card[_ngcontent-sc244]   .mobile-icon[_ngcontent-sc244] {
#     display: inline-block;
#     height: 0.8rem;
#     width: 1.5rem;
#     margin-right: 0.2rem;
#     background-image: url("/assets/iridium/images/course-catalog/course-icon-mobile.svg");
#     background-position: center;
#     background-size: contain;
#     background-repeat: no-repeat;
#     vertical-align: middle; } }
# .pointer[_ngcontent-sc244] {
#   cursor: pointer; }
# .course-level[_ngcontent-sc244] {
#   width: 0.8rem;
#   height: 0.8rem;
#   background-size: contain;
#   display: inline-block;
#   vertical-align: middle;
#   background-repeat: no-repeat;
#   margin-right: 0.5rem; }
# .course-level-advanced[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/advanced.svg"); }
# .course-level-intermediate[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/intermediate.svg"); }
# .course-level-beginner[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/beginner.svg"); }
# .nanodegree-card[_nghost-sc244]   .image-overlay[_ngcontent-sc244], .nanodegree-card   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   position: absolute;
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 100%;
#   height: 100%;
#   background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon.png");
#   background-repeat: no-repeat;
#   background-position: 0.5rem 0.5rem; }
# .nanodegree-card[_nghost-sc244]   .image-overlay[_ngcontent-sc244]:last-child, .nanodegree-card   [_nghost-sc244]   .image-overlay[_ngcontent-sc244]:last-child {
#     margin-right: 0; }
# @media (max-width: 48rem) {
#   .nanodegree-card[_nghost-sc244]   .mobile-icon[_ngcontent-sc244], .nanodegree-card   [_nghost-sc244]   .mobile-icon[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon-mobile.svg"); } }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+1)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+1)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(82, 92, 101, 0.6); }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+2)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+2)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(255, 162, 52, 0.6); }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+3)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+3)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(2, 204, 186, 0.6); }
# .tag[_ngcontent-sc244] {
#   float: right;
#   text-align: center;
#   font-size: 0.8125rem;
#   line-height: 1.5rem;
#   padding: 0.375rem 0.75rem;
#   letter-spacing: 0.125rem;
#   border-radius: 0.25rem;
#   text-transform: uppercase;
#   font-weight: 600; }
# @media screen and (min-width: 48rem) {
#     .tag[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (max-width: 20rem) {
#     .tag[_ngcontent-sc244] {
#       background: none;
#       box-shadow: none;
#       margin: 0; } }
# .tag--free[_ngcontent-sc244] {
#     color: #02ccba; }
# .tag--new[_ngcontent-sc244] {
#     color: #6854c5; }</style></head>
# <body>
#
# <!-- START: Debug Grid Guidelines -->
# <!-- WARNING: Never update this to GIT -->
# <!-- REQUIRES: enable main[.sandbox.scss|.scss] debug section -->
# <!--<div class="grid-helper">-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--<div class="grid-column"></div>-->
# <!--</div>-->
# <!-- END: Debug Grid Guidelines -->
#
# <ir-root _nghost-sc0="" ng-version="6.0.6" class="page-us page-courses page-courses-all"><ir-nav-mobile _ngcontent-sc0="" _nghost-sc1=""><a _ngcontent-sc1="" class="logo-link" irhybridlink="/" title="Udacity" href="/"><div _ngcontent-sc1="" class="logo-wordmark"><svg _ngcontent-sc1="" alt="Udacity" height="30" viewBox="0 0 180 30" width="180"><g _ngcontent-sc1="" fill="none" fill-rule="evenodd"><path _ngcontent-sc1="" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.29385c-3.575172 0-5.95862-2.644648-5.95862-6.170846 0-3.526197 2.482758-6.072895 5.95862-6.072895 2.78069 0 4.468966 1.5672 4.468966 1.5672l.794483-1.3713s-1.787587-1.86105-5.46207-1.86105c-4.766896 0-7.746206 3.526198-7.746206 7.738045 0 4.309797 3.07862 7.933945 7.944827 7.933945 3.773793 0 5.66069-2.5467 5.66069-2.5467l-1.092414-1.175398c-.09931-.09795-1.588965 1.959-4.568276 1.959zm14.896553-14.00684h1.986206v15.67199h-1.986207zm10.924137 1.959h4.965517v13.71299h1.986207V9.794994h4.96552v-1.959H143.0069m30.587583 0l-4.766896 7.150344-4.866207-7.150347h-2.085518l5.95862 8.717546v6.954445h1.986208v-6.954444l5.85931-8.71754m-81.434482 0l-6.157242 15.67199h1.986207l1.688276-4.5057 6.45517-1.3713 2.18483 5.876998h1.986203l-6.05793-15.67199h-2.085518zm-1.886897 9.305242l2.97931-7.248294h.099315L97.92 16.063788l-5.56138 1.07745z" fill="#2E3D49" id="wordmark"></path><path _ngcontent-sc1="" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z" fill="#02B3E4" id="mark"></path></g></svg></div></a><nav _ngcontent-sc1="" class="header__sidenav--navigation" role="navigation"><ul _ngcontent-sc1=""><!----><!----><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" title="Catalog" href="/courses/all"> Catalog </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" title="Explore" href="/pathfinder"> Explore </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" title="Nanodegree" href="/nanodegree"> Nanodegree </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" title="Career Services" href="/career-services"> Career Services </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" title="For Business" href="/enterprise"> For Business </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" class="blue" title="Sign In" href="https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated"> Sign In </a></li><li _ngcontent-sc1="" class="ng-star-inserted"><a _ngcontent-sc1="" class="turquoise" title="Get Started" href="https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated"> Get Started </a></li></ul></nav></ir-nav-mobile><ir-content _ngcontent-sc0="" _nghost-sc2=""><ir-moustache _ngcontent-sc0="" _nghost-sc3="" class="ng-tns-c3-0 ng-trigger ng-trigger-shrinkUpAnimation ng-star-inserted"><!----></ir-moustache><ir-header _ngcontent-sc0="" _nghost-sc4=""><header _ngcontent-sc4=""><div _ngcontent-sc4="" class="header__navbar--toggle"><a _ngcontent-sc4="" class= ...
# <script type="text/javascript" src="runtime.779ab63315b4a9607089.js"></script><script type="text/javascript" src="polyfills.9f2bda1e51d11e4eb315.js"></script><script type="text/javascript" src="scripts.7810e8fe1e953f6db44e.js"></script><script type="text/javascript" src="main.cf6ccd25ad509cb9cf80.js"></script>
#
# <script id="iridium-us-state" type="application/json">{&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-US&q;:[{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Catalog&q;},{&q;href&q;:&q;/pathfinder&q;,&q;text&q;:&q;Explore&q;},{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegree&q;},{&q;href&q;:&q;/career-services&q;,&q;text&q;:&q;Career Services&q;},{&q;href&q;:&q;/enterprise&q;,&q;text&q;:&q;For Business&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-US&q;:[],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--primary&q;]}]},&q;/courses/all@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Nanodegree&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;--nd&q;}}]},{&q;section&q;:&q;Skill Level&q;,&q;values&q;:[{&q;title&q;:&q;Beginner&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;beginner&q;}},{&q;title&q;:&q;Intermediate&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;intermediate&q;}},{&q;title&q;:&q;Advanced&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;advanced&q;}}]},{&q;section&q;:&q;Estimated Duration&q;,&q;values&q;:[{&q;title&q;:&q;&l;1 month&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:0,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:1,&q;rangeMaxInclusive&q;:false}},{&q;title&q;:&q;1 - 3 months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:1,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:3,&q;rangeMaxInclusive&q;:true}},{&q;title&q;:&q;3+ months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:3,&q;rangeMinInclusive&q;:true}}]}],&q;/courses/all@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;tit ...

# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.

# %%
soup = BeautifulSoup(r.text, "lxml")
print(soup.get_text())
# Out:
# Course Catalog | Udacity
#
#
#
#
# html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# span.snackbar__content[_ngcontent-sc0] {
#   margin: 0;
#   color: white; }
#
# span.snackbar__content[_ngcontent-sc0]   a[_ngcontent-sc0] {
#     margin: 0;
#     color: white;
#     text-decoration: underline; }html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 23.72881356%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem);
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2], .sticky   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2], .sticky   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-riseup[_nghost-sc2], .page-riseup   [_nghost-sc2] {
#   background: #2e3d49; }html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 2.5rem 0.75rem 1.5rem;
#   color: #fff;
#   text-align: center; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-sc4] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc4] {
#   display: none !important; }
#
# .show[_ngcontent-sc4] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc4] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc4] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc4] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc4] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc4] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc4] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc4] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc4] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc4] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc4] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc4] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc4] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#
# .contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc4] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc4] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc4] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc4] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc4] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc4] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc4] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc4] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc4] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc4]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc4]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc4], [_nghost-sc4] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc4]::after, [_nghost-sc4]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc4], .header--clone[_nghost-sc4] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc4]   .header__navbar[_ngcontent-sc4], .header--clone[_nghost-sc4]   .header__navbar[_ngcontent-sc4], .header.header--clone[_ngcontent-sc4]   header[_ngcontent-sc4], .header--clone[_nghost-sc4]   header[_ngcontent-sc4] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc4], .header--stick[_nghost-sc4] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc4]::after, header[_ngcontent-sc4]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc4], header[_ngcontent-sc4] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc4]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 23.72881356%; }
#           .header__navbar--logo[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc4] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc4] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc4]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc4] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc4] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__navbar--logo[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc4]   .logo-mark[_ngcontent-sc4] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   nav[_ngcontent-sc4] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc4]   a[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   div[_ngcontent-sc4] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--primary[_ngcontent-sc4]:hover, .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--turquoise[_ngcontent-sc4]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .button--guest[_ngcontent-sc4], .header__navbar--navigation[_ngcontent-sc4]   .button--student[_ngcontent-sc4] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc4]   .divider[_ngcontent-sc4]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc4] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc4] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark[_ngcontent-sc4], .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   .logo-wordmark--cn[_ngcontent-sc4] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc4]   .logo-link[_ngcontent-sc4]   #wordmark[_ngcontent-sc4] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc4] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc4]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   li[_ngcontent-sc4] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4], .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc4]   .guest[_ngcontent-sc4]   a[_ngcontent-sc4]:hover, .header__sidenav--navigation[_ngcontent-sc4]   .student[_ngcontent-sc4]   a[_ngcontent-sc4]:hover {
#             color: #01647f; }
#
# [_nghost-sc4] {
#   display: block; }
#
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
#
# .header-icons[_ngcontent-sc4] {
#   display: block;
#   position: relative;
#   top: 1.4rem;
#   float: right;
#   margin-right: -0.7rem; }
#
# .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#     height: 1.8rem;
#     fill: #02b3e4; }
#
# @media screen and (min-width: 30rem) {
#     .header-icons[_ngcontent-sc4] {
#       display: none; } }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .page-homepage[_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4], .page-homepage   [_nghost-sc4]   .logo-wordmark--cn[_ngcontent-sc4]   h1[_ngcontent-sc4] {
#   margin-bottom: 0; }
#
# .page-eu.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-eu.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage[_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4], .page-in.page-homepage   [_nghost-sc4]   img.logo-wordmark--img[_ngcontent-sc4] {
#   padding-bottom: 1.5rem; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage[_nghost-sc4]:not(.page-us)   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .button--navigation[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .button--navigation[_ngcontent-sc4]:hover, .page-homepage:not(.page-us)   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .text--navigation[_ngcontent-sc4], .page-homepage:not(.page-us)   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-homepage[_nghost-sc4]:not(.page-us)   .divider[_ngcontent-sc4]::before, .page-homepage:not(.page-us)   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-riseup[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-riseup[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-riseup[_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-riseup[_nghost-sc4]   .button--navigation[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-riseup[_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover, .page-riseup   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-riseup[_nghost-sc4]   .text--navigation[_ngcontent-sc4], .page-riseup   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-riseup[_nghost-sc4]   .divider[_ngcontent-sc4]::before, .page-riseup   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-business[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-business   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-business[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-business   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-business[_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-business   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-business[_nghost-sc4]   .button--navigation[_ngcontent-sc4], .page-business   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-business[_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover, .page-business   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-business[_nghost-sc4]   .text--navigation[_ngcontent-sc4], .page-business   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# .page-business[_nghost-sc4]   .divider[_ngcontent-sc4]::before, .page-business   [_nghost-sc4]   .divider[_ngcontent-sc4]::before {
#   border-left: 1px solid #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-en[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #wordmark-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #mark[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header__navbar[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen[_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   header[_ngcontent-sc4]   #stroke-cn[_ngcontent-sc4] {
#   stroke: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .nav-toggle[_ngcontent-sc4]   .bar[_ngcontent-sc4] {
#   background: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .header-icons[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   fill: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .button--navigation[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .button--navigation[_ngcontent-sc4] {
#   color: #fff; }
#
# .page-fuer-unternehmen[_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover, .page-fuer-unternehmen   [_nghost-sc4]   .button--navigation[_ngcontent-sc4]:hover {
#     color: rgba(255, 255, 255, 0.8); }
#
# .page-fuer-unternehmen[_nghost-sc4]   .text--navigation[_ngcontent-sc4], .page-fuer-unternehmen   [_nghost-sc4]   .text--navigation[_ngcontent-sc4] {
#   color: #fff;
#   pointer-events: none;
#   cursor: default; }
#
# ...
#       margin: 0 auto 1rem;
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 100%; }
# .card__inner[_ngcontent-sc244]   .image_wrapper[_ngcontent-sc244]   .image-placeholder[_ngcontent-sc244]:last-child {
#         margin-right: 0; }
# .card__inner[_ngcontent-sc244]   .image_wrapper[_ngcontent-sc244]   .image-placeholder[_ngcontent-sc244]   span[_ngcontent-sc244] {
#         text-align: center; }
# @media screen and (min-width: 48rem) {
#         .card__inner[_ngcontent-sc244]   .image_wrapper[_ngcontent-sc244]   .image-placeholder[_ngcontent-sc244] {
#           height: 6.5rem; } }
# .card-wrapper[_ngcontent-sc244]   .card__expander[_ngcontent-sc244] {
#   transition: max-height 0.5s ease-in-out;
#   background-color: white;
#   box-shadow: 5px 5px 25px 0px rgba(46, 61, 73, 0.2);
#   border-radius: 0 0 0.375rem 0.375rem; }
# .card-wrapper.is-collapsed[_ngcontent-sc244]   .card__expander[_ngcontent-sc244] {
#   overflow: hidden;
#   width: 100%;
#   max-height: 0; }
# .card-wrapper.is-expanded[_ngcontent-sc244]   .card__expander[_ngcontent-sc244] {
#   overflow: hidden;
#   width: 100%;
#   max-height: 20rem; }
# .card-wrapper.is-expanded[_ngcontent-sc244]   .card__inner[_ngcontent-sc244] {
#   border-bottom-left-radius: 0;
#   border-bottom-right-radius: 0; }
# .card-wrapper[_ngcontent-sc244]   hr[_ngcontent-sc244] {
#   border-top: 1px solid #dbe2e8;
#   margin: 1.5rem 4rem; }
# .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#   margin-top: 0;
#   font-weight: 600;
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   color: #7D97AD;
#   text-transform: none;
#   display: inline-block; }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     .card[_ngcontent-sc244]   .category[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# .card-heading[_ngcontent-sc244] {
#   margin-top: 0;
#   margin-bottom: 0.5rem; }
# .card-heading[_ngcontent-sc244]   a[_ngcontent-sc244] {
#     color: #2e3d49;
#     text-transform: capitalize;
#     font-weight: 600;
#     display: block;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     line-height: 1.6rem;
#     max-height: 4.8rem; }
# .card-heading[_ngcontent-sc244]   a[_ngcontent-sc244]:hover {
#       color: #02b3e4; }
# .card-content[_ngcontent-sc244] {
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 74.57627119%; }
# .card-content[_ngcontent-sc244]:last-child {
#     margin-right: 0; }
# @media (max-width: 62rem) {
#     .card-content[_ngcontent-sc244] {
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 100%; }
#       .card-content[_ngcontent-sc244]:last-child {
#         margin-right: 0; } }
# .card__expander[_ngcontent-sc244] {
#   background: linear-gradient(to top left, #F7F7F7, #EAFBFF); }
# .card__expander--summary[_ngcontent-sc244] {
#     font-size: 0.9rem;
#     padding: 1.5rem 4rem 0; }
# .card__expander--details[_ngcontent-sc244] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 100%;
#     display: flex;
#     justify-content: space-between;
#     padding: 0 4rem 1.5rem; }
# .card__expander--details[_ngcontent-sc244]:last-child {
#       margin-right: 0; }
# .card__expander--details[_ngcontent-sc244]   .btn[_ngcontent-sc244] {
#       width: 10rem;
#       height: 2.5rem;
#       line-height: 2.3rem;
#       color: #fff;
#       background-color: #02b3e4; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244] {
#   display: flex; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   h4[_ngcontent-sc244] {
#     font-size: 0.9rem;
#     text-transform: capitalize;
#     margin-top: 0; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   div[_ngcontent-sc244] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 49.15254237%; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   div[_ngcontent-sc244]:last-child {
#       margin-right: 0; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   span[_ngcontent-sc244] {
#     font-size: 0.875rem;
#     color: #2e3d49; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   span.truncate-content[_ngcontent-sc244] {
#       max-height: 3rem;
#       display: block;
#       overflow-y: hidden; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   .level[_ngcontent-sc244]   span[_ngcontent-sc244]:after {
#     content: '' !important; }
# .card[_ngcontent-sc244]   .right-sub[_ngcontent-sc244]   .skills[_ngcontent-sc244]    ~ .level[_ngcontent-sc244] {
#     margin-top: 1.4rem; }
# .card[_ngcontent-sc244]   h4[_ngcontent-sc244] {
#   margin-bottom: 0; }
# @media (max-width: 48rem) {
#   .card[_ngcontent-sc244]   .mobile-icon[_ngcontent-sc244] {
#     display: inline-block;
#     height: 0.8rem;
#     width: 1.5rem;
#     margin-right: 0.2rem;
#     background-image: url("/assets/iridium/images/course-catalog/course-icon-mobile.svg");
#     background-position: center;
#     background-size: contain;
#     background-repeat: no-repeat;
#     vertical-align: middle; } }
# .pointer[_ngcontent-sc244] {
#   cursor: pointer; }
# .course-level[_ngcontent-sc244] {
#   width: 0.8rem;
#   height: 0.8rem;
#   background-size: contain;
#   display: inline-block;
#   vertical-align: middle;
#   background-repeat: no-repeat;
#   margin-right: 0.5rem; }
# .course-level-advanced[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/advanced.svg"); }
# .course-level-intermediate[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/intermediate.svg"); }
# .course-level-beginner[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/svgs/beginner.svg"); }
# .nanodegree-card[_nghost-sc244]   .image-overlay[_ngcontent-sc244], .nanodegree-card   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   position: absolute;
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 100%;
#   height: 100%;
#   background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon.png");
#   background-repeat: no-repeat;
#   background-position: 0.5rem 0.5rem; }
# .nanodegree-card[_nghost-sc244]   .image-overlay[_ngcontent-sc244]:last-child, .nanodegree-card   [_nghost-sc244]   .image-overlay[_ngcontent-sc244]:last-child {
#     margin-right: 0; }
# @media (max-width: 48rem) {
#   .nanodegree-card[_nghost-sc244]   .mobile-icon[_ngcontent-sc244], .nanodegree-card   [_nghost-sc244]   .mobile-icon[_ngcontent-sc244] {
#     background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon-mobile.svg"); } }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+1)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+1)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(82, 92, 101, 0.6); }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+2)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+2)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(255, 162, 52, 0.6); }
# .nanodegree-card[_nghost-sc244]:nth-child(3n+3)   .image-overlay[_ngcontent-sc244], .nanodegree-card:nth-child(3n+3)   [_nghost-sc244]   .image-overlay[_ngcontent-sc244] {
#   background-color: rgba(2, 204, 186, 0.6); }
# .tag[_ngcontent-sc244] {
#   float: right;
#   text-align: center;
#   font-size: 0.8125rem;
#   line-height: 1.5rem;
#   padding: 0.375rem 0.75rem;
#   letter-spacing: 0.125rem;
#   border-radius: 0.25rem;
#   text-transform: uppercase;
#   font-weight: 600; }
# @media screen and (min-width: 48rem) {
#     .tag[_ngcontent-sc244] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (max-width: 20rem) {
#     .tag[_ngcontent-sc244] {
#       background: none;
#       box-shadow: none;
#       margin: 0; } }
# .tag--free[_ngcontent-sc244] {
#     color: #02ccba; }
# .tag--new[_ngcontent-sc244] {
#     color: #6854c5; }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Catalog  Explore  Nanodegree  Career Services  For Business  Sign In  Get Started  Catalog  Explore  Nanodegree  Career Services  For Business  Sign In  Get Started Program CatalogSort by PopularSort by NewestFiltersFilter BySelect Program DetailsTypeNanodegreeFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration<1 month1 - 3 months3+ monthsIndustry SkillsSkillsAI AlgorithmsAR developmentARKitAlteryxAndroid DevelopmentBlueprint programmingC++CSSControls and EstimationCore DataDeep LearningDesign SprintDigital MarketingDisplay AdsExcelFacebook MarketingGoogle VR SDK for UnityHTMLJava programmingJavaScriptJupyter NotebooksKalman FiltersMachine LearningMobile Web AppsNetworkingNeural NetworksOffline Capable Web AppsOptimizationPredictive ModelingProbabilityPrototypingPythonReactReact NativeReduxRobot Operating SystemRoboticsSQLSearch AdsSearch AlgorithmsSelf-Driving CarsSocial Media MarketingStatisticsSupervised LearningSwift programmingTableauUIKitUnityUnity ARKit PluginUnrealUnsupervised LearningUser testingVR developmentWeb Tooling and AutomationYouTube MarketingFilter BySelect Program DetailsTypeNanodegreeFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration<1 month1 - 3 months3+ monthsIndustry SkillsSkillsAI AlgorithmsAR developmentARKitAlteryxAndroid DevelopmentBlueprint programmingC++CSSControls and EstimationCore DataDeep LearningDesign SprintDigital MarketingDisplay AdsExcelFacebook MarketingGoogle VR SDK for UnityHTMLJava programmingJavaScriptJupyter NotebooksKalman FiltersMachine LearningMobile Web AppsNetworkingNeural NetworksOffline Capable Web AppsOptimizationPredictive ModelingProbabilityPrototypingPythonReactReact NativeReduxRobot Operating SystemRoboticsSQLSearch AdsSearch AlgorithmsSelf-Driving CarsSocial Media MarketingStatisticsSupervised LearningSwift programmingTableauUIKitUnityUnity ARKit PluginUnrealUnsupervised LearningUser testingVR developmentWeb Tooling and AutomationYouTube MarketingAllArtificial IntelligenceArtificial IntelligenceDeep LearningDeep Reinforcement LearningMachine LearningComputer VisionAI Programming with PythonNatural Language ProcessingData ScienceData ScientistData AnalystBusiness AnalyticsPredictive Analytics for BusinessProgramming for Data ScienceProgramming and DevelopmentAndroid DeveloperAndroid BasicsBlockchainIntro To ProgrammingFront End DeveloperFull Stack DeveloperMobile Web SpecialistReactVirtual RealityUnrealiOSAI Programming with PythonAutonomous SystemsRoboticsSelf Driving CarIntro To Self Driving CarFlying CarBusinessDigital MarketingGoogle AdwordsDesign Sprint FoundationsBusiness AnalyticsPredictive Analytics for BusinessCareerSchoolAllArtificial IntelligenceArtificial IntelligenceDeep LearningDeep Reinforcement LearningMachine LearningComputer VisionAI Programming with PythonNatural Language ProcessingData ScienceData ScientistData AnalystBusiness AnalyticsPredictive Analytics for BusinessProgramming for Data ScienceProgramming and DevelopmentAndroid DeveloperAndroid BasicsBlockchainIntro To ProgrammingFront End DeveloperFull Stack DeveloperMobile Web SpecialistReactVirtual RealityUnrealiOSAI Programming with PythonAutonomous SystemsRoboticsSelf Driving CarIntro To Self Driving CarFlying CarBusinessDigital MarketingGoogle AdwordsDesign Sprint FoundationsBusiness AnalyticsPredictive Analytics for BusinessCareerApply FiltersNewSchool of Data ScienceData Analyst In Collaboration WithKaggle, ModeintermediateNanodegree DetailsintermediateLearn MoreSchool of Artificial IntelligenceDeep LearningSkills CoveredDeep Learning, Neural Networks, Jupyter Notebooks, CNNs, GANsintermediateNanodegree DetailsintermediateDeep learning is driving advances in artificial intelligence that are changing our world. Enroll now to build and apply your own deep neural networks to produce amazing solutions to important challenges.Learn MoreSchool of Artificial IntelligenceMachine Learning EngineerSkills CoveredMachine Learning, Supervised Learning, Unsupervised L ...
#
# {&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-US&q;:[{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Catalog&q;},{&q;href&q;:&q;/pathfinder&q;,&q;text&q;:&q;Explore&q;},{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegree&q;},{&q;href&q;:&q;/career-services&q;,&q;text&q;:&q;Career Services&q;},{&q;href&q;:&q;/enterprise&q;,&q;text&q;:&q;For Business&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-US&q;:[],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--primary&q;]}]},&q;/courses/all@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Nanodegree&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;--nd&q;}}]},{&q;section&q;:&q;Skill Level&q;,&q;values&q;:[{&q;title&q;:&q;Beginner&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;beginner&q;}},{&q;title&q;:&q;Intermediate&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;intermediate&q;}},{&q;title&q;:&q;Advanced&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;advanced&q;}}]},{&q;section&q;:&q;Estimated Duration&q;,&q;values&q;:[{&q;title&q;:&q;&l;1 month&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:0,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:1,&q;rangeMaxInclusive&q;:false}},{&q;title&q;:&q;1 - 3 months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:1,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:3,&q;rangeMaxInclusive&q;:true}},{&q;title&q;:&q;3+ months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:3,&q;rangeMinInclusive&q;:true}}]}],&q;/courses/all@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q; ...

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just ike in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
# Find all course summaries
summaries = soup.find_all("div", {"class":"course-summary-card"})
print('Number of Courses:', len(summaries))
# Out:
# Number of Courses: 222

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(summaries[0].prettify())
# Out:
# <div _ngcontent-sc241="" class="course-summary-card row row-gap-medium catalog-card nanodegree-card ng-star-inserted">
#  <ir-catlog-card _ngcontent-sc241="" _nghost-sc244="">
#   <div _ngcontent-sc244="" class="card-wrapper is-collapsed">
#    <div _ngcontent-sc244="" class="card__inner card mb-0">
#     <div _ngcontent-sc244="" class="card__inner--upper">
#      <div _ngcontent-sc244="" class="image_wrapper hidden-md-down">
#       <a _ngcontent-sc244="" href="/course/data-analyst-nanodegree--nd002">
#        <!-- -->
#        <div _ngcontent-sc244="" class="image-container ng-star-inserted" style="background-image:url(https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd002/nd-card.jpg);">
#         <div _ngcontent-sc244="" class="image-overlay">
#         </div>
#        </div>
#       </a>
#       <!-- -->
#      </div>
#      <div _ngcontent-sc244="" class="card-content">
#       <!-- -->
#       <span _ngcontent-sc244="" class="tag tag--new card ng-star-inserted">
#        New
#       </span>
#       <!-- -->
#       <div _ngcontent-sc244="" class="category-wrapper">
#        <span _ngcontent-sc244="" class="mobile-icon">
#        </span>
#        <!-- -->
#        <h4 _ngcontent-sc244="" class="category ng-star-inserted">
#         School of Data Science
#        </h4>
#       </div>
#       <h3 _ngcontent-sc244="" class="card-heading">
#        <a _ngcontent-sc244="" href="/course/data-analyst-nanodegree--nd002">
#         Data Analyst
#        </a>
#       </h3>
#       <div _ngcontent-sc244="" class="right-sub">
#        <!-- -->
#        <!-- -->
#        <div _ngcontent-sc244="" class="hidden-sm-down ng-star-inserted">
#         <h4 _ngcontent-sc244="">
#          In Collaboration With
#         </h4>
#         <span _ngcontent-sc244="" class="truncate-content">
#          <!-- -->
#          <span _ngcontent-sc244="" class="ng-star-inserted">
#           Kaggle,
#          </span>
#          <span _ngcontent-sc244="" class="ng-star-inserted">
#           Mode
#          </span>
#         </span>
#        </div>
#        <div _ngcontent-sc244="" class="hidden-md-up level">
#         <span _ngcontent-sc244="" class="course-level course-level-intermediate" classname="course-level course-level-intermediate">
#         </span>
#         <span _ngcontent-sc244="" class="capitalize">
#          intermediate
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div _ngcontent-sc244="" class="card__inner--lower hidden-sm-down">
#      <div _ngcontent-sc244="" class="left uppercase blue expander pointer">
#       <!-- -->
#       <span _ngcontent-sc244="" class="ng-star-inserted">
#        Nanodegree Details
#       </span>
#       <!-- -->
#      </div>
#      <div _ngcontent-sc244="" class="right">
#       <!-- -->
#       <span _ngcontent-sc244="" class="caption text-right level ng-star-inserted">
#        <span _ngcontent-sc244="" class="course-level course-level-intermediate" classname="course-level course-level-intermediate">
#        </span>
#        <span _ngcontent-sc244="" class="capitalize">
#         intermediate
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div _ngcontent-sc244="" class="card__expander">
#     <div _ngcontent-sc244="" class="card__expander--summary mb-1">
#      <!-- -->
#     </div>
#     <hr _ngcontent-sc244=""/>
#     <div _ngcontent-sc244="" class="card__expander--details">
#      <div _ngcontent-sc244="" class="rating">
#       <!-- -->
#      </div>
#      <a _ngcontent-sc244="" class="button--primary btn" href="/course/data-analyst-nanodegree--nd002">
#       Learn More
#      </a>
#     </div>
#    </div>
#   </div>
#  </ir-catlog-card>
# </div>

# %% [markdown]
# Look for selectors contain the the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
summaries[0].select_one("h3").get_text().strip()
# Out:
# 'Data Analyst'

# %%
# Extract school
summaries[0].select_one("h4").get_text().strip()
# Out:
# 'School of Data Science'

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for summary in summaries:
    # append name and school of each summary to courses list
    title = summary.select_one("h3").get_text().strip()
    school = summary.select_one("h4").get_text().strip()
    courses.append((title, school))

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
# Out:
# 222 course summaries found. Sample:
# [('Data Analyst', 'School of Data Science'),
#  ('Deep Learning', 'School of Artificial Intelligence'),
#  ('Machine Learning Engineer', 'School of Artificial Intelligence'),
#  ('Self Driving Car Engineer Nanodegree', 'School of Autonomous Systems'),
#  ('React', 'School of Development'),
#  ('Digital Marketing', 'School of Business'),
#  ('Programming for Data Science', 'School of Data Science'),
#  ('Introduction to Programming', 'School of Development'),
#  ('AI Programming with Python', 'School of Development'),
#  ('Business Analytics', 'School of Business'),
#  ('Front End Web Developer', 'School of Development'),
#  ('Data Scientist', 'School of Data Science'),
#  ('Computer Vision', 'School of Artificial Intelligence'),
#  ('Intro to Self-Driving Cars', 'School of Autonomous Systems'),
#  ('Full Stack Web Developer', 'School of Development'),
#  ('Robotic Software Engineer', 'In Collaboration With'),
#  ('Flying Car', 'School of Autonomous Systems'),
#  ('Android Developer', 'School of Development'),
#  ('Natural Language Processing', 'School of Artificial Intelligence'),
#  ('VR Developer', 'School of Development')]
